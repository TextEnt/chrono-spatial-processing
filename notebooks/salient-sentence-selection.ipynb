# %% [markdown]
# ## Imports

# %%
from pathlib import Path
from spacy.tokens import DocBin
from tqdm import tqdm
from textentlib.utils import nlp_model_fr, print_corpus_summary, SalientSentenceSelector

# %%
SPACY_CORPUS_SERIALIZED_PATH = "../data/corpus_EF.spacy"

# %% [markdown]
# ## Loading pre-processed data

# %%
entity_fishing_pipe = nlp_model_fr.add_pipe(
    "entityfishing", config={
        #"api_ef_base": "http://nerd.huma-num.fr/nerd/service"
        "api_ef_base": "http://localhost:8090/service/"
    }
)

# %%
if Path(SPACY_CORPUS_SERIALIZED_PATH).exists():
    spacy_corpus = DocBin(store_user_data=True).from_disk(SPACY_CORPUS_SERIALIZED_PATH)
    print(f"Loaded serialize spacy corpus from {SPACY_CORPUS_SERIALIZED_PATH}")
    print_corpus_summary(spacy_corpus, nlp_model_fr)
else:
    spacy_corpus = DocBin(store_user_data=True)
# Out:
# Loaded serialize spacy corpus from ../data/corpus_EF.spacy
# Number of documents in the corpus: 594
# Number of entities in the corpus: 287389
# Number of tokens in the corpus: 12885306

# %%
docs = spacy_corpus.get_docs(nlp_model_fr.vocab)

# %% [markdown]
# ## Adding entity linking information to docs in corpus

# %%
entity_fishing_pipe = nlp_model_fr.add_pipe(
    "entityfishing", config={
        #"api_ef_base": "http://nerd.huma-num.fr/nerd/service"
        "api_ef_base": "http://localhost:8090/service/"
    }
)

# %%
#nlp_model_fr.pipe_names

# %%
spacy_corpus = DocBin(store_user_data=True)

# %%
for spacy_doc in tqdm(list(docs)):
    el_doc = entity_fishing_pipe(spacy_doc)
    el_doc.user_data['entity_linking'] = 'spacy_entity_fishing'
    spacy_corpus.add(el_doc)
# Out:
# 100%|██████████| 594/594 [09:58<00:00,  1.01s/it]

# %%
spacy_corpus.to_disk('./data/corpus_EF.spacy')

# %%
print_corpus_summary(spacy_corpus, nlp_model_fr)
# Out:
# Number of documents in the corpus: 594
# Number of entities in the corpus: 287389
# Number of tokens in the corpus: 12885306

# %% [markdown]
# ## Selection of salient sentences

# %%
import random, operator, json
from textentlib.utils import SalientSentenceSelector

# %%
spacy_docs = list(docs)

# %%
sample_doc = random.choice(spacy_docs)

# %%
sample_doc.user_data
# Out:
# {'author': 'Bordelon, Laurent',
#  'title': 'La baguette de Vulcain Comedie',
#  'publication_date': '1693',
#  'path': '../TheatreLFSV2-downloaded/NER/bpt6k859543c.tar.gz.tei_segmented_ner.xml',
#  'filename': 'bpt6k859543c.tar.gz.tei_segmented_ner.xml',
#  'entity_linking': 'spacy_entity_fishing',
#  ('._.',
#   'annotations',
#   None,
#   None): {'disambiguation_text_service': {'software': 'entity-fishing',
#    'version': '0.0.6',
#    'date': '2025-01-10T16:49:39.018589Z',
#    'runtime': 314,
#    'nbest': False,
#    'text': 'Chez A\' ROUEN, EAN DUMESNIL, dans la Cour du Palais. BONAVENTURE LE BRUN, sous la Porte du Palais. AVIS AULECIEUN. À Baguette de Vulcain Comédie a eu tant de succès, représentée sur le Théâtre dans cette ville par les Comédients, que plusieurs Personnes qui l\'ont vu joüer ont souhaité de l\'avoir Imprimée, ce qui m\'a obligé d\'en demander une Copie, sur laquelle aai fin cette Impression le plus fidèlement qu\'il a été possible, et où je n\'ai rien épargné pour sa perfection, je dois espérer que l\'on m\'en sçaura bon té et que si cet pièce agrée au public on lui en donnera plusieurs au pula suite, ACTEURS. ROGER, Chevalier. UN DRUIDE, Musicien. COLOMBINE, Femme ayaut perdu son Mari. IZABELLE, Jeune fille. THIBAUD, autre Paysan. Une vieille femme de LOCAS, Personnage muet. PIERROT, Paysan niais valet de Hrointin BRADAMANTE, Fille endormie depuis deux cents ans. PASQUAREL, Mari de Colombine LA 2 BAGUETE DE VULCAIN. MED I 2 ORNE\'E DE MUSIQUE. LE -THÉÂTRE REPRÉSENTE un Palais, et dans le fonds un Géant d\'une énorme et prodigieuse grandeuleu . SCÈNE I. OGER habillé et armé en Chevalier, sa Baguette à la main. \nGER\n C\'est dans ce jour que Roger, cet A incomparable Chevalier, va délivrer Bradamante de ce monstrueux Geant, qui par la force de ses enchantements la tithait renfermée et endormie dans ce Palais depuis deux cents ans. Corrobore mon cœur craintif, D\'un Julep confortatif, Car l\'hideuse et l\'affreuse mine De ce Geant rébarbatif, A fait sur moi pauvre chétif, Les effets d\'une médecine. Et toi cruel Sarrasin, Qui par un esprit trop malin Retiens ma gente Tourterelle, Dis-moi si tes bras pour fendants, Ont bien pu garder deux cens ans L\'honneur de cette Jouvencelle. Hélas! dans notre temps Pour conserver une Pucelle Jusques à l\'âge de seiz ans, Combien fandrait-il de Géants. Mais il est temps de montrer des éfets sans s\'amuser à des paroles, puisque le Géant est endormi, coupons-jui d\'a bord la tête. Les Violons pour exciter Roger au combat joüent un air. Roger coupe le Géant en plusieurs morceaux. Les membres séparés courent après Seigneur, ce qui lui fait dire d\'un ton tremblant et Comique. Messieurs les membres je vous demande pardon, ayez pitié d\'un pauvre Chevalier: Madame la Tête quartier „ vous prie, je ne l\'ai pas fait exprès, mo crojois pas que cela vous ferait mal, quartier, quartier, miséricorde. Tous ces membres disparaissent. \nJER\n Je suis vainqueur, Mais ce n\'est pas sans peur. Achevons de rompre l\'enchantement et tirons des bras du sommeil la charmante Bradamante Le Palais qui était gardé par le Géant, s\'ouvre.  dès est lèle ROGER allant à la porte du Palais pour réveiller BRADAMANTE LLONS réveillez-vous, belle enA Vormie, n\'est-il pas temps depuis deux cens ans que vous dormez, cela en nolribie, on ne iquuroie tirer une femme du lit. ROGEA lui donmint un toup de sa Baguette. Aslons qu\'on se réveile. BRADAMANTE étonnée. Ah Ciel. \nROGER\n Qu\'avez-vous la Belle, est-ce que le coloris de mon visage vous surprend, ô après la belle que depuis deux cens ans que vous dormez, les hommes sont changez du blanc au noir, et les fémmes du noir au blanc et au rouge; mais pardonnez belle Bradamante, si je vous interromps dans queique reres donc tous auriez peut-être été bien aise de voir la fin. \nBRADAMANTE\n 1 ois, il y a deux cents ans que je n\'y vu le jour. \nROGER\n Assurément. \nBRADAMANTE\n l\' on revje ne retrourerarconc plus l\'amant qu\'on m\'avait destiné pour époux. \nOGER\n Ho! pour des Amants vous n\'en manquerez pas, la plus laide en a dans ce pays-cy; mais pour des épouseurs, rara avis erit: Mais dites-moi un peu des nouvelles du temps passé, en revanche je vous en apprendrai de celui-cy. De votre temps, il y a deux ceus ans, avant votre sommeil, comment faisait-on l\'amour. \nBRADAMANTE\n me emui le paiore parre cœur, la Maîtresse croyait tout ce que son Amant toujours disait, et l\'Amant ne lui disait que ce qu\'il pensait. \nGER\n Ho que ce n\'est plus le temps, o ...
#    'language': {'lang': 'en', 'conf': 1.0},
#    'global_categories': ({'weight': 0.002055448268595827,
#      'source': 'wikipedia-en',
#      'category': 'Burgundy',
#      'page_id': 34084872},
#     {'weight': 0.005565126253761371,
#      'source': 'wikipedia-en',
#      'category': 'Astronomical objects known since antiquity',
#      'page_id': 42814603},
#     {'weight': 0.001552137637847906,
#      'source': 'wikipedia-en',
#      'category': 'United States Department of Energy national laboratories',
#      'page_id': 42594949}),
#    'entities': ({'rawName': 'PIERROT',
#      'offsetStart': 779,
#      'offsetEnd': 786,
#      'confidence_score': 0.4001,
#      'wikipediaExternalRef': 2397503,
#      'wikidataId': 'Q2638650',
#      'domains': ('Administration', 'Sociology')},
#     {'rawName': 'Colombine',
#      'offsetStart': 888,
#      'offsetEnd': 897,
#      'confidence_score': 0.4269,
#      'wikipediaExternalRef': 662603,
#      'wikidataId': 'Q444127'},
#     {'rawName': 'GER',
#      'offsetStart': 1119,
#      'offsetEnd': 1122,
#      'confidence_score': 0.666,
#      'wikipediaExternalRef': 897091,
#      'wikidataId': 'Q249083',
#      'domains': ('Sociology', 'Astronomy', 'Computer_Science')},
#     {'rawName': 'Roger',
#      'offsetStart': 1147,
#      'offsetEnd': 1152,
#      'confidence_score': 0.3754,
#      'wikipediaExternalRef': 987632,
#      'wikidataId': 'Q4925304',
#      'domains': ('Biology',)},
#     {'rawName': 'Julep',
#      'offsetStart': 1374,
#      'offsetEnd': 1379,
#      'confidence_score': 0.4987,
#      'wikipediaExternalRef': 42671484,
#      'wikidataId': 'Q21750314',
#      'domains': ('Body_Care', 'Health')},
#     {'rawName': 'Roger',
#      'offsetStart': 1953,
#      'offsetEnd': 1958,
#      'confidence_score': 0.3754,
#      'wikipediaExternalRef': 987632,
#      'wikidataId': 'Q4925304',
#      'domains': ('Biology',)},
#     {'rawName': 'Roger',
#      'offsetStart': 1985,
#      'offsetEnd': 1990,
#      'confidence_score': 0.3754,
#      'wikipediaExternalRef': 987632,
#      'wikidataId': 'Q4925304',
#      'domains': ('Biology',)},
#     {'rawName': 'Seigneur',
#      'offsetStart': 2063,
#      'offsetEnd': 2071,
#      'confidence_score': 0.5033,
#      'wikipediaExternalRef': 2650181,
#      'wikidataId': 'Q1450700',
#      'domains': ('Sociology', 'Biology')},
#     {'rawName': 'Madame',
#      'offsetStart': 2205,
#      'offsetEnd': 2211,
#      'confidence_score': 0.3743,
#      'wikipediaExternalRef': 7376613,
#      'wikidataId': 'Q3136876',
#      'domains': ('Military',)},
#     {'rawName': 'JER',
#      'offsetStart': 2377,
#      'offsetEnd': 2380,
#      'confidence_score': 0.627,
#      'wikipediaExternalRef': 2171117,
#      'wikidataId': 'Q6184849',
#      'domains': ('Administration', 'Sociology')},
#     {'rawName': 'Bradamante',
#      'offsetStart': 2507,
#      'offsetEnd': 2517,
#      'confidence_score': 0.6816,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'BRADAMANTE',
#      'offsetStart': 2630,
#      'offsetEnd': 2640,
#      'confidence_score': 0.6816,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'BRADAMANTE',
#      'offsetStart': 2862,
#      'offsetEnd': 2872,
#      'confidence_score': 0.6816,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'Belle',
#      'offsetStart': 2915,
#      'offsetEnd': 2920,
#      'confidence_score': 0.3966,
#      'wikipediaExternalRef': 17132025,
#      'wikidataId': 'Q2894703',
#      'domains': ('Biology',)},
#     {'rawName': 'Bradamante',
#      'offsetStart': 3140,
#      'offsetEnd': 3150,
#      'confidence_score': 0.6816,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'BRADAMANTE',
#      'offsetStart': 3253,
#      'offsetEnd': 3263,
#      'confidence_score': 0.6816,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'BRADAMANTE',
#      'offsetStart': 3338,
#      'offsetEnd': 3348,
#      'confidence_score': 0.4505,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'BRADAMANTE',
#      'offsetStart': 3744,
#      'offsetEnd': 3754,
#      'confidence_score': 0.4505,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'GER',
#      'offsetStart': 3894,
#      'offsetEnd': 3897,
#      'confidence_score': 0.666,
#      'wikipediaExternalRef': 897091,
#      'wikidataId': 'Q249083',
#      'domains': ('Sociology', 'Astronomy', 'Computer_Science')},
#     {'rawName': 'BRADAMANTE',
#      'offsetStart': 4176,
#      'offsetEnd': 4186,
#      'confidence_score': 0.4505,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'BRADAMANTE',
#      'offsetStart': 4707,
#      'offsetEnd': 4717,
#      'confidence_score': 0.4505,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'Lansquenet',
#      'offsetStart': 4951,
#      'offsetEnd': 4961,
#      'confidence_score': 0.6622,
#      'wikipediaExternalRef': 98082,
#      'wikidataId': 'Q382713',
#      'domains': ('Sociology',)},
#     {'rawName': 'BRADAMANTE',
#      'offsetStart': 4998,
#      'offsetEnd': 5008,
#      'confidence_score': 0.4505,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'Césars',
#      'offsetStart': 5140,
#      'offsetEnd': 5146,
#      'confidence_score': 0.6756,
#      'wikipediaExternalRef': 101349,
#      'wikidataId': 'Q174389',
#      'domains': ('Biology',
#       'Geography',
#       'Sociology',
#       'Astronomy',
#       'Electronics',
#       'Computer_Science',
#       'Geology')},
#     {'rawName': 'BRADAMANTE',
#      'offsetStart': 5230,
#      'offsetEnd': 5240,
#      'confidence_score': 0.4505,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'BRADAMANTE',
#      'offsetStart': 5708,
#      'offsetEnd': 5718,
#      'confidence_score': 0.4505,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'BRADAMANTE',
#      'offsetStart': 6090,
#      'offsetEnd': 6100,
#      'confidence_score': 0.4505,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'BRADAMANTE',
#      'offsetStart': 6403,
#      'offsetEnd': 6413,
#      'confidence_score': 0.4505,
#      'wikipediaExternalRef': 2577026,
#      'wikidataId': 'Q1163427',
#      'domains': ('Sociology',)},
#     {'rawName': 'OGER',
#      'offsetStart': 6585,
#      'offsetEnd': 6589,
#      'confidence_score': 0.4693,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'IBAD',
#      'offsetStart': 6905,
#      'offsetEnd': 6909,
#      'confidence_score': 0.6627,
#      'wikipediaExternalRef': 1835541,
#      'wikidataId': 'Q904053',
#      'domains': ('Engineering',)},
#     {'rawName': 'GER',
#      'offsetStart': 7084,
#      'offsetEnd': 7087,
#      'confidence_score': 0.69,
#      'wikipediaExternalRef': 897091,
#      'wikidataId': 'Q249083',
#      'domains': ('Sociology', 'Astronomy', 'Computer_Science')},
#     {'rawName': 'GER',
#      'offsetStart': 7168,
#      'offsetEnd': 7171,
#      'confidence_score': 0.69,
#      'wikipediaExternalRef': 897091,
#      'wikidataId': 'Q249083',
#      'domains': ('Sociology', 'Astronomy', 'Computer_Science')},
#     {'rawName': 'GER',
#      'offsetStart': 7281,
#      'offsetEnd': 7284,
#      'confidence_score': 0.69,
#      'wikipediaExternalRef': 897091,
#      'wikidataId': 'Q249083',
#      'domains': ('Sociology', 'Astronomy', 'Computer_Science')},
#     {'rawName': 'Almanach',
#      'offsetStart': 7498,
#      'offsetEnd': 7506,
#      'confidence_score': 0.3888,
#      'wikipediaExternalRef': 192230,
#      'wikidataId': 'Q171341',
#      'domains': ('Pedagogy',)},
#     {'rawName': 'ER',
#      'offsetStart': 7584,
#      'offsetEnd': 7586,
#      'confidence_score': 0.7096,
#      'wikipediaExternalRef': 177153,
#      'wikidataId': 'Q207375',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ER',
#      'offsetStart': 7845,
#      'offsetEnd': 7847,
#      'confidence_score': 0.7096,
#      'wikipediaExternalRef': 177153,
#      'wikidataId': 'Q207375',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'Pierrot',
#      'offsetStart': 7916,
#      'offsetEnd': 7923,
#      'confidence_score': 0.6596,
#      'wikipediaExternalRef': 51126,
#      'wikidataId': 'Q17309',
#      'domains': ('Biology', 'Psychiatry', 'Health')},
#     {'rawName': 'GER',
#      'offsetStart': 8115,
#      'offsetEnd': 8118,
#      'confidence_score': 0.69,
#      'wikipediaExternalRef': 897091,
#      'wikidataId': 'Q249083',
#      'domains': ('Sociology', 'Astronomy', 'Computer_Science')},
#     {'rawName': 'ER',
#      'offsetStart': 8175,
#      'offsetEnd': 8177,
#      'confidence_score': 0.7096,
#      'wikipediaExternalRef': 177153,
#      'wikidataId': 'Q207375',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'GER',
#      'offsetStart': 8672,
#      'offsetEnd': 8675,
#      'confidence_score': 0.69,
#      'wikipediaExternalRef': 897091,
#      'wikidataId': 'Q249083',
#      'domains': ('Sociology', 'Astronomy', 'Computer_Science')},
#     {'rawName': 'OGER',
#      'offsetStart': 9082,
#      'offsetEnd': 9086,
#      'confidence_score': 0.4693,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'OGER',
#      'offsetStart': 9355,
#      'offsetEnd': 9359,
#      'confidence_score': 0.4693,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'Boulogne',
#      'offsetStart': 11098,
#      'offsetEnd': 11106,
#      'confidence_score': 0.6876,
#      'wikipediaExternalRef': 128242,
#      'wikidataId': 'Q81997',
#      'domains': ('Architecture',)},
#     {'rawName': 'Bourgogne',
#      'offsetStart': 11153,
#      'offsetEnd': 11162,
#      'confidence_score': 0.4409,
#      'wikipediaExternalRef': 85451,
#      'wikidataId': 'Q1173',
#      'domains': ('Geography', 'Statistics')},
#     {'rawName': 'Champagné',
#      'offsetStart': 11177,
#      'offsetEnd': 11186,
#      'confidence_score': 0.7058,
#      'wikipediaExternalRef': 2202361,
#      'wikidataId': 'Q636699',
#      'domains': ('Geography',)},
#     {'rawName': 'Ratafia',
#      'offsetStart': 11321,
#      'offsetEnd': 11328,
#      'confidence_score': 0.7763,
#      'wikipediaExternalRef': 1037384,
#      'wikidataId': 'Q240728',
#      'domains': ('Agriculture',)},
#     {'rawName': 'Ratafia',
#      'offsetStart': 11364,
#      'offsetEnd': 11371,
#      'confidence_score': 0.7763,
#      'wikipediaExternalRef': 1037384,
#      'wikidataId': 'Q240728',
#      'domains': ('Agriculture',)},
#     {'rawName': 'GER',
#      'offsetStart': 12016,
#      'offsetEnd': 12019,
#      'confidence_score': 0.69,
#      'wikipediaExternalRef': 897091,
#      'wikidataId': 'Q249083',
#      'domains': ('Sociology', 'Astronomy', 'Computer_Science')},
#     {'rawName': 'GER',
#      'offsetStart': 13123,
#      'offsetEnd': 13126,
#      'confidence_score': 0.69,
#      'wikipediaExternalRef': 897091,
#      'wikidataId': 'Q249083',
#      'domains': ('Sociology', 'Astronomy', 'Computer_Science')},
#     {'rawName': 'OGER',
#      'offsetStart': 13158,
#      'offsetEnd': 13162,
#      'confidence_score': 0.4693,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'CIS',
#      'offsetStart': 13183,
#      'offsetEnd': 13186,
#      'confidence_score': 0.6692,
#      'wikipediaExternalRef': 36870,
#      'wikidataId': 'Q7779',
#      'domains': ('Administration',)},
#     {'rawName': 'ICAS',
#      'offsetStart': 13248,
#      'offsetEnd': 13252,
#      'confidence_score': 0.6576,
#      'wikipediaExternalRef': 1272451,
#      'wikidataId': 'Q6040071',
#      'domains': ('Commerce', 'Enterprise')},
#     {'rawName': 'ER',
#      'offsetStart': 13438,
#      'offsetEnd': 13440,
#      'confidence_score': 0.7096,
#      'wikipediaExternalRef': 177153,
#      'wikidataId': 'Q207375',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'OGER',
#      'offsetStart': 13503,
#      'offsetEnd': 13507,
#      'confidence_score': 0.4693,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'OGER',
#      'offsetStart': 13535,
#      'offsetEnd': 13539,
#      'confidence_score': 0.4693,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'Almanach',
#      'offsetStart': 14119,
#      'offsetEnd': 14127,
#      'confidence_score': 0.3897,
#      'wikipediaExternalRef': 192230,
#      'wikidataId': 'Q171341',
#      'domains': ('Pedagogy',)},
#     {'rawName': 'GER',
#      'offsetStart': 14241,
#      'offsetEnd': 14244,
#      'confidence_score': 0.666,
#      'wikipediaExternalRef': 897091,
#      'wikidataId': 'Q249083',
#      'domains': ('Sociology', 'Astronomy', 'Computer_Science')},
#     {'rawName': 'ER',
#      'offsetStart': 14319,
#      'offsetEnd': 14321,
#      'confidence_score': 0.6821,
#      'wikipediaExternalRef': 177153,
#      'wikidataId': 'Q207375',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'BER',
#      'offsetStart': 14673,
#      'offsetEnd': 14676,
#      'confidence_score': 0.6207,
#      'wikipediaExternalRef': 26971838,
#      'wikidataId': 'Q4986613',
#      'domains': ('Pedagogy',)},
#     {'rawName': 'DGER',
#      'offsetStart': 15285,
#      'offsetEnd': 15289,
#      'confidence_score': 0.6987,
#      'wikipediaExternalRef': 18560205,
#      'wikidataId': 'Q2348553',
#      'domains': ('Military',)},
#     {'rawName': 'Baguette',
#      'offsetStart': 15932,
#      'offsetEnd': 15940,
#      'confidence_score': 0.639,
#      'wikipediaExternalRef': 14967135,
#      'wikidataId': 'Q4842149',
#      'domains': ('Animals',)},
#     {'rawName': 'Mer',
#      'offsetStart': 16084,
#      'offsetEnd': 16087,
#      'confidence_score': 0.3837,
#      'wikipediaExternalRef': 34533583,
#      'wikidataId': 'Q3595671',
#      'domains': ('Electronics', 'Computer_Science')},
#     {'rawName': 'Terre',
#      'offsetStart': 16095,
#      'offsetEnd': 16100,
#      'confidence_score': 0.458,
#      'wikipediaExternalRef': 59780893,
#      'wikidataId': 'Q65117675',
#      'domains': ('Sociology',)},
#     {'rawName': 'Baguette',
#      'offsetStart': 16404,
#      'offsetEnd': 16412,
#      'confidence_score': 0.639,
#      'wikipediaExternalRef': 14967135,
#      'wikidataId': 'Q4842149',
#      'domains': ('Animals',)},
#     {'rawName': 'Baguette',
#      'offsetStart': 16725,
#      'offsetEnd': 16733,
#      'confidence_score': 0.639,
#      'wikipediaExternalRef': 14967135,
#      'wikidataId': 'Q4842149',
#      'domains': ('Animals',)},
#     {'rawName': 'Baguette',
#      'offsetStart': 16852,
#      'offsetEnd': 16860,
#      'confidence_score': 0.639,
#      'wikipediaExternalRef': 14967135,
#      'wikidataId': 'Q4842149',
#      'domains': ('Animals',)},
#     {'rawName': 'Vulcain',
#      'offsetStart': 16897,
#      'offsetEnd': 16904,
#      'confidence_score': 0.6637,
#      'wikipediaExternalRef': 6974287,
#      'wikidataId': 'Q44532',
#      'domains': ('Administration',
#       'Aviation',
#       'Transport',
#       'Vehicles',
#       'Energy',
#       'Mechanics')},
#     {'rawName': 'Mars',
#      'offsetStart': 17147,
#      'offsetEnd': 17151,
#      'confidence_score': 0.6438,
#      'wikipediaExternalRef': 14640471,
#      'wikidataId': 'Q111',
#      'domains': ('Astronomy',)},
#     {'rawName': 'Mari',
#      'offsetStart': 17365,
#      'offsetEnd': 17369,
#      'confidence_score': 0.4997,
#      'wikipediaExternalRef': 1022282,
#      'wikidataId': 'Q244762',
#      'domains': ('Sociology',)},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 17984,
#      'offsetEnd': 17993,
#      'confidence_score': 0.4541,
#      'wikipediaExternalRef': 57941671,
#      'wikidataId': 'Q56274326',
#      'domains': ('Electronics', 'Computer_Science', 'Sociology')},
#     {'rawName': 'Blondin',
#      'offsetStart': 18234,
#      'offsetEnd': 18241,
#      'confidence_score': 0.4669,
#      'wikipediaExternalRef': 1304527,
#      'wikidataId': 'Q860180',
#      'domains': ('Geology',)},
#     {'rawName': 'Rabat',
#      'offsetStart': 18244,
#      'offsetEnd': 18249,
#      'confidence_score': 0.7366,
#      'wikipediaExternalRef': 57400,
#      'wikidataId': 'Q3551',
#      'domains': ('Administration', 'Geology', 'Geography', 'Sociology')},
#     {'rawName': 'Rabat',
#      'offsetStart': 18293,
#      'offsetEnd': 18298,
#      'confidence_score': 0.7366,
#      'wikipediaExternalRef': 57400,
#      'wikidataId': 'Q3551',
#      'domains': ('Administration', 'Geology', 'Geography', 'Sociology')},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 18347,
#      'offsetEnd': 18356,
#      'confidence_score': 0.4541,
#      'wikipediaExternalRef': 57941671,
#      'wikidataId': 'Q56274326',
#      'domains': ('Electronics', 'Computer_Science', 'Sociology')},
#     {'rawName': 'Raba',
#      'offsetStart': 18704,
#      'offsetEnd': 18708,
#      'confidence_score': 0.525,
#      'wikipediaExternalRef': 4783411,
#      'wikidataId': 'Q615272',
#      'domains': ('Geology', 'Environment', 'Gas')},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 19404,
#      'offsetEnd': 19413,
#      'confidence_score': 0.4541,
#      'wikipediaExternalRef': 57941671,
#      'wikidataId': 'Q56274326',
#      'domains': ('Electronics', 'Computer_Science', 'Sociology')},
#     {'rawName': 'Virgo',
#      'offsetStart': 20918,
#      'offsetEnd': 20923,
#      'confidence_score': 0.6666,
#      'wikipediaExternalRef': 32407,
#      'wikidataId': 'Q8842',
#      'domains': ('Astronomy',)},
#     {'rawName': 'Pierrot',
#      'offsetStart': 21626,
#      'offsetEnd': 21633,
#      'confidence_score': 0.6436,
#      'wikipediaExternalRef': 51126,
#      'wikidataId': 'Q17309',
#      'domains': ('Biology', 'Psychiatry', 'Health')},
#     {'rawName': 'Abé',
#      'offsetStart': 21923,
#      'offsetEnd': 21926,
#      'confidence_score': 0.5705,
#      'wikipediaExternalRef': 725094,
#      'wikidataId': 'Q34833',
#      'domains': ('Astronomy', 'Geography', 'Sociology')},
#     {'rawName': 'Isabelle',
#      'offsetStart': 21939,
#      'offsetEnd': 21947,
#      'confidence_score': 0.3892,
#      'wikipediaExternalRef': 59409168,
#      'wikidataId': 'Q59220438',
#      'domains': ('Biology',)},
#     {'rawName': 'OGER',
#      'offsetStart': 24273,
#      'offsetEnd': 24277,
#      'confidence_score': 0.4762,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'Bassette',
#      'offsetStart': 24353,
#      'offsetEnd': 24361,
#      'confidence_score': 0.5197,
#      'wikipediaExternalRef': 98228,
#      'wikidataId': 'Q4868070',
#      'domains': ('Sociology',)},
#     {'rawName': 'Lansquenet',
#      'offsetStart': 24372,
#      'offsetEnd': 24382,
#      'confidence_score': 0.7277,
#      'wikipediaExternalRef': 98082,
#      'wikidataId': 'Q382713',
#      'domains': ('Sociology',)},
#     {'rawName': 'PIERROT',
#      'offsetStart': 24899,
#      'offsetEnd': 24906,
#      'confidence_score': 0.6097,
#      'wikipediaExternalRef': 51126,
#      'wikidataId': 'Q17309',
#      'domains': ('Biology', 'Psychiatry', 'Health')},
#     {'rawName': 'Mademoiselle',
#      'offsetStart': 24973,
#      'offsetEnd': 24985,
#      'confidence_score': 0.538,
#      'wikipediaExternalRef': 1698168,
#      'wikidataId': 'Q738294',
#      'domains': ('Artisanship',)},
#     {'rawName': 'GER',
#      'offsetStart': 26900,
#      'offsetEnd': 26903,
#      'confidence_score': 0.4661,
#      'wikipediaExternalRef': 897091,
#      'wikidataId': 'Q249083',
#      'domains': ('Sociology', 'Astronomy', 'Computer_Science')},
#     {'rawName': 'Baguette',
#      'offsetStart': 27060,
#      'offsetEnd': 27068,
#      'confidence_score': 0.639,
#      'wikipediaExternalRef': 14967135,
#      'wikidataId': 'Q4842149',
#      'domains': ('Animals',)},
#     {'rawName': 'MARINETTE',
#      'offsetStart': 27174,
#      'offsetEnd': 27183,
#      'confidence_score': 0.4221,
#      'wikipediaExternalRef': 139385,
#      'wikidataId': 'Q1013700',
#      'domains': ('Administration',)},
#     {'rawName': 'Roger',
#      'offsetStart': 28127,
#      'offsetEnd': 28132,
#      'confidence_score': 0.3754,
#      'wikipediaExternalRef': 987632,
#      'wikidataId': 'Q4925304',
#      'domains': ('Biology',)},
#     {'rawName': 'ISABELLE',
#      'offsetStart': 28482,
#      'offsetEnd': 28490,
#      'confidence_score': 0.717,
#      'wikipediaExternalRef': 483004,
#      'wikidataId': 'Q14706515',
#      'domains': ('Vehicles',
#       'Transport',
#       'Energy',
#       'Electricity',
#       'Electronics')},
#     {'rawName': 'M',
#      'offsetStart': 28744,
#      'offsetEnd': 28745,
#      'confidence_score': 0.374,
#      'wikipediaExternalRef': 255869,
#      'wikidataId': 'Q246154',
#      'domains': ('Administration',)},
#     {'rawName': 'Lyon',
#      'offsetStart': 30256,
#      'offsetEnd': 30260,
#      'confidence_score': 0.6708,
#      'wikipediaExternalRef': 8638634,
#      'wikidataId': 'Q456',
#      'domains': ('Geography', 'Environment', 'Gas', 'Geology', 'Sociology')},
#     {'rawName': 'Vulcain',
#      'offsetStart': 30450,
#      'offsetEnd': 30457,
#      'confidence_score': 0.6637,
#      'wikipediaExternalRef': 6974287,
#      'wikidataId': 'Q44532',
#      'domains': ('Administration',
#       'Aviation',
#       'Transport',
#       'Vehicles',
#       'Energy',
#       'Mechanics')},
#     {'rawName': 'Venus',
#      'offsetStart': 30518,
#      'offsetEnd': 30523,
#      'confidence_score': 0.6449,
#      'wikipediaExternalRef': 32745,
#      'wikidataId': 'Q313',
#      'domains': ('Astronomy',)},
#     {'rawName': 'Lyon',
#      'offsetStart': 30755,
#      'offsetEnd': 30759,
#      'confidence_score': 0.6708,
#      'wikipediaExternalRef': 8638634,
#      'wikidataId': 'Q456',
#      'domains': ('Geography', 'Environment', 'Gas', 'Geology', 'Sociology')},
#     {'rawName': 'Vulcain',
#      'offsetStart': 30951,
#      'offsetEnd': 30958,
#      'confidence_score': 0.6637,
#      'wikipediaExternalRef': 6974287,
#      'wikidataId': 'Q44532',
#      'domains': ('Administration',
#       'Aviation',
#       'Transport',
#       'Vehicles',
#       'Energy',
#       'Mechanics')},
#     {'rawName': 'Venus',
#      'offsetStart': 31019,
#      'offsetEnd': 31024,
#      'confidence_score': 0.6449,
#      'wikipediaExternalRef': 32745,
#      'wikidataId': 'Q313',
#      'domains': ('Astronomy',)})}, 'disambiguation_terms_service': {'software': 'entity-fishing',
#    'version': '0.0.6',
#    'date': '2025-01-10T16:49:39.063897Z',
#    'runtime': 30,
#    'nbest': False,
#    'shortText': "A' ROUEN EAN DUMESNIL ROGER IZABELLE THIBAUD LOCAS PIERROT Hrointin BRADAMANTE PASQUAREL Colombine OGER GER Roger Julep Roger Roger Seigneur Madame JER Bradamante ROGER BRADAMANTE ROGEA BRADAMANTE ROGER Belle Bradamante BRADAMANTE ROGER BRADAMANTE OGER BRADAMANTE GER BRADAMANTE ROGER BRADAMANTE ROGER Lansquenet BRADAMANTE ROGER Césars BRADAMANTE ROGER Coinedle BRADAMANTE ROGER BRADAMANTE ROGER ROGER BRADAMANTE RRADAMANTE OGER ROGER Méd Dles IBAD GER GER MARINETTTE GER MARINETTTE Almanach ER Maturine ER RINETTE Pierrot GER ER MARINETTTE GER ROGER OGER TZADELLE Morcellsrie OGER IZABELLE ROGER IZABELLE TLABELLE ROGER Montrant ROGER IZABELLE ROGEN IZABELLE ROGER Jambons de Mayence Artichaux Truffes Mortadelles Boulogne Bourgogne Champagné IZABELLE Ratafia ROGER Ratafia IZABELLE ROGER LE DRUIDE OGER GER LUCAS OGER GER LUCAS OGER CIS ICAS ER OGER L'UCAS OGER LUCAS OGER Almanach LUCAS GER LUCAS ER Poupone BER LE DRUIDE OGER OGER DGER COLOMBINE ROGER COLOMBINE ROGER Baguette Mer Terre Bagnette COLOMBINE ROGER Baguette ROGER Baguette ROGER Baguette Vulcain Mars Forgeron COLOMBINE OGER Mari COLOMBINE ROGER CmnDINE COLOMBINE ROGER COLOMBINE ÀOLOMAIIE ROGER COLOMBINE ROGER Blondin Rabat ROGER Rabat COLOMBINE ROGER Raba ULOMBINE ROGER Pasquarel Alueenle E ROGER COLOMBINE ASQUAREL ROGER Pozer ROGER Pasquarel ASQUAREL ROGER TE DRUIDE ROGER Virgo Cricorne ROGER COLOMBINE ROGER ROCANTIN Pierrot JERROT ROCANTIN JERROT Mtout ROCANTIN JERROT Abé Isabelle ROCANTIN OCANTIN F OCANTIN JERROT ROCANTIN JERROT ROCANTIN IFRROT JERROT ROCANTIN ROCANTIN ROGER ROCANTIN ROGER OCANTIN OGER Bassette Lansquenet Tuie ROCANTIN PIERROT Mademoiselle ROGER Paguette ROCANTIN ROCANTIN ROGER COLOMBINE Rocantin GER Baguette ROGER DRUIDE PASQUAREL COLOMBINE ISABELLE TIBAUD LUCAS MARINETTE LE DRUIDE LUCAS ZABELLE Roger OGER ISABELLE LUCAS M COLOMBINE PASQUAREL ROGER Pasquarel MARINETTTE TIBAUD COLOMBINE DRUIDE Msabille ROGER Lyon OGER Vulcain Venus ROGER Lyon OGER Vulcain Venus ROGER",
#    'language': {'lang': 'en', 'conf': 1.0},
#    'global_categories': ({'weight': 0.20959275104756112,
#      'source': 'wikipedia-en',
#      'category': 'Parts of speech',
#      'page_id': 869421},
#     {'weight': 0.20959275104756112,
#      'source': 'wikipedia-en',
#      'category': 'Operating signals',
#      'page_id': 55925524},
#     {'weight': 0.004459420235054495,
#      'source': 'wikipedia-en',
#      'category': 'Engerdal',
#      'page_id': 34785139},
#     {'weight': 0.20959275104756112,
#      'source': 'wikipedia-en',
#      'category': 'Amateur radio',
#      'page_id': 702878},
#     {'weight': 0.20959275104756112,
#      'source': 'wikipedia-en',
#      'category': 'Military communications',
#      'page_id': 1572524}),
#    'entities': ({'rawName': 'ROGER',
#      'offsetStart': 610,
#      'offsetEnd': 615,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'THIBAUD',
#      'offsetStart': 711,
#      'offsetEnd': 718,
#      'confidence_score': 0.1968,
#      'wikipediaExternalRef': 15267557,
#      'wikidataId': 'Q3556171',
#      'domains': ('Geography',)},
#     {'rawName': 'LOCAS',
#      'offsetStart': 755,
#      'offsetEnd': 760,
#      'confidence_score': 0.2919,
#      'wikipediaExternalRef': 2321604,
#      'wikidataId': 'Q7573440',
#      'domains': ('Administration', 'Sociology')},
#     {'rawName': 'OGER',
#      'offsetStart': 1060,
#      'offsetEnd': 1064,
#      'confidence_score': 0.3363,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'ROGER',
#      'offsetStart': 2581,
#      'offsetEnd': 2586,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 2892,
#      'offsetEnd': 2897,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 3318,
#      'offsetEnd': 3323,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'OGER',
#      'offsetStart': 3429,
#      'offsetEnd': 3433,
#      'confidence_score': 0.3363,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'ROGER',
#      'offsetStart': 4317,
#      'offsetEnd': 4322,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 4855,
#      'offsetEnd': 4860,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 5061,
#      'offsetEnd': 5066,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 5449,
#      'offsetEnd': 5454,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 5939,
#      'offsetEnd': 5944,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 6220,
#      'offsetEnd': 6225,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 6248,
#      'offsetEnd': 6253,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 6723,
#      'offsetEnd': 6728,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 8913,
#      'offsetEnd': 8918,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 9665,
#      'offsetEnd': 9670,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 9996,
#      'offsetEnd': 10001,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 10357,
#      'offsetEnd': 10362,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGEN',
#      'offsetStart': 10667,
#      'offsetEnd': 10672,
#      'confidence_score': 0.2288,
#      'wikipediaExternalRef': 4272656,
#      'wikidataId': 'Q1637472',
#      'domains': ('Astronomy', 'Nautical', 'Transport')},
#     {'rawName': 'ROGER',
#      'offsetStart': 10888,
#      'offsetEnd': 10893,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 11330,
#      'offsetEnd': 11335,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 11593,
#      'offsetEnd': 11598,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'OGER',
#      'offsetStart': 11850,
#      'offsetEnd': 11854,
#      'confidence_score': 0.3363,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'LUCAS',
#      'offsetStart': 12686,
#      'offsetEnd': 12691,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 44764997,
#      'wikidataId': 'Q25312731',
#      'domains': ('Telecommunication', 'Astronautics')},
#     {'rawName': 'OGER',
#      'offsetStart': 12773,
#      'offsetEnd': 12777,
#      'confidence_score': 0.3363,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'LUCAS',
#      'offsetStart': 13150,
#      'offsetEnd': 13155,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 44764997,
#      'wikidataId': 'Q25312731',
#      'domains': ('Telecommunication', 'Astronautics')},
#     {'rawName': 'LUCAS',
#      'offsetStart': 13542,
#      'offsetEnd': 13547,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 44764997,
#      'wikidataId': 'Q25312731',
#      'domains': ('Telecommunication', 'Astronautics')},
#     {'rawName': 'OGER',
#      'offsetStart': 13608,
#      'offsetEnd': 13612,
#      'confidence_score': 0.3363,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'LUCAS',
#      'offsetStart': 14138,
#      'offsetEnd': 14143,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 44764997,
#      'wikidataId': 'Q25312731',
#      'domains': ('Telecommunication', 'Astronautics')},
#     {'rawName': 'LUCAS',
#      'offsetStart': 14269,
#      'offsetEnd': 14274,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 44764997,
#      'wikidataId': 'Q25312731',
#      'domains': ('Telecommunication', 'Astronautics')},
#     {'rawName': 'OGER',
#      'offsetStart': 14918,
#      'offsetEnd': 14922,
#      'confidence_score': 0.3363,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'OGER',
#      'offsetStart': 15062,
#      'offsetEnd': 15066,
#      'confidence_score': 0.3363,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 15334,
#      'offsetEnd': 15343,
#      'confidence_score': 0.4269,
#      'wikipediaExternalRef': 662603,
#      'wikidataId': 'Q444127'},
#     {'rawName': 'ROGER',
#      'offsetStart': 15442,
#      'offsetEnd': 15447,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 15652,
#      'offsetEnd': 15661,
#      'confidence_score': 0.4269,
#      'wikipediaExternalRef': 662603,
#      'wikidataId': 'Q444127'},
#     {'rawName': 'ROGER',
#      'offsetStart': 15903,
#      'offsetEnd': 15908,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 16226,
#      'offsetEnd': 16235,
#      'confidence_score': 0.4269,
#      'wikipediaExternalRef': 662603,
#      'wikidataId': 'Q444127'},
#     {'rawName': 'ROGER',
#      'offsetStart': 16303,
#      'offsetEnd': 16308,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 16625,
#      'offsetEnd': 16630,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 16829,
#      'offsetEnd': 16834,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'OGER',
#      'offsetStart': 17283,
#      'offsetEnd': 17287,
#      'confidence_score': 0.3363,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 17491,
#      'offsetEnd': 17500,
#      'confidence_score': 0.4269,
#      'wikipediaExternalRef': 662603,
#      'wikidataId': 'Q444127'},
#     {'rawName': 'ROGER',
#      'offsetStart': 17531,
#      'offsetEnd': 17536,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 17615,
#      'offsetEnd': 17624,
#      'confidence_score': 0.4269,
#      'wikipediaExternalRef': 662603,
#      'wikidataId': 'Q444127'},
#     {'rawName': 'ROGER',
#      'offsetStart': 17648,
#      'offsetEnd': 17653,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 17674,
#      'offsetEnd': 17683,
#      'confidence_score': 0.4269,
#      'wikipediaExternalRef': 662603,
#      'wikidataId': 'Q444127'},
#     {'rawName': 'ROGER',
#      'offsetStart': 17927,
#      'offsetEnd': 17932,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 18125,
#      'offsetEnd': 18130,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 18257,
#      'offsetEnd': 18262,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 18438,
#      'offsetEnd': 18443,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 19260,
#      'offsetEnd': 19265,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 19360,
#      'offsetEnd': 19365,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 19514,
#      'offsetEnd': 19519,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 19762,
#      'offsetEnd': 19767,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 20400,
#      'offsetEnd': 20405,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 20865,
#      'offsetEnd': 20870,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 21072,
#      'offsetEnd': 21077,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 21154,
#      'offsetEnd': 21163,
#      'confidence_score': 0.4269,
#      'wikipediaExternalRef': 662603,
#      'wikidataId': 'Q444127'},
#     {'rawName': 'ROGER',
#      'offsetStart': 21219,
#      'offsetEnd': 21224,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 23868,
#      'offsetEnd': 23873,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 24077,
#      'offsetEnd': 24082,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 25126,
#      'offsetEnd': 25131,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'ROGER',
#      'offsetStart': 25997,
#      'offsetEnd': 26002,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 26469,
#      'offsetEnd': 26478,
#      'confidence_score': 0.4269,
#      'wikipediaExternalRef': 662603,
#      'wikidataId': 'Q444127'},
#     {'rawName': 'ROGER',
#      'offsetStart': 27095,
#      'offsetEnd': 27100,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'LUCAS',
#      'offsetStart': 27151,
#      'offsetEnd': 27156,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 44764997,
#      'wikidataId': 'Q25312731',
#      'domains': ('Telecommunication', 'Astronautics')},
#     {'rawName': 'LUCAS',
#      'offsetStart': 27941,
#      'offsetEnd': 27946,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 44764997,
#      'wikidataId': 'Q25312731',
#      'domains': ('Telecommunication', 'Astronautics')},
#     {'rawName': 'OGER',
#      'offsetStart': 28301,
#      'offsetEnd': 28305,
#      'confidence_score': 0.3363,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'LUCAS',
#      'offsetStart': 28652,
#      'offsetEnd': 28657,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 44764997,
#      'wikidataId': 'Q25312731',
#      'domains': ('Telecommunication', 'Astronautics')},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 28828,
#      'offsetEnd': 28837,
#      'confidence_score': 0.4269,
#      'wikipediaExternalRef': 662603,
#      'wikidataId': 'Q444127'},
#     {'rawName': 'ROGER',
#      'offsetStart': 29208,
#      'offsetEnd': 29213,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'COLOMBINE',
#      'offsetStart': 29938,
#      'offsetEnd': 29947,
#      'confidence_score': 0.4269,
#      'wikipediaExternalRef': 662603,
#      'wikidataId': 'Q444127'},
#     {'rawName': 'ROGER',
#      'offsetStart': 30176,
#      'offsetEnd': 30181,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'OGER',
#      'offsetStart': 30350,
#      'offsetEnd': 30354,
#      'confidence_score': 0.3363,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'ROGER',
#      'offsetStart': 30577,
#      'offsetEnd': 30582,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)},
#     {'rawName': 'OGER',
#      'offsetStart': 30851,
#      'offsetEnd': 30855,
#      'confidence_score': 0.3363,
#      'wikipediaExternalRef': 15898263,
#      'wikidataId': 'Q1228972',
#      'domains': ('Agriculture', 'Engineering', 'Biology')},
#     {'rawName': 'ROGER',
#      'offsetStart': 31078,
#      'offsetEnd': 31083,
#      'confidence_score': 0.3478,
#      'wikipediaExternalRef': 9590793,
#      'wikidataId': 'Q2918312',
#      'domains': ('Telecommunication',)})}},
#  ('._.',
#   'metadata',
#   None,
#   None): {'disambiguation_text_service': {'status_code': 200,
#    'reason': 'OK',
#    'ok': True,
#    'encoding': 'utf-8'}, 'disambiguation_terms_service': {'status_code': 200,
#    'reason': 'OK',
#    'ok': True,
#    'encoding': 'utf-8'}},
#  ('._.', 'kb_qid', 779, 786): 'Q2638650',
#  ('._.', 'url_wikidata', 779, 786): 'https://www.wikidata.org/wiki/Q2638650',
#  ('._.', 'wikipedia_page_ref', 779, 786): '2397503',
#  ('._.', 'nerd_score', 779, 786): 0.4001,
#  ('._.', 'kb_qid', 888, 897): 'Q444127',
#  ('._.', 'url_wikidata', 888, 897): 'https://www.wikidata.org/wiki/Q444127',
#  ('._.', 'wikipedia_page_ref', 888, 897): '662603',
#  ('._.', 'nerd_score', 888, 897): 0.4269,
#  ('._.', 'kb_qid', 1119, 1122): 'Q249083',
# ...
#  ('._.', 'url_wikidata', 5449, 5454): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 5449, 5454): '9590793',
#  ('._.', 'nerd_score', 5449, 5454): 0.3478,
#  ('._.', 'kb_qid', 5939, 5944): 'Q2918312',
#  ('._.', 'url_wikidata', 5939, 5944): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 5939, 5944): '9590793',
#  ('._.', 'nerd_score', 5939, 5944): 0.3478,
#  ('._.', 'kb_qid', 6220, 6225): 'Q2918312',
#  ('._.', 'url_wikidata', 6220, 6225): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 6220, 6225): '9590793',
#  ('._.', 'nerd_score', 6220, 6225): 0.3478,
#  ('._.', 'kb_qid', 6248, 6253): 'Q2918312',
#  ('._.', 'url_wikidata', 6248, 6253): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 6248, 6253): '9590793',
#  ('._.', 'nerd_score', 6248, 6253): 0.3478,
#  ('._.', 'kb_qid', 6723, 6728): 'Q2918312',
#  ('._.', 'url_wikidata', 6723, 6728): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 6723, 6728): '9590793',
#  ('._.', 'nerd_score', 6723, 6728): 0.3478,
#  ('._.', 'kb_qid', 8913, 8918): 'Q2918312',
#  ('._.', 'url_wikidata', 8913, 8918): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 8913, 8918): '9590793',
#  ('._.', 'nerd_score', 8913, 8918): 0.3478,
#  ('._.', 'kb_qid', 9665, 9670): 'Q2918312',
#  ('._.', 'url_wikidata', 9665, 9670): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 9665, 9670): '9590793',
#  ('._.', 'nerd_score', 9665, 9670): 0.3478,
#  ('._.', 'kb_qid', 9996, 10001): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   9996,
#   10001): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 9996, 10001): '9590793',
#  ('._.', 'nerd_score', 9996, 10001): 0.3478,
#  ('._.', 'kb_qid', 10357, 10362): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   10357,
#   10362): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 10357, 10362): '9590793',
#  ('._.', 'nerd_score', 10357, 10362): 0.3478,
#  ('._.', 'kb_qid', 10667, 10672): 'Q1637472',
#  ('._.',
#   'url_wikidata',
#   10667,
#   10672): 'https://www.wikidata.org/wiki/Q1637472',
#  ('._.', 'wikipedia_page_ref', 10667, 10672): '4272656',
#  ('._.', 'nerd_score', 10667, 10672): 0.2288,
#  ('._.', 'kb_qid', 10888, 10893): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   10888,
#   10893): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 10888, 10893): '9590793',
#  ('._.', 'nerd_score', 10888, 10893): 0.3478,
#  ('._.', 'kb_qid', 11330, 11335): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   11330,
#   11335): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 11330, 11335): '9590793',
#  ('._.', 'nerd_score', 11330, 11335): 0.3478,
#  ('._.', 'kb_qid', 11593, 11598): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   11593,
#   11598): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 11593, 11598): '9590793',
#  ('._.', 'nerd_score', 11593, 11598): 0.3478,
#  ('._.', 'kb_qid', 11850, 11854): 'Q1228972',
#  ('._.',
#   'url_wikidata',
#   11850,
#   11854): 'https://www.wikidata.org/wiki/Q1228972',
#  ('._.', 'wikipedia_page_ref', 11850, 11854): '15898263',
#  ('._.', 'nerd_score', 11850, 11854): 0.3363,
#  ('._.', 'kb_qid', 12686, 12691): 'Q25312731',
#  ('._.',
#   'url_wikidata',
#   12686,
#   12691): 'https://www.wikidata.org/wiki/Q25312731',
#  ('._.', 'wikipedia_page_ref', 12686, 12691): '44764997',
#  ('._.', 'nerd_score', 12686, 12691): 0.3478,
#  ('._.', 'kb_qid', 12773, 12777): 'Q1228972',
#  ('._.',
#   'url_wikidata',
#   12773,
#   12777): 'https://www.wikidata.org/wiki/Q1228972',
#  ('._.', 'wikipedia_page_ref', 12773, 12777): '15898263',
#  ('._.', 'nerd_score', 12773, 12777): 0.3363,
#  ('._.', 'kb_qid', 13150, 13155): 'Q25312731',
#  ('._.',
#   'url_wikidata',
#   13150,
#   13155): 'https://www.wikidata.org/wiki/Q25312731',
#  ('._.', 'wikipedia_page_ref', 13150, 13155): '44764997',
#  ('._.', 'nerd_score', 13150, 13155): 0.3478,
#  ('._.', 'kb_qid', 13542, 13547): 'Q25312731',
#  ('._.',
#   'url_wikidata',
#   13542,
#   13547): 'https://www.wikidata.org/wiki/Q25312731',
#  ('._.', 'wikipedia_page_ref', 13542, 13547): '44764997',
#  ('._.', 'nerd_score', 13542, 13547): 0.3478,
#  ('._.', 'kb_qid', 13608, 13612): 'Q1228972',
#  ('._.',
#   'url_wikidata',
#   13608,
#   13612): 'https://www.wikidata.org/wiki/Q1228972',
#  ('._.', 'wikipedia_page_ref', 13608, 13612): '15898263',
#  ('._.', 'nerd_score', 13608, 13612): 0.3363,
#  ('._.', 'kb_qid', 14138, 14143): 'Q25312731',
#  ('._.',
#   'url_wikidata',
#   14138,
#   14143): 'https://www.wikidata.org/wiki/Q25312731',
#  ('._.', 'wikipedia_page_ref', 14138, 14143): '44764997',
#  ('._.', 'nerd_score', 14138, 14143): 0.3478,
#  ('._.', 'kb_qid', 14269, 14274): 'Q25312731',
#  ('._.',
#   'url_wikidata',
#   14269,
#   14274): 'https://www.wikidata.org/wiki/Q25312731',
#  ('._.', 'wikipedia_page_ref', 14269, 14274): '44764997',
#  ('._.', 'nerd_score', 14269, 14274): 0.3478,
#  ('._.', 'kb_qid', 14918, 14922): 'Q1228972',
#  ('._.',
#   'url_wikidata',
#   14918,
#   14922): 'https://www.wikidata.org/wiki/Q1228972',
#  ('._.', 'wikipedia_page_ref', 14918, 14922): '15898263',
#  ('._.', 'nerd_score', 14918, 14922): 0.3363,
#  ('._.', 'kb_qid', 15062, 15066): 'Q1228972',
#  ('._.',
#   'url_wikidata',
#   15062,
#   15066): 'https://www.wikidata.org/wiki/Q1228972',
#  ('._.', 'wikipedia_page_ref', 15062, 15066): '15898263',
#  ('._.', 'nerd_score', 15062, 15066): 0.3363,
#  ('._.', 'kb_qid', 15334, 15343): 'Q444127',
#  ('._.',
#   'url_wikidata',
#   15334,
#   15343): 'https://www.wikidata.org/wiki/Q444127',
#  ('._.', 'wikipedia_page_ref', 15334, 15343): '662603',
#  ('._.', 'nerd_score', 15334, 15343): 0.4269,
#  ('._.', 'kb_qid', 15442, 15447): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   15442,
#   15447): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 15442, 15447): '9590793',
#  ('._.', 'nerd_score', 15442, 15447): 0.3478,
#  ('._.', 'kb_qid', 15652, 15661): 'Q444127',
#  ('._.',
#   'url_wikidata',
#   15652,
#   15661): 'https://www.wikidata.org/wiki/Q444127',
#  ('._.', 'wikipedia_page_ref', 15652, 15661): '662603',
#  ('._.', 'nerd_score', 15652, 15661): 0.4269,
#  ('._.', 'kb_qid', 15903, 15908): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   15903,
#   15908): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 15903, 15908): '9590793',
#  ('._.', 'nerd_score', 15903, 15908): 0.3478,
#  ('._.', 'kb_qid', 16226, 16235): 'Q444127',
#  ('._.',
#   'url_wikidata',
#   16226,
#   16235): 'https://www.wikidata.org/wiki/Q444127',
#  ('._.', 'wikipedia_page_ref', 16226, 16235): '662603',
#  ('._.', 'nerd_score', 16226, 16235): 0.4269,
#  ('._.', 'kb_qid', 16303, 16308): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   16303,
#   16308): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 16303, 16308): '9590793',
#  ('._.', 'nerd_score', 16303, 16308): 0.3478,
#  ('._.', 'kb_qid', 16625, 16630): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   16625,
#   16630): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 16625, 16630): '9590793',
#  ('._.', 'nerd_score', 16625, 16630): 0.3478,
#  ('._.', 'kb_qid', 16829, 16834): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   16829,
#   16834): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 16829, 16834): '9590793',
#  ('._.', 'nerd_score', 16829, 16834): 0.3478,
#  ('._.', 'kb_qid', 17283, 17287): 'Q1228972',
#  ('._.',
#   'url_wikidata',
#   17283,
#   17287): 'https://www.wikidata.org/wiki/Q1228972',
#  ('._.', 'wikipedia_page_ref', 17283, 17287): '15898263',
#  ('._.', 'nerd_score', 17283, 17287): 0.3363,
#  ('._.', 'kb_qid', 17491, 17500): 'Q444127',
#  ('._.',
#   'url_wikidata',
#   17491,
#   17500): 'https://www.wikidata.org/wiki/Q444127',
#  ('._.', 'wikipedia_page_ref', 17491, 17500): '662603',
#  ('._.', 'nerd_score', 17491, 17500): 0.4269,
#  ('._.', 'kb_qid', 17531, 17536): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   17531,
#   17536): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 17531, 17536): '9590793',
#  ('._.', 'nerd_score', 17531, 17536): 0.3478,
#  ('._.', 'kb_qid', 17615, 17624): 'Q444127',
#  ('._.',
#   'url_wikidata',
#   17615,
#   17624): 'https://www.wikidata.org/wiki/Q444127',
#  ('._.', 'wikipedia_page_ref', 17615, 17624): '662603',
#  ('._.', 'nerd_score', 17615, 17624): 0.4269,
#  ('._.', 'kb_qid', 17648, 17653): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   17648,
#   17653): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 17648, 17653): '9590793',
#  ('._.', 'nerd_score', 17648, 17653): 0.3478,
#  ('._.', 'kb_qid', 17674, 17683): 'Q444127',
#  ('._.',
#   'url_wikidata',
#   17674,
#   17683): 'https://www.wikidata.org/wiki/Q444127',
#  ('._.', 'wikipedia_page_ref', 17674, 17683): '662603',
#  ('._.', 'nerd_score', 17674, 17683): 0.4269,
#  ('._.', 'kb_qid', 17927, 17932): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   17927,
#   17932): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 17927, 17932): '9590793',
#  ('._.', 'nerd_score', 17927, 17932): 0.3478,
#  ('._.', 'kb_qid', 18125, 18130): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   18125,
#   18130): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 18125, 18130): '9590793',
#  ('._.', 'nerd_score', 18125, 18130): 0.3478,
#  ('._.', 'kb_qid', 18257, 18262): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   18257,
#   18262): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 18257, 18262): '9590793',
#  ('._.', 'nerd_score', 18257, 18262): 0.3478,
#  ('._.', 'kb_qid', 18438, 18443): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   18438,
#   18443): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 18438, 18443): '9590793',
#  ('._.', 'nerd_score', 18438, 18443): 0.3478,
#  ('._.', 'kb_qid', 19260, 19265): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   19260,
#   19265): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 19260, 19265): '9590793',
#  ('._.', 'nerd_score', 19260, 19265): 0.3478,
#  ('._.', 'kb_qid', 19360, 19365): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   19360,
#   19365): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 19360, 19365): '9590793',
#  ('._.', 'nerd_score', 19360, 19365): 0.3478,
#  ('._.', 'kb_qid', 19514, 19519): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   19514,
#   19519): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 19514, 19519): '9590793',
#  ('._.', 'nerd_score', 19514, 19519): 0.3478,
#  ('._.', 'kb_qid', 19762, 19767): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   19762,
#   19767): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 19762, 19767): '9590793',
#  ('._.', 'nerd_score', 19762, 19767): 0.3478,
#  ('._.', 'kb_qid', 20400, 20405): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   20400,
#   20405): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 20400, 20405): '9590793',
#  ('._.', 'nerd_score', 20400, 20405): 0.3478,
#  ('._.', 'kb_qid', 20865, 20870): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   20865,
#   20870): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 20865, 20870): '9590793',
#  ('._.', 'nerd_score', 20865, 20870): 0.3478,
#  ('._.', 'kb_qid', 21072, 21077): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   21072,
#   21077): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 21072, 21077): '9590793',
#  ('._.', 'nerd_score', 21072, 21077): 0.3478,
#  ('._.', 'kb_qid', 21154, 21163): 'Q444127',
#  ('._.',
#   'url_wikidata',
#   21154,
#   21163): 'https://www.wikidata.org/wiki/Q444127',
#  ('._.', 'wikipedia_page_ref', 21154, 21163): '662603',
#  ('._.', 'nerd_score', 21154, 21163): 0.4269,
#  ('._.', 'kb_qid', 21219, 21224): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   21219,
#   21224): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 21219, 21224): '9590793',
#  ('._.', 'nerd_score', 21219, 21224): 0.3478,
#  ('._.', 'kb_qid', 23868, 23873): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   23868,
#   23873): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 23868, 23873): '9590793',
#  ('._.', 'nerd_score', 23868, 23873): 0.3478,
#  ('._.', 'kb_qid', 24077, 24082): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   24077,
#   24082): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 24077, 24082): '9590793',
#  ('._.', 'nerd_score', 24077, 24082): 0.3478,
#  ('._.', 'kb_qid', 25126, 25131): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   25126,
#   25131): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 25126, 25131): '9590793',
#  ('._.', 'nerd_score', 25126, 25131): 0.3478,
#  ('._.', 'kb_qid', 25997, 26002): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   25997,
#   26002): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 25997, 26002): '9590793',
#  ('._.', 'nerd_score', 25997, 26002): 0.3478,
#  ('._.', 'kb_qid', 26469, 26478): 'Q444127',
#  ('._.',
#   'url_wikidata',
#   26469,
#   26478): 'https://www.wikidata.org/wiki/Q444127',
#  ('._.', 'wikipedia_page_ref', 26469, 26478): '662603',
#  ('._.', 'nerd_score', 26469, 26478): 0.4269,
#  ('._.', 'kb_qid', 27095, 27100): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   27095,
#   27100): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 27095, 27100): '9590793',
#  ('._.', 'nerd_score', 27095, 27100): 0.3478,
#  ('._.', 'kb_qid', 27151, 27156): 'Q25312731',
#  ('._.',
#   'url_wikidata',
#   27151,
#   27156): 'https://www.wikidata.org/wiki/Q25312731',
#  ('._.', 'wikipedia_page_ref', 27151, 27156): '44764997',
#  ('._.', 'nerd_score', 27151, 27156): 0.3478,
#  ('._.', 'kb_qid', 27941, 27946): 'Q25312731',
#  ('._.',
#   'url_wikidata',
#   27941,
#   27946): 'https://www.wikidata.org/wiki/Q25312731',
#  ('._.', 'wikipedia_page_ref', 27941, 27946): '44764997',
#  ('._.', 'nerd_score', 27941, 27946): 0.3478,
#  ('._.', 'kb_qid', 28301, 28305): 'Q1228972',
#  ('._.',
#   'url_wikidata',
#   28301,
#   28305): 'https://www.wikidata.org/wiki/Q1228972',
#  ('._.', 'wikipedia_page_ref', 28301, 28305): '15898263',
#  ('._.', 'nerd_score', 28301, 28305): 0.3363,
#  ('._.', 'kb_qid', 28652, 28657): 'Q25312731',
#  ('._.',
#   'url_wikidata',
#   28652,
#   28657): 'https://www.wikidata.org/wiki/Q25312731',
#  ('._.', 'wikipedia_page_ref', 28652, 28657): '44764997',
#  ('._.', 'nerd_score', 28652, 28657): 0.3478,
#  ('._.', 'kb_qid', 28828, 28837): 'Q444127',
#  ('._.',
#   'url_wikidata',
#   28828,
#   28837): 'https://www.wikidata.org/wiki/Q444127',
#  ('._.', 'wikipedia_page_ref', 28828, 28837): '662603',
#  ('._.', 'nerd_score', 28828, 28837): 0.4269,
#  ('._.', 'kb_qid', 29208, 29213): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   29208,
#   29213): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 29208, 29213): '9590793',
#  ('._.', 'nerd_score', 29208, 29213): 0.3478,
#  ('._.', 'kb_qid', 29938, 29947): 'Q444127',
#  ('._.',
#   'url_wikidata',
#   29938,
#   29947): 'https://www.wikidata.org/wiki/Q444127',
#  ('._.', 'wikipedia_page_ref', 29938, 29947): '662603',
#  ('._.', 'nerd_score', 29938, 29947): 0.4269,
#  ('._.', 'kb_qid', 30176, 30181): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   30176,
#   30181): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 30176, 30181): '9590793',
#  ('._.', 'nerd_score', 30176, 30181): 0.3478,
#  ('._.', 'kb_qid', 30350, 30354): 'Q1228972',
#  ('._.',
#   'url_wikidata',
#   30350,
#   30354): 'https://www.wikidata.org/wiki/Q1228972',
#  ('._.', 'wikipedia_page_ref', 30350, 30354): '15898263',
#  ('._.', 'nerd_score', 30350, 30354): 0.3363,
#  ('._.', 'kb_qid', 30577, 30582): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   30577,
#   30582): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 30577, 30582): '9590793',
#  ('._.', 'nerd_score', 30577, 30582): 0.3478,
#  ('._.', 'kb_qid', 30851, 30855): 'Q1228972',
#  ('._.',
#   'url_wikidata',
#   30851,
#   30855): 'https://www.wikidata.org/wiki/Q1228972',
#  ('._.', 'wikipedia_page_ref', 30851, 30855): '15898263',
#  ('._.', 'nerd_score', 30851, 30855): 0.3363,
#  ('._.', 'kb_qid', 31078, 31083): 'Q2918312',
#  ('._.',
#   'url_wikidata',
#   31078,
#   31083): 'https://www.wikidata.org/wiki/Q2918312',
#  ('._.', 'wikipedia_page_ref', 31078, 31083): '9590793',
#  ('._.', 'nerd_score', 31078, 31083): 0.3478}

# %% [markdown]
# ## Pre-generate document summaries

# %%
# the summary should contain:
# document metadata: author, title, publication date
# top 5 person mentions
# top 5 place mentions
# most salient person entity + top 5 sentences
# most salient place entity + top 5 sentences
def build_JSON_document_summary(spacy_doc):
    sass = SalientSentenceSelector(spacy_doc)

    # extract the top 5 sentences for the most frequent geographical place in the document
    # this entity context made of the k sentences can then be fed to an LLM
    top_place, place_rel_sentences = sass.select(top_k_sentences=5, entity_type='place')

    # extract the top 5 sentences for the most frequent person in the document
    # this entity context made of the k sentences can then be fed to an LLM
    top_person, person_rel_sentences = sass.select(top_k_sentences=5, entity_type='person')

    top_5_persons = sorted(
        list(sass.person_entities.values()),
        key=operator.attrgetter('mention_frequency'),
        reverse=True
    )[:5]

    top_5_places = sorted(
        list(sass.place_entities.values()),
        key=operator.attrgetter('mention_frequency'),
        reverse=True
    )[:5]



    summary = {
        "metadata": {
            "author": spacy_doc.user_data['author'],
            "title": spacy_doc.user_data['title'],
            "publication_date": spacy_doc.user_data['publication_date'],
            "document_id": spacy_doc.user_data['filename'].split('.')[0]
        },
        "context": {
            "people": {
                "top_1_person": {
                    "entity": {
                        "label": top_person.unique_surface_forms[0],
                        "frequency": top_place.mention_frequency
                    },
                    "related_sentences": [str(sent) for sent in person_rel_sentences]
                },
                "top_5_persons": [e.unique_surface_forms[0] for e in top_5_persons]
            },
            "places":{
                "top_1_place": {
                    "entity": {
                        "label": top_place.unique_surface_forms[0],
                        "frequency": top_place.mention_frequency
                    },
                    "related_sentences": [str(sent) for sent in place_rel_sentences]
                },
                "top_5_places": [e.unique_surface_forms[0] for e in top_5_places]
            }
        }
    }
    return summary

# %%
doc_summary = build_JSON_document_summary(sample_doc)
# Out:
# Document btv1b86221195.tar.gz.tei_segmented_ner.xml contains 353 PER entities; 199 linked and 154 non-linked
# Document btv1b86221195.tar.gz.tei_segmented_ner.xml contains 37 PER unique entities
# Document btv1b86221195.tar.gz.tei_segmented_ner.xml contains 19 LOC entities; 9 linked and 10 non-linked
# Document btv1b86221195.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities

# %%
print(json.dumps(doc_summary, indent=2, ensure_ascii=False))
# Out:
# {
#   "metadata": {
#     "author": "Rotrou, Jean de",
#     "title": "\"Dom Bernard de Cabrère, tragi-comédie de Rotrou [avec une \"\"Élégie\"\" de l'auteur à Mazarin]\"",
#     "publication_date": "1648",
#     "document_id": "btv1b86221195"
#   },
#   "context": {
#     "people": {
#       "top_1_person": {
#         "entity": {
#           "label": "LOPE",
#           "frequency": 6
#         },
#         "related_sentences": [
#           "D. BERNARD embrassant D \nLope\n DLût au ciel, cher de Lune, et ainsi le dis sans T feinte, Que le sort qui vous livre toujours si rude atteinte, Et contre qui pour vous, touts mes souhaits sont vains, Suivist son inconstance, et nous changeast de mains La disgrâce du Roi, me serait moins sensible, Que le mépris qu'il fait de ce bras invincible;",
#           "Et nous faire tribut de votre liberté: D. \nLOPE\n Il paraît par l'acçuil que m'a fait Violante, Que cette qualité me serait messeante, Et l'on redoute peu la rigueur d'un Amant, Anon ne daigne nonoreru un tegaru seulement. \nDOROTHÉE\n Qui manque un rendez-vous, fait bien voir qu'il néglige Les plus chères faveurs dontvne Amante oblige.",
#           "D. \nLOPE\n NFIN, cher Lazarille, un plut heureux Génie MN Nous va, de nos destins, forcer la tyrannie, Et ce bras l'aura mise au rang des ennemis, Qu'au joug de cet État ses exploits ont sousmis.",
#           "Au reste cette amour tendant à l'hyménée, Jugez de la grandeur qui vous est destinée, \nM\n D. \nLOPE\n Puis-je si malheureux n'avoir pas pour suspect, D'un astre si malin ce favorable aspect? \n",
#           "D. \nLOPE\n Quand l'appareil fut prêt, et que de vos vaisseaux Dom Bernard eut couvert l'humide sein des eaux, Les vents en même instant, furent sans violence, Et volontairement s'imposèrent silence;"
#         ]
#       },
#       "top_5_entities": [
#         "LOPE",
#         "Leonor",
#         "Dom Bernard",
#         "D",
#         "DOROTHÉE"
#       ]
#     },
#     "places": {
#       "top_1_place": {
#         "entity": {
#           "label": "Paris",
#           "frequency": 6
#         },
#         "related_sentences": [
#           "Il est permis à ANTOINE DE SOMAUILLE, Marchand Libraire à Paris, d'imprimer ou faire imprimer une Comédie intitulée, Dom Bernard de Cabre, et ce durant le temps et espace de cinq ans, à compter du jour que ledit Livre sera achevé d'imprimer.",
#           "Il est permis à ANTOINE DE SOMAUILLE, Marchand Libraire à Paris, d'imprimer ou faire imprimer une Comédie intitulée, Dom Bernard de Cabre, et ce durant le temps et espace de cinq ans, à compter du jour que ledit Livre sera achevé d'imprimer.",
#           "Et ledit de Sommauille a associé audit Privilège Toussaint Quinet, aussi Marchand Libraire à Paris, suivant l'accord fait entr'eux.",
#           "Et ledit de Sommauille a associé audit Privilège Toussaint Quinet, aussi Marchand Libraire à Paris, suivant l'accord fait entr'eux.",
#           "Grâce et Privilège du Roi, donné à Paris le 11."
#         ]
#       },
#       "top_5_entities": [
#         "Paris",
#         "Navarre",
#         "Saragosse"
#       ]
#     }
#   }
# }

# %%
import os

# create a code block that does the following:
# 1) it iterates over document in `spacy_docs`
# 2) for each document, it builds a JSON summary using the `build_JSON_document_summary` function
# 3) it writes the JSON summary to a file in the `data/summaries` directory (if it does not exist, create it);  
# Ensure the summaries directory exists
os.makedirs('data/summaries', exist_ok=True)

# Iterate over documents in spacy_docs
for i, spacy_doc in enumerate(spacy_docs):
    try:
        # Build JSON summary
        doc_summary = build_JSON_document_summary(spacy_doc)
        
        # Define the file path
        file_path = f"data/summaries/{doc_summary['metadata']['document_id']}_summary.json"
        
        # Write the JSON summary to a file
        with open(file_path, 'w', encoding='utf-8') as f:
            json.dump(doc_summary, f, indent=2, ensure_ascii=False)
    except Exception as e:
        print(f"Error processing document {i}: {e}")
# Out:
# Document bpt6k1090127n.tar.gz.tei_segmented_ner.xml contains 268 PER entities; 73 linked and 195 non-linked
# Document bpt6k1090127n.tar.gz.tei_segmented_ner.xml contains 37 PER unique entities
# Document bpt6k1090127n.tar.gz.tei_segmented_ner.xml contains 46 LOC entities; 24 linked and 22 non-linked
# Document bpt6k1090127n.tar.gz.tei_segmented_ner.xml contains 11 LOC unique entities
# Document bpt6k5626255h.tar.gz.tei_segmented_ner.xml contains 364 PER entities; 150 linked and 214 non-linked
# Document bpt6k5626255h.tar.gz.tei_segmented_ner.xml contains 37 PER unique entities
# Document bpt6k5626255h.tar.gz.tei_segmented_ner.xml contains 76 LOC entities; 68 linked and 8 non-linked
# Document bpt6k5626255h.tar.gz.tei_segmented_ner.xml contains 11 LOC unique entities
# Document bpt6k1280401n.tar.gz.tei_segmented_ner.xml contains 257 PER entities; 75 linked and 182 non-linked
# Document bpt6k1280401n.tar.gz.tei_segmented_ner.xml contains 32 PER unique entities
# Document bpt6k1280401n.tar.gz.tei_segmented_ner.xml contains 13 LOC entities; 12 linked and 1 non-linked
# Document bpt6k1280401n.tar.gz.tei_segmented_ner.xml contains 2 LOC unique entities
# Document bpt6k852913n.tar.gz.tei_segmented_ner.xml contains 209 PER entities; 84 linked and 125 non-linked
# Document bpt6k852913n.tar.gz.tei_segmented_ner.xml contains 14 PER unique entities
# Document bpt6k852913n.tar.gz.tei_segmented_ner.xml contains 6 LOC entities; 5 linked and 1 non-linked
# Document bpt6k852913n.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k5738753j.tar.gz.tei_segmented_ner.xml contains 349 PER entities; 280 linked and 69 non-linked
# Document bpt6k5738753j.tar.gz.tei_segmented_ner.xml contains 37 PER unique entities
# Document bpt6k5738753j.tar.gz.tei_segmented_ner.xml contains 23 LOC entities; 16 linked and 7 non-linked
# Document bpt6k5738753j.tar.gz.tei_segmented_ner.xml contains 7 LOC unique entities
# Document bpt6k8568894.tar.gz.tei_segmented_ner.xml contains 240 PER entities; 57 linked and 183 non-linked
# Document bpt6k8568894.tar.gz.tei_segmented_ner.xml contains 22 PER unique entities
# Document bpt6k8568894.tar.gz.tei_segmented_ner.xml contains 4 LOC entities; 4 linked and 0 non-linked
# Document bpt6k8568894.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k57899298.tar.gz.tei_segmented_ner.xml contains 283 PER entities; 83 linked and 200 non-linked
# Document bpt6k57899298.tar.gz.tei_segmented_ner.xml contains 23 PER unique entities
# Document bpt6k57899298.tar.gz.tei_segmented_ner.xml contains 28 LOC entities; 24 linked and 4 non-linked
# Document bpt6k57899298.tar.gz.tei_segmented_ner.xml contains 9 LOC unique entities
# Document bpt6k63632073.tar.gz.tei_segmented_ner.xml contains 204 PER entities; 150 linked and 54 non-linked
# Document bpt6k63632073.tar.gz.tei_segmented_ner.xml contains 34 PER unique entities
# Document bpt6k63632073.tar.gz.tei_segmented_ner.xml contains 16 LOC entities; 3 linked and 13 non-linked
# Document bpt6k63632073.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k57347539.tar.gz.tei_segmented_ner.xml contains 107 PER entities; 56 linked and 51 non-linked
# Document bpt6k57347539.tar.gz.tei_segmented_ner.xml contains 40 PER unique entities
# Document bpt6k57347539.tar.gz.tei_segmented_ner.xml contains 82 LOC entities; 62 linked and 20 non-linked
# Document bpt6k57347539.tar.gz.tei_segmented_ner.xml contains 45 LOC unique entities
# Document bpt6k1090193n.tar.gz.tei_segmented_ner.xml contains 130 PER entities; 68 linked and 62 non-linked
# Document bpt6k1090193n.tar.gz.tei_segmented_ner.xml contains 33 PER unique entities
# Document bpt6k1090193n.tar.gz.tei_segmented_ner.xml contains 9 LOC entities; 6 linked and 3 non-linked
# Document bpt6k1090193n.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k1280569k.tar.gz.tei_segmented_ner.xml contains 612 PER entities; 319 linked and 293 non-linked
# Document bpt6k1280569k.tar.gz.tei_segmented_ner.xml contains 48 PER unique entities
# Document bpt6k1280569k.tar.gz.tei_segmented_ner.xml contains 16 LOC entities; 11 linked and 5 non-linked
# Document bpt6k1280569k.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k56197532.tar.gz.tei_segmented_ner.xml contains 378 PER entities; 126 linked and 252 non-linked
# Document bpt6k56197532.tar.gz.tei_segmented_ner.xml contains 56 PER unique entities
# Document bpt6k56197532.tar.gz.tei_segmented_ner.xml contains 22 LOC entities; 12 linked and 10 non-linked
# Document bpt6k56197532.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k12804022.tar.gz.tei_segmented_ner.xml contains 737 PER entities; 173 linked and 564 non-linked
# Document bpt6k12804022.tar.gz.tei_segmented_ner.xml contains 44 PER unique entities
# Document bpt6k12804022.tar.gz.tei_segmented_ner.xml contains 9 LOC entities; 8 linked and 1 non-linked
# Document bpt6k12804022.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k6340762j.tar.gz.tei_segmented_ner.xml contains 163 PER entities; 49 linked and 114 non-linked
# Document bpt6k6340762j.tar.gz.tei_segmented_ner.xml contains 29 PER unique entities
# Document bpt6k6340762j.tar.gz.tei_segmented_ner.xml contains 18 LOC entities; 16 linked and 2 non-linked
# Document bpt6k6340762j.tar.gz.tei_segmented_ner.xml contains 14 LOC unique entities
# Document bpt6k1090150w.tar.gz.tei_segmented_ner.xml contains 313 PER entities; 84 linked and 229 non-linked
# Document bpt6k1090150w.tar.gz.tei_segmented_ner.xml contains 13 PER unique entities
# Document bpt6k1090150w.tar.gz.tei_segmented_ner.xml contains 8 LOC entities; 5 linked and 3 non-linked
# Document bpt6k1090150w.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k62614839.tar.gz.tei_segmented_ner.xml contains 353 PER entities; 74 linked and 279 non-linked
# Document bpt6k62614839.tar.gz.tei_segmented_ner.xml contains 17 PER unique entities
# Document bpt6k62614839.tar.gz.tei_segmented_ner.xml contains 9 LOC entities; 7 linked and 2 non-linked
# Document bpt6k62614839.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k1521653f.tar.gz.tei_segmented_ner.xml contains 530 PER entities; 345 linked and 185 non-linked
# Document bpt6k1521653f.tar.gz.tei_segmented_ner.xml contains 82 PER unique entities
# Document bpt6k1521653f.tar.gz.tei_segmented_ner.xml contains 23 LOC entities; 8 linked and 15 non-linked
# Document bpt6k1521653f.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k1090035v.tar.gz.tei_segmented_ner.xml contains 1358 PER entities; 456 linked and 902 non-linked
# Document bpt6k1090035v.tar.gz.tei_segmented_ner.xml contains 141 PER unique entities
# Document bpt6k1090035v.tar.gz.tei_segmented_ner.xml contains 107 LOC entities; 33 linked and 74 non-linked
# Document bpt6k1090035v.tar.gz.tei_segmented_ner.xml contains 20 LOC unique entities
# Document bpt6k1090091g.tar.gz.tei_segmented_ner.xml contains 478 PER entities; 287 linked and 191 non-linked
# Document bpt6k1090091g.tar.gz.tei_segmented_ner.xml contains 36 PER unique entities
# Document bpt6k1090091g.tar.gz.tei_segmented_ner.xml contains 5 LOC entities; 5 linked and 0 non-linked
# Document bpt6k1090091g.tar.gz.tei_segmented_ner.xml contains 2 LOC unique entities
# Document bpt6k852855g.tar.gz.tei_segmented_ner.xml contains 319 PER entities; 213 linked and 106 non-linked
# Document bpt6k852855g.tar.gz.tei_segmented_ner.xml contains 43 PER unique entities
# Document bpt6k852855g.tar.gz.tei_segmented_ner.xml contains 6 LOC entities; 6 linked and 0 non-linked
# Document bpt6k852855g.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k1280294m.tar.gz.tei_segmented_ner.xml contains 347 PER entities; 232 linked and 115 non-linked
# Document bpt6k1280294m.tar.gz.tei_segmented_ner.xml contains 55 PER unique entities
# Document bpt6k1280294m.tar.gz.tei_segmented_ner.xml contains 63 LOC entities; 57 linked and 6 non-linked
# Document bpt6k1280294m.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k12803190.tar.gz.tei_segmented_ner.xml contains 879 PER entities; 413 linked and 466 non-linked
# Document bpt6k12803190.tar.gz.tei_segmented_ner.xml contains 43 PER unique entities
# Document bpt6k12803190.tar.gz.tei_segmented_ner.xml contains 37 LOC entities; 34 linked and 3 non-linked
# Document bpt6k12803190.tar.gz.tei_segmented_ner.xml contains 10 LOC unique entities
# Document bpt6k8568033.tar.gz.tei_segmented_ner.xml contains 432 PER entities; 245 linked and 187 non-linked
# Document bpt6k8568033.tar.gz.tei_segmented_ner.xml contains 43 PER unique entities
# Document bpt6k8568033.tar.gz.tei_segmented_ner.xml contains 17 LOC entities; 12 linked and 5 non-linked
# Document bpt6k8568033.tar.gz.tei_segmented_ner.xml contains 10 LOC unique entities
# Document bpt6k1520591g.tar.gz.tei_segmented_ner.xml contains 273 PER entities; 163 linked and 110 non-linked
# Document bpt6k1520591g.tar.gz.tei_segmented_ner.xml contains 67 PER unique entities
# Document bpt6k1520591g.tar.gz.tei_segmented_ner.xml contains 6 LOC entities; 3 linked and 3 non-linked
# Document bpt6k1520591g.tar.gz.tei_segmented_ner.xml contains 2 LOC unique entities
# Document bpt6k12804007.tar.gz.tei_segmented_ner.xml contains 254 PER entities; 74 linked and 180 non-linked
# Document bpt6k12804007.tar.gz.tei_segmented_ner.xml contains 32 PER unique entities
# Document bpt6k12804007.tar.gz.tei_segmented_ner.xml contains 12 LOC entities; 11 linked and 1 non-linked
# Document bpt6k12804007.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k8568902.tar.gz.tei_segmented_ner.xml contains 374 PER entities; 228 linked and 146 non-linked
# Document bpt6k8568902.tar.gz.tei_segmented_ner.xml contains 118 PER unique entities
# Document bpt6k8568902.tar.gz.tei_segmented_ner.xml contains 63 LOC entities; 49 linked and 14 non-linked
# Document bpt6k8568902.tar.gz.tei_segmented_ner.xml contains 26 LOC unique entities
# Document bpt6k852853q.tar.gz.tei_segmented_ner.xml contains 540 PER entities; 172 linked and 368 non-linked
# Document bpt6k852853q.tar.gz.tei_segmented_ner.xml contains 41 PER unique entities
# Document bpt6k852853q.tar.gz.tei_segmented_ner.xml contains 29 LOC entities; 12 linked and 17 non-linked
# Document bpt6k852853q.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k57346959.tar.gz.tei_segmented_ner.xml contains 119 PER entities; 31 linked and 88 non-linked
# Document bpt6k57346959.tar.gz.tei_segmented_ner.xml contains 12 PER unique entities
# Document bpt6k57346959.tar.gz.tei_segmented_ner.xml contains 6 LOC entities; 6 linked and 0 non-linked
# Document bpt6k57346959.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document btv1b86221054.tar.gz.tei_segmented_ner.xml contains 397 PER entities; 210 linked and 187 non-linked
# Document btv1b86221054.tar.gz.tei_segmented_ner.xml contains 50 PER unique entities
# Document btv1b86221054.tar.gz.tei_segmented_ner.xml contains 32 LOC entities; 26 linked and 6 non-linked
# Document btv1b86221054.tar.gz.tei_segmented_ner.xml contains 12 LOC unique entities
# Document bpt6k8528619.tar.gz.tei_segmented_ner.xml contains 96 PER entities; 51 linked and 45 non-linked
# Document bpt6k8528619.tar.gz.tei_segmented_ner.xml contains 16 PER unique entities
# Document bpt6k8528619.tar.gz.tei_segmented_ner.xml contains 1 LOC entities; 1 linked and 0 non-linked
# Document bpt6k8528619.tar.gz.tei_segmented_ner.xml contains 1 LOC unique entities
# Document bpt6k5507412z.tar.gz.tei_segmented_ner.xml contains 148 PER entities; 92 linked and 56 non-linked
# Document bpt6k5507412z.tar.gz.tei_segmented_ner.xml contains 26 PER unique entities
# Document bpt6k5507412z.tar.gz.tei_segmented_ner.xml contains 9 LOC entities; 5 linked and 4 non-linked
# Document bpt6k5507412z.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k856976z.tar.gz.tei_segmented_ner.xml contains 143 PER entities; 101 linked and 42 non-linked
# Document bpt6k856976z.tar.gz.tei_segmented_ner.xml contains 20 PER unique entities
# Document bpt6k856976z.tar.gz.tei_segmented_ner.xml contains 11 LOC entities; 8 linked and 3 non-linked
# Document bpt6k856976z.tar.gz.tei_segmented_ner.xml contains 1 LOC unique entities
# Document bpt6k1090046n.tar.gz.tei_segmented_ner.xml contains 400 PER entities; 144 linked and 256 non-linked
# Document bpt6k1090046n.tar.gz.tei_segmented_ner.xml contains 42 PER unique entities
# Document bpt6k1090046n.tar.gz.tei_segmented_ner.xml contains 23 LOC entities; 11 linked and 12 non-linked
# Document bpt6k1090046n.tar.gz.tei_segmented_ner.xml contains 7 LOC unique entities
# Document bpt6k1090181f.tar.gz.tei_segmented_ner.xml contains 488 PER entities; 378 linked and 110 non-linked
# Document bpt6k1090181f.tar.gz.tei_segmented_ner.xml contains 29 PER unique entities
# Document bpt6k1090181f.tar.gz.tei_segmented_ner.xml contains 5 LOC entities; 2 linked and 3 non-linked
# Document bpt6k1090181f.tar.gz.tei_segmented_ner.xml contains 1 LOC unique entities
# Document bpt6k856888r.tar.gz.tei_segmented_ner.xml contains 652 PER entities; 385 linked and 267 non-linked
# Document bpt6k856888r.tar.gz.tei_segmented_ner.xml contains 88 PER unique entities
# Document bpt6k856888r.tar.gz.tei_segmented_ner.xml contains 45 LOC entities; 28 linked and 17 non-linked
# Document bpt6k856888r.tar.gz.tei_segmented_ner.xml contains 20 LOC unique entities
# Document bpt6k1521139f.tar.gz.tei_segmented_ner.xml contains 77 PER entities; 28 linked and 49 non-linked
# Document bpt6k1521139f.tar.gz.tei_segmented_ner.xml contains 18 PER unique entities
# Document bpt6k1521139f.tar.gz.tei_segmented_ner.xml contains 3 LOC entities; 2 linked and 1 non-linked
# Document bpt6k1521139f.tar.gz.tei_segmented_ner.xml contains 2 LOC unique entities
# Document btv1b86221128.tar.gz.tei_segmented_ner.xml contains 273 PER entities; 38 linked and 235 non-linked
# Document btv1b86221128.tar.gz.tei_segmented_ner.xml contains 22 PER unique entities
# Document btv1b86221128.tar.gz.tei_segmented_ner.xml contains 10 LOC entities; 4 linked and 6 non-linked
# Document btv1b86221128.tar.gz.tei_segmented_ner.xml contains 2 LOC unique entities
# Document bpt6k1090154j.tar.gz.tei_segmented_ner.xml contains 118 PER entities; 82 linked and 36 non-linked
# Document bpt6k1090154j.tar.gz.tei_segmented_ner.xml contains 31 PER unique entities
# Document bpt6k1090154j.tar.gz.tei_segmented_ner.xml contains 7 LOC entities; 5 linked and 2 non-linked
# Document bpt6k1090154j.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k5734490j.tar.gz.tei_segmented_ner.xml contains 425 PER entities; 265 linked and 160 non-linked
# Document bpt6k5734490j.tar.gz.tei_segmented_ner.xml contains 40 PER unique entities
# Document bpt6k5734490j.tar.gz.tei_segmented_ner.xml contains 17 LOC entities; 8 linked and 9 non-linked
# Document bpt6k5734490j.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k10902522.tar.gz.tei_segmented_ner.xml contains 225 PER entities; 101 linked and 124 non-linked
# Document bpt6k10902522.tar.gz.tei_segmented_ner.xml contains 23 PER unique entities
# Document bpt6k10902522.tar.gz.tei_segmented_ner.xml contains 4 LOC entities; 3 linked and 1 non-linked
# Document bpt6k10902522.tar.gz.tei_segmented_ner.xml contains 2 LOC unique entities
# Document bpt6k5745518r.tar.gz.tei_segmented_ner.xml contains 249 PER entities; 108 linked and 141 non-linked
# Document bpt6k5745518r.tar.gz.tei_segmented_ner.xml contains 39 PER unique entities
# Document bpt6k5745518r.tar.gz.tei_segmented_ner.xml contains 20 LOC entities; 13 linked and 7 non-linked
# Document bpt6k5745518r.tar.gz.tei_segmented_ner.xml contains 11 LOC unique entities
# Document bpt6k54487748.tar.gz.tei_segmented_ner.xml contains 202 PER entities; 104 linked and 98 non-linked
# Document bpt6k54487748.tar.gz.tei_segmented_ner.xml contains 29 PER unique entities
# Document bpt6k54487748.tar.gz.tei_segmented_ner.xml contains 26 LOC entities; 18 linked and 8 non-linked
# Document bpt6k54487748.tar.gz.tei_segmented_ner.xml contains 8 LOC unique entities
# Document bpt6k10902077.tar.gz.tei_segmented_ner.xml contains 183 PER entities; 123 linked and 60 non-linked
# Document bpt6k10902077.tar.gz.tei_segmented_ner.xml contains 19 PER unique entities
# Error processing document 42: 'DataFrame' object has no attribute 'qid'
# Document bpt6k1090177j.tar.gz.tei_segmented_ner.xml contains 281 PER entities; 96 linked and 185 non-linked
# Document bpt6k1090177j.tar.gz.tei_segmented_ner.xml contains 51 PER unique entities
# Document bpt6k1090177j.tar.gz.tei_segmented_ner.xml contains 9 LOC entities; 4 linked and 5 non-linked
# Document bpt6k1090177j.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k1090190d.tar.gz.tei_segmented_ner.xml contains 713 PER entities; 295 linked and 418 non-linked
# Document bpt6k1090190d.tar.gz.tei_segmented_ner.xml contains 57 PER unique entities
# Document bpt6k1090190d.tar.gz.tei_segmented_ner.xml contains 4 LOC entities; 4 linked and 0 non-linked
# Document bpt6k1090190d.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k6354094m.tar.gz.tei_segmented_ner.xml contains 350 PER entities; 273 linked and 77 non-linked
# Document bpt6k6354094m.tar.gz.tei_segmented_ner.xml contains 23 PER unique entities
# Document bpt6k6354094m.tar.gz.tei_segmented_ner.xml contains 13 LOC entities; 11 linked and 2 non-linked
# Document bpt6k6354094m.tar.gz.tei_segmented_ner.xml contains 7 LOC unique entities
# Document bpt6k10901675.tar.gz.tei_segmented_ner.xml contains 533 PER entities; 286 linked and 247 non-linked
# Document bpt6k10901675.tar.gz.tei_segmented_ner.xml contains 20 PER unique entities
# Document bpt6k10901675.tar.gz.tei_segmented_ner.xml contains 3 LOC entities; 3 linked and 0 non-linked
# Document bpt6k10901675.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k1519300g.tar.gz.tei_segmented_ner.xml contains 170 PER entities; 27 linked and 143 non-linked
# Document bpt6k1519300g.tar.gz.tei_segmented_ner.xml contains 13 PER unique entities
# Error processing document 47: 'DataFrame' object has no attribute 'qid'
# Document bpt6k1090096j.tar.gz.tei_segmented_ner.xml contains 417 PER entities; 259 linked and 158 non-linked
# Document bpt6k1090096j.tar.gz.tei_segmented_ner.xml contains 25 PER unique entities
# Document bpt6k1090096j.tar.gz.tei_segmented_ner.xml contains 25 LOC entities; 21 linked and 4 non-linked
# Document bpt6k1090096j.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k8528590.tar.gz.tei_segmented_ner.xml contains 356 PER entities; 234 linked and 122 non-linked
# Document bpt6k8528590.tar.gz.tei_segmented_ner.xml contains 22 PER unique entities
# Document bpt6k8528590.tar.gz.tei_segmented_ner.xml contains 6 LOC entities; 6 linked and 0 non-linked
# Document bpt6k8528590.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k5690275b.tar.gz.tei_segmented_ner.xml contains 1173 PER entities; 661 linked and 512 non-linked
# Document bpt6k5690275b.tar.gz.tei_segmented_ner.xml contains 113 PER unique entities
# Document bpt6k5690275b.tar.gz.tei_segmented_ner.xml contains 30 LOC entities; 23 linked and 7 non-linked
# Document bpt6k5690275b.tar.gz.tei_segmented_ner.xml contains 13 LOC unique entities
# Document bpt6k5448680n.tar.gz.tei_segmented_ner.xml contains 501 PER entities; 230 linked and 271 non-linked
# Document bpt6k5448680n.tar.gz.tei_segmented_ner.xml contains 83 PER unique entities
# Document bpt6k5448680n.tar.gz.tei_segmented_ner.xml contains 41 LOC entities; 31 linked and 10 non-linked
# Document bpt6k5448680n.tar.gz.tei_segmented_ner.xml contains 7 LOC unique entities
# Document bpt6k1090087k.tar.gz.tei_segmented_ner.xml contains 1534 PER entities; 891 linked and 643 non-linked
# Document bpt6k1090087k.tar.gz.tei_segmented_ner.xml contains 193 PER unique entities
# Document bpt6k1090087k.tar.gz.tei_segmented_ner.xml contains 50 LOC entities; 41 linked and 9 non-linked
# Document bpt6k1090087k.tar.gz.tei_segmented_ner.xml contains 25 LOC unique entities
# Document bpt6k15220617.tar.gz.tei_segmented_ner.xml contains 250 PER entities; 163 linked and 87 non-linked
# Document bpt6k15220617.tar.gz.tei_segmented_ner.xml contains 33 PER unique entities
# Document bpt6k15220617.tar.gz.tei_segmented_ner.xml contains 8 LOC entities; 5 linked and 3 non-linked
# Document bpt6k15220617.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k10901126.tar.gz.tei_segmented_ner.xml contains 295 PER entities; 182 linked and 113 non-linked
# Document bpt6k10901126.tar.gz.tei_segmented_ner.xml contains 34 PER unique entities
# Document bpt6k10901126.tar.gz.tei_segmented_ner.xml contains 49 LOC entities; 46 linked and 3 non-linked
# Document bpt6k10901126.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k1280537m.tar.gz.tei_segmented_ner.xml contains 371 PER entities; 185 linked and 186 non-linked
# Document bpt6k1280537m.tar.gz.tei_segmented_ner.xml contains 25 PER unique entities
# Document bpt6k1280537m.tar.gz.tei_segmented_ner.xml contains 1 LOC entities; 1 linked and 0 non-linked
# Document bpt6k1280537m.tar.gz.tei_segmented_ner.xml contains 1 LOC unique entities
# Document bpt6k10902396.tar.gz.tei_segmented_ner.xml contains 106 PER entities; 51 linked and 55 non-linked
# Document bpt6k10902396.tar.gz.tei_segmented_ner.xml contains 21 PER unique entities
# Document bpt6k10902396.tar.gz.tei_segmented_ner.xml contains 10 LOC entities; 7 linked and 3 non-linked
# Document bpt6k10902396.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k852871n.tar.gz.tei_segmented_ner.xml contains 295 PER entities; 109 linked and 186 non-linked
# Document bpt6k852871n.tar.gz.tei_segmented_ner.xml contains 31 PER unique entities
# Document bpt6k852871n.tar.gz.tei_segmented_ner.xml contains 4 LOC entities; 1 linked and 3 non-linked
# Document bpt6k852871n.tar.gz.tei_segmented_ner.xml contains 1 LOC unique entities
# Document bpt6k5754483z.tar.gz.tei_segmented_ner.xml contains 1161 PER entities; 638 linked and 523 non-linked
# Document bpt6k5754483z.tar.gz.tei_segmented_ner.xml contains 74 PER unique entities
# Document bpt6k5754483z.tar.gz.tei_segmented_ner.xml contains 42 LOC entities; 28 linked and 14 non-linked
# Document bpt6k5754483z.tar.gz.tei_segmented_ner.xml contains 13 LOC unique entities
# Document bpt6k1081525.tar.gz.tei_segmented_ner.xml contains 398 PER entities; 176 linked and 222 non-linked
# Document bpt6k1081525.tar.gz.tei_segmented_ner.xml contains 42 PER unique entities
# Document bpt6k1081525.tar.gz.tei_segmented_ner.xml contains 35 LOC entities; 32 linked and 3 non-linked
# Document bpt6k1081525.tar.gz.tei_segmented_ner.xml contains 8 LOC unique entities
# Document bpt6k3045974n.tar.gz.tei_segmented_ner.xml contains 242 PER entities; 119 linked and 123 non-linked
# Document bpt6k3045974n.tar.gz.tei_segmented_ner.xml contains 27 PER unique entities
# Document bpt6k3045974n.tar.gz.tei_segmented_ner.xml contains 11 LOC entities; 9 linked and 2 non-linked
# Document bpt6k3045974n.tar.gz.tei_segmented_ner.xml contains 7 LOC unique entities
# Document bpt6k1097754.tar.gz.tei_segmented_ner.xml contains 448 PER entities; 143 linked and 305 non-linked
# Document bpt6k1097754.tar.gz.tei_segmented_ner.xml contains 60 PER unique entities
# Document bpt6k1097754.tar.gz.tei_segmented_ner.xml contains 22 LOC entities; 18 linked and 4 non-linked
# Document bpt6k1097754.tar.gz.tei_segmented_ner.xml contains 14 LOC unique entities
# Document bpt6k6262823q.tar.gz.tei_segmented_ner.xml contains 618 PER entities; 210 linked and 408 non-linked
# Document bpt6k6262823q.tar.gz.tei_segmented_ner.xml contains 36 PER unique entities
# Document bpt6k6262823q.tar.gz.tei_segmented_ner.xml contains 31 LOC entities; 24 linked and 7 non-linked
# Document bpt6k6262823q.tar.gz.tei_segmented_ner.xml contains 11 LOC unique entities
# Document bpt6k8572113.tar.gz.tei_segmented_ner.xml contains 337 PER entities; 234 linked and 103 non-linked
# Document bpt6k8572113.tar.gz.tei_segmented_ner.xml contains 52 PER unique entities
# Document bpt6k8572113.tar.gz.tei_segmented_ner.xml contains 8 LOC entities; 8 linked and 0 non-linked
# Document bpt6k8572113.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k5747751p.tar.gz.tei_segmented_ner.xml contains 244 PER entities; 141 linked and 103 non-linked
# Document bpt6k5747751p.tar.gz.tei_segmented_ner.xml contains 72 PER unique entities
# Document bpt6k5747751p.tar.gz.tei_segmented_ner.xml contains 35 LOC entities; 32 linked and 3 non-linked
# Document bpt6k5747751p.tar.gz.tei_segmented_ner.xml contains 18 LOC unique entities
# Document bpt6k852860x.tar.gz.tei_segmented_ner.xml contains 310 PER entities; 253 linked and 57 non-linked
# Document bpt6k852860x.tar.gz.tei_segmented_ner.xml contains 36 PER unique entities
# Document bpt6k852860x.tar.gz.tei_segmented_ner.xml contains 77 LOC entities; 66 linked and 11 non-linked
# Document bpt6k852860x.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document btv1b8619706h.tar.gz.tei_segmented_ner.xml contains 190 PER entities; 83 linked and 107 non-linked
# Document btv1b8619706h.tar.gz.tei_segmented_ner.xml contains 22 PER unique entities
# Document btv1b8619706h.tar.gz.tei_segmented_ner.xml contains 6 LOC entities; 3 linked and 3 non-linked
# Document btv1b8619706h.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k841557s.tar.gz.tei_segmented_ner.xml contains 391 PER entities; 86 linked and 305 non-linked
# Document bpt6k841557s.tar.gz.tei_segmented_ner.xml contains 30 PER unique entities
# Document bpt6k841557s.tar.gz.tei_segmented_ner.xml contains 16 LOC entities; 12 linked and 4 non-linked
# Document bpt6k841557s.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k1040272f.tar.gz.tei_segmented_ner.xml contains 150 PER entities; 77 linked and 73 non-linked
# Document bpt6k1040272f.tar.gz.tei_segmented_ner.xml contains 29 PER unique entities
# Document bpt6k1040272f.tar.gz.tei_segmented_ner.xml contains 17 LOC entities; 16 linked and 1 non-linked
# Document bpt6k1040272f.tar.gz.tei_segmented_ner.xml contains 12 LOC unique entities
# Document bpt6k8569793.tar.gz.tei_segmented_ner.xml contains 350 PER entities; 202 linked and 148 non-linked
# Document bpt6k8569793.tar.gz.tei_segmented_ner.xml contains 101 PER unique entities
# Document bpt6k8569793.tar.gz.tei_segmented_ner.xml contains 45 LOC entities; 29 linked and 16 non-linked
# Document bpt6k8569793.tar.gz.tei_segmented_ner.xml contains 20 LOC unique entities
# Document bpt6k1090229t.tar.gz.tei_segmented_ner.xml contains 172 PER entities; 94 linked and 78 non-linked
# Document bpt6k1090229t.tar.gz.tei_segmented_ner.xml contains 17 PER unique entities
# Document bpt6k1090229t.tar.gz.tei_segmented_ner.xml contains 1 LOC entities; 0 linked and 1 non-linked
# Document bpt6k1090229t.tar.gz.tei_segmented_ner.xml contains 0 LOC unique entities
# Error processing document 70: list index out of range
# Document bpt6k856871r.tar.gz.tei_segmented_ner.xml contains 506 PER entities; 175 linked and 331 non-linked
# Document bpt6k856871r.tar.gz.tei_segmented_ner.xml contains 106 PER unique entities
# Document bpt6k856871r.tar.gz.tei_segmented_ner.xml contains 32 LOC entities; 17 linked and 15 non-linked
# Document bpt6k856871r.tar.gz.tei_segmented_ner.xml contains 14 LOC unique entities
# Document bpt6k8529175.tar.gz.tei_segmented_ner.xml contains 230 PER entities; 188 linked and 42 non-linked
# Document bpt6k8529175.tar.gz.tei_segmented_ner.xml contains 41 PER unique entities
# Document bpt6k8529175.tar.gz.tei_segmented_ner.xml contains 9 LOC entities; 3 linked and 6 non-linked
# Document bpt6k8529175.tar.gz.tei_segmented_ner.xml contains 2 LOC unique entities
# Document bpt6k12804482.tar.gz.tei_segmented_ner.xml contains 219 PER entities; 167 linked and 52 non-linked
# Document bpt6k12804482.tar.gz.tei_segmented_ner.xml contains 27 PER unique entities
# Document bpt6k12804482.tar.gz.tei_segmented_ner.xml contains 16 LOC entities; 11 linked and 5 non-linked
# Document bpt6k12804482.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document btv1b8622111v.tar.gz.tei_segmented_ner.xml contains 369 PER entities; 200 linked and 169 non-linked
# Document btv1b8622111v.tar.gz.tei_segmented_ner.xml contains 42 PER unique entities
# Document btv1b8622111v.tar.gz.tei_segmented_ner.xml contains 17 LOC entities; 16 linked and 1 non-linked
# Document btv1b8622111v.tar.gz.tei_segmented_ner.xml contains 8 LOC unique entities
# Document bpt6k1280396s.tar.gz.tei_segmented_ner.xml contains 2019 PER entities; 369 linked and 1650 non-linked
# Document bpt6k1280396s.tar.gz.tei_segmented_ner.xml contains 107 PER unique entities
# Document bpt6k1280396s.tar.gz.tei_segmented_ner.xml contains 62 LOC entities; 55 linked and 7 non-linked
# Document bpt6k1280396s.tar.gz.tei_segmented_ner.xml contains 17 LOC unique entities
# Document btv1b8622115h.tar.gz.tei_segmented_ner.xml contains 442 PER entities; 278 linked and 164 non-linked
# Document btv1b8622115h.tar.gz.tei_segmented_ner.xml contains 71 PER unique entities
# Document btv1b8622115h.tar.gz.tei_segmented_ner.xml contains 25 LOC entities; 21 linked and 4 non-linked
# Document btv1b8622115h.tar.gz.tei_segmented_ner.xml contains 10 LOC unique entities
# Document bpt6k6524930f.tar.gz.tei_segmented_ner.xml contains 485 PER entities; 233 linked and 252 non-linked
# Document bpt6k6524930f.tar.gz.tei_segmented_ner.xml contains 91 PER unique entities
# Document bpt6k6524930f.tar.gz.tei_segmented_ner.xml contains 45 LOC entities; 38 linked and 7 non-linked
# Document bpt6k6524930f.tar.gz.tei_segmented_ner.xml contains 7 LOC unique entities
# Document bpt6k10903080.tar.gz.tei_segmented_ner.xml contains 585 PER entities; 219 linked and 366 non-linked
# Document bpt6k10903080.tar.gz.tei_segmented_ner.xml contains 67 PER unique entities
# Document bpt6k10903080.tar.gz.tei_segmented_ner.xml contains 37 LOC entities; 28 linked and 9 non-linked
# Document bpt6k10903080.tar.gz.tei_segmented_ner.xml contains 15 LOC unique entities
# Document bpt6k8529052.tar.gz.tei_segmented_ner.xml contains 187 PER entities; 67 linked and 120 non-linked
# Document bpt6k8529052.tar.gz.tei_segmented_ner.xml contains 44 PER unique entities
# Document bpt6k8529052.tar.gz.tei_segmented_ner.xml contains 11 LOC entities; 7 linked and 4 non-linked
# Document bpt6k8529052.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k856883v.tar.gz.tei_segmented_ner.xml contains 876 PER entities; 566 linked and 310 non-linked
# Document bpt6k856883v.tar.gz.tei_segmented_ner.xml contains 49 PER unique entities
# Document bpt6k856883v.tar.gz.tei_segmented_ner.xml contains 23 LOC entities; 22 linked and 1 non-linked
# Document bpt6k856883v.tar.gz.tei_segmented_ner.xml contains 7 LOC unique entities
# Document bpt6k1280475z.tar.gz.tei_segmented_ner.xml contains 285 PER entities; 184 linked and 101 non-linked
# Document bpt6k1280475z.tar.gz.tei_segmented_ner.xml contains 31 PER unique entities
# Document bpt6k1280475z.tar.gz.tei_segmented_ner.xml contains 11 LOC entities; 9 linked and 2 non-linked
# Document bpt6k1280475z.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k12804074.tar.gz.tei_segmented_ner.xml contains 238 PER entities; 43 linked and 195 non-linked
# Document bpt6k12804074.tar.gz.tei_segmented_ner.xml contains 13 PER unique entities
# Document bpt6k12804074.tar.gz.tei_segmented_ner.xml contains 4 LOC entities; 0 linked and 4 non-linked
# Document bpt6k12804074.tar.gz.tei_segmented_ner.xml contains 0 LOC unique entities
# Error processing document 82: list index out of range
# Document bpt6k55303536.tar.gz.tei_segmented_ner.xml contains 518 PER entities; 169 linked and 349 non-linked
# Document bpt6k55303536.tar.gz.tei_segmented_ner.xml contains 61 PER unique entities
# Document bpt6k55303536.tar.gz.tei_segmented_ner.xml contains 32 LOC entities; 18 linked and 14 non-linked
# Document bpt6k55303536.tar.gz.tei_segmented_ner.xml contains 17 LOC unique entities
# Document bpt6k8529230.tar.gz.tei_segmented_ner.xml contains 858 PER entities; 89 linked and 769 non-linked
# Document bpt6k8529230.tar.gz.tei_segmented_ner.xml contains 36 PER unique entities
# Document bpt6k8529230.tar.gz.tei_segmented_ner.xml contains 7 LOC entities; 4 linked and 3 non-linked
# Document bpt6k8529230.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k856901n.tar.gz.tei_segmented_ner.xml contains 341 PER entities; 178 linked and 163 non-linked
# Document bpt6k856901n.tar.gz.tei_segmented_ner.xml contains 57 PER unique entities
# Document bpt6k856901n.tar.gz.tei_segmented_ner.xml contains 29 LOC entities; 18 linked and 11 non-linked
# Document bpt6k856901n.tar.gz.tei_segmented_ner.xml contains 8 LOC unique entities
# Document btv1b8622127q.tar.gz.tei_segmented_ner.xml contains 477 PER entities; 62 linked and 415 non-linked
# Document btv1b8622127q.tar.gz.tei_segmented_ner.xml contains 25 PER unique entities
# Document btv1b8622127q.tar.gz.tei_segmented_ner.xml contains 9 LOC entities; 8 linked and 1 non-linked
# Document btv1b8622127q.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k8528577.tar.gz.tei_segmented_ner.xml contains 288 PER entities; 74 linked and 214 non-linked
# Document bpt6k8528577.tar.gz.tei_segmented_ner.xml contains 19 PER unique entities
# Document bpt6k8528577.tar.gz.tei_segmented_ner.xml contains 8 LOC entities; 6 linked and 2 non-linked
# Document bpt6k8528577.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k1090236z.tar.gz.tei_segmented_ner.xml contains 304 PER entities; 174 linked and 130 non-linked
# Document bpt6k1090236z.tar.gz.tei_segmented_ner.xml contains 55 PER unique entities
# Document bpt6k1090236z.tar.gz.tei_segmented_ner.xml contains 6 LOC entities; 4 linked and 2 non-linked
# Document bpt6k1090236z.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k15207270.tar.gz.tei_segmented_ner.xml contains 113 PER entities; 69 linked and 44 non-linked
# Document bpt6k15207270.tar.gz.tei_segmented_ner.xml contains 19 PER unique entities
# Document bpt6k15207270.tar.gz.tei_segmented_ner.xml contains 11 LOC entities; 6 linked and 5 non-linked
# Document bpt6k15207270.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k10901304.tar.gz.tei_segmented_ner.xml contains 282 PER entities; 219 linked and 63 non-linked
# Document bpt6k10901304.tar.gz.tei_segmented_ner.xml contains 21 PER unique entities
# Document bpt6k10901304.tar.gz.tei_segmented_ner.xml contains 18 LOC entities; 16 linked and 2 non-linked
# Document bpt6k10901304.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document btv1b8610784x.tar.gz.tei_segmented_ner.xml contains 695 PER entities; 156 linked and 539 non-linked
# Document btv1b8610784x.tar.gz.tei_segmented_ner.xml contains 32 PER unique entities
# Document btv1b8610784x.tar.gz.tei_segmented_ner.xml contains 6 LOC entities; 6 linked and 0 non-linked
# Document btv1b8610784x.tar.gz.tei_segmented_ner.xml contains 2 LOC unique entities
# Document bpt6k5629556w.tar.gz.tei_segmented_ner.xml contains 206 PER entities; 88 linked and 118 non-linked
# Document bpt6k5629556w.tar.gz.tei_segmented_ner.xml contains 25 PER unique entities
# Document bpt6k5629556w.tar.gz.tei_segmented_ner.xml contains 9 LOC entities; 1 linked and 8 non-linked
# Document bpt6k5629556w.tar.gz.tei_segmented_ner.xml contains 1 LOC unique entities
# Document btv1b8610800k.tar.gz.tei_segmented_ner.xml contains 603 PER entities; 521 linked and 82 non-linked
# Document btv1b8610800k.tar.gz.tei_segmented_ner.xml contains 56 PER unique entities
# Document btv1b8610800k.tar.gz.tei_segmented_ner.xml contains 14 LOC entities; 11 linked and 3 non-linked
# Document btv1b8610800k.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k15138878.tar.gz.tei_segmented_ner.xml contains 158 PER entities; 119 linked and 39 non-linked
# Document bpt6k15138878.tar.gz.tei_segmented_ner.xml contains 14 PER unique entities
# Document bpt6k15138878.tar.gz.tei_segmented_ner.xml contains 6 LOC entities; 1 linked and 5 non-linked
# Document bpt6k15138878.tar.gz.tei_segmented_ner.xml contains 1 LOC unique entities
# Document bpt6k5745520t.tar.gz.tei_segmented_ner.xml contains 531 PER entities; 228 linked and 303 non-linked
# Document bpt6k5745520t.tar.gz.tei_segmented_ner.xml contains 32 PER unique entities
# Document bpt6k5745520t.tar.gz.tei_segmented_ner.xml contains 18 LOC entities; 18 linked and 0 non-linked
# Document bpt6k5745520t.tar.gz.tei_segmented_ner.xml contains 7 LOC unique entities
# Document bpt6k1522369k.tar.gz.tei_segmented_ner.xml contains 124 PER entities; 101 linked and 23 non-linked
# Document bpt6k1522369k.tar.gz.tei_segmented_ner.xml contains 25 PER unique entities
# Document bpt6k1522369k.tar.gz.tei_segmented_ner.xml contains 16 LOC entities; 5 linked and 11 non-linked
# Document bpt6k1522369k.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k841852.tar.gz.tei_segmented_ner.xml contains 455 PER entities; 252 linked and 203 non-linked
# Document bpt6k841852.tar.gz.tei_segmented_ner.xml contains 53 PER unique entities
# Document bpt6k841852.tar.gz.tei_segmented_ner.xml contains 24 LOC entities; 17 linked and 7 non-linked
# Document bpt6k841852.tar.gz.tei_segmented_ner.xml contains 8 LOC unique entities
# Document bpt6k15205791.tar.gz.tei_segmented_ner.xml contains 445 PER entities; 291 linked and 154 non-linked
# Document bpt6k15205791.tar.gz.tei_segmented_ner.xml contains 97 PER unique entities
# Document bpt6k15205791.tar.gz.tei_segmented_ner.xml contains 10 LOC entities; 3 linked and 7 non-linked
# Document bpt6k15205791.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k87013650.tar.gz.tei_segmented_ner.xml contains 623 PER entities; 358 linked and 265 non-linked
# Document bpt6k87013650.tar.gz.tei_segmented_ner.xml contains 65 PER unique entities
# Document bpt6k87013650.tar.gz.tei_segmented_ner.xml contains 112 LOC entities; 100 linked and 12 non-linked
# Document bpt6k87013650.tar.gz.tei_segmented_ner.xml contains 13 LOC unique entities
# Document bpt6k1090099s.tar.gz.tei_segmented_ner.xml contains 256 PER entities; 164 linked and 92 non-linked
# Document bpt6k1090099s.tar.gz.tei_segmented_ner.xml contains 44 PER unique entities
# Document bpt6k1090099s.tar.gz.tei_segmented_ner.xml contains 30 LOC entities; 28 linked and 2 non-linked
# Document bpt6k1090099s.tar.gz.tei_segmented_ner.xml contains 12 LOC unique entities
# Document bpt6k5754191g.tar.gz.tei_segmented_ner.xml contains 476 PER entities; 208 linked and 268 non-linked
# Document bpt6k5754191g.tar.gz.tei_segmented_ner.xml contains 26 PER unique entities
# Document bpt6k5754191g.tar.gz.tei_segmented_ner.xml contains 39 LOC entities; 34 linked and 5 non-linked
# Document bpt6k5754191g.tar.gz.tei_segmented_ner.xml contains 12 LOC unique entities
# Document bpt6k57544369.tar.gz.tei_segmented_ner.xml contains 279 PER entities; 181 linked and 98 non-linked
# Document bpt6k57544369.tar.gz.tei_segmented_ner.xml contains 46 PER unique entities
# Document bpt6k57544369.tar.gz.tei_segmented_ner.xml contains 30 LOC entities; 23 linked and 7 non-linked
# Document bpt6k57544369.tar.gz.tei_segmented_ner.xml contains 9 LOC unique entities
# Document bpt6k1090263v.tar.gz.tei_segmented_ner.xml contains 359 PER entities; 59 linked and 300 non-linked
# Document bpt6k1090263v.tar.gz.tei_segmented_ner.xml contains 35 PER unique entities
# Document bpt6k1090263v.tar.gz.tei_segmented_ner.xml contains 115 LOC entities; 40 linked and 75 non-linked
# Document bpt6k1090263v.tar.gz.tei_segmented_ner.xml contains 19 LOC unique entities
# Document btv1b8622109s.tar.gz.tei_segmented_ner.xml contains 2592 PER entities; 1724 linked and 868 non-linked
# Document btv1b8622109s.tar.gz.tei_segmented_ner.xml contains 331 PER unique entities
# Document btv1b8622109s.tar.gz.tei_segmented_ner.xml contains 171 LOC entities; 134 linked and 37 non-linked
# Document btv1b8622109s.tar.gz.tei_segmented_ner.xml contains 40 LOC unique entities
# Document bpt6k1280410m.tar.gz.tei_segmented_ner.xml contains 338 PER entities; 65 linked and 273 non-linked
# Document bpt6k1280410m.tar.gz.tei_segmented_ner.xml contains 42 PER unique entities
# Document bpt6k1280410m.tar.gz.tei_segmented_ner.xml contains 9 LOC entities; 4 linked and 5 non-linked
# Document bpt6k1280410m.tar.gz.tei_segmented_ner.xml contains 2 LOC unique entities
# Document bpt6k6255602h.tar.gz.tei_segmented_ner.xml contains 1056 PER entities; 391 linked and 665 non-linked
# Document bpt6k6255602h.tar.gz.tei_segmented_ner.xml contains 45 PER unique entities
# Document bpt6k6255602h.tar.gz.tei_segmented_ner.xml contains 42 LOC entities; 29 linked and 13 non-linked
# Document bpt6k6255602h.tar.gz.tei_segmented_ner.xml contains 10 LOC unique entities
# Document btv1b8610788k.tar.gz.tei_segmented_ner.xml contains 751 PER entities; 129 linked and 622 non-linked
# Document btv1b8610788k.tar.gz.tei_segmented_ner.xml contains 31 PER unique entities
# Document btv1b8610788k.tar.gz.tei_segmented_ner.xml contains 30 LOC entities; 28 linked and 2 non-linked
# Document btv1b8610788k.tar.gz.tei_segmented_ner.xml contains 13 LOC unique entities
# Document bpt6k1513096g.tar.gz.tei_segmented_ner.xml contains 439 PER entities; 25 linked and 414 non-linked
# Document bpt6k1513096g.tar.gz.tei_segmented_ner.xml contains 15 PER unique entities
# Document bpt6k1513096g.tar.gz.tei_segmented_ner.xml contains 13 LOC entities; 4 linked and 9 non-linked
# Document bpt6k1513096g.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k10900687.tar.gz.tei_segmented_ner.xml contains 519 PER entities; 457 linked and 62 non-linked
# Document bpt6k10900687.tar.gz.tei_segmented_ner.xml contains 49 PER unique entities
# Document bpt6k10900687.tar.gz.tei_segmented_ner.xml contains 10 LOC entities; 7 linked and 3 non-linked
# Document bpt6k10900687.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k1336391.tar.gz.tei_segmented_ner.xml contains 365 PER entities; 283 linked and 82 non-linked
# Document bpt6k1336391.tar.gz.tei_segmented_ner.xml contains 38 PER unique entities
# Document bpt6k1336391.tar.gz.tei_segmented_ner.xml contains 11 LOC entities; 8 linked and 3 non-linked
# Document bpt6k1336391.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k857201r.tar.gz.tei_segmented_ner.xml contains 633 PER entities; 315 linked and 318 non-linked
# Document bpt6k857201r.tar.gz.tei_segmented_ner.xml contains 75 PER unique entities
# Document bpt6k857201r.tar.gz.tei_segmented_ner.xml contains 43 LOC entities; 17 linked and 26 non-linked
# Document bpt6k857201r.tar.gz.tei_segmented_ner.xml contains 7 LOC unique entities
# Document btv1b8622104q.tar.gz.tei_segmented_ner.xml contains 312 PER entities; 187 linked and 125 non-linked
# Document btv1b8622104q.tar.gz.tei_segmented_ner.xml contains 37 PER unique entities
# Document btv1b8622104q.tar.gz.tei_segmented_ner.xml contains 51 LOC entities; 47 linked and 4 non-linked
# Document btv1b8622104q.tar.gz.tei_segmented_ner.xml contains 10 LOC unique entities
# Document bpt6k1280398m.tar.gz.tei_segmented_ner.xml contains 240 PER entities; 73 linked and 167 non-linked
# Document bpt6k1280398m.tar.gz.tei_segmented_ner.xml contains 33 PER unique entities
# Document bpt6k1280398m.tar.gz.tei_segmented_ner.xml contains 10 LOC entities; 7 linked and 3 non-linked
# Document bpt6k1280398m.tar.gz.tei_segmented_ner.xml contains 2 LOC unique entities
# Document bpt6k1280309m.tar.gz.tei_segmented_ner.xml contains 345 PER entities; 276 linked and 69 non-linked
# Document bpt6k1280309m.tar.gz.tei_segmented_ner.xml contains 33 PER unique entities
# Document bpt6k1280309m.tar.gz.tei_segmented_ner.xml contains 12 LOC entities; 10 linked and 2 non-linked
# Document bpt6k1280309m.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k12802899.tar.gz.tei_segmented_ner.xml contains 228 PER entities; 165 linked and 63 non-linked
# Document bpt6k12802899.tar.gz.tei_segmented_ner.xml contains 23 PER unique entities
# Document bpt6k12802899.tar.gz.tei_segmented_ner.xml contains 78 LOC entities; 77 linked and 1 non-linked
# Document bpt6k12802899.tar.gz.tei_segmented_ner.xml contains 9 LOC unique entities
# Document btv1b8622113p.tar.gz.tei_segmented_ner.xml contains 300 PER entities; 37 linked and 263 non-linked
# Document btv1b8622113p.tar.gz.tei_segmented_ner.xml contains 18 PER unique entities
# Document btv1b8622113p.tar.gz.tei_segmented_ner.xml contains 18 LOC entities; 3 linked and 15 non-linked
# Document btv1b8622113p.tar.gz.tei_segmented_ner.xml contains 1 LOC unique entities
# Document bpt6k1090221h.tar.gz.tei_segmented_ner.xml contains 202 PER entities; 99 linked and 103 non-linked
# Document bpt6k1090221h.tar.gz.tei_segmented_ner.xml contains 46 PER unique entities
# Document bpt6k1090221h.tar.gz.tei_segmented_ner.xml contains 54 LOC entities; 36 linked and 18 non-linked
# Document bpt6k1090221h.tar.gz.tei_segmented_ner.xml contains 20 LOC unique entities
# Document bpt6k1090186h.tar.gz.tei_segmented_ner.xml contains 587 PER entities; 237 linked and 350 non-linked
# Document bpt6k1090186h.tar.gz.tei_segmented_ner.xml contains 42 PER unique entities
# Document bpt6k1090186h.tar.gz.tei_segmented_ner.xml contains 23 LOC entities; 17 linked and 6 non-linked
# Document bpt6k1090186h.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k5745752g.tar.gz.tei_segmented_ner.xml contains 1629 PER entities; 660 linked and 969 non-linked
# Document bpt6k5745752g.tar.gz.tei_segmented_ner.xml contains 220 PER unique entities
# Document bpt6k5745752g.tar.gz.tei_segmented_ner.xml contains 54 LOC entities; 34 linked and 20 non-linked
# Document bpt6k5745752g.tar.gz.tei_segmented_ner.xml contains 24 LOC unique entities
# Document bpt6k1280557c.tar.gz.tei_segmented_ner.xml contains 531 PER entities; 365 linked and 166 non-linked
# Document bpt6k1280557c.tar.gz.tei_segmented_ner.xml contains 33 PER unique entities
# Document bpt6k1280557c.tar.gz.tei_segmented_ner.xml contains 4 LOC entities; 4 linked and 0 non-linked
# Document bpt6k1280557c.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k10900457.tar.gz.tei_segmented_ner.xml contains 408 PER entities; 65 linked and 343 non-linked
# Document bpt6k10900457.tar.gz.tei_segmented_ner.xml contains 26 PER unique entities
# Document bpt6k10900457.tar.gz.tei_segmented_ner.xml contains 10 LOC entities; 4 linked and 6 non-linked
# Document bpt6k10900457.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k15132891.tar.gz.tei_segmented_ner.xml contains 314 PER entities; 179 linked and 135 non-linked
# Document bpt6k15132891.tar.gz.tei_segmented_ner.xml contains 65 PER unique entities
# Document bpt6k15132891.tar.gz.tei_segmented_ner.xml contains 36 LOC entities; 24 linked and 12 non-linked
# Document bpt6k15132891.tar.gz.tei_segmented_ner.xml contains 15 LOC unique entities
# Document btv1b8610816f.tar.gz.tei_segmented_ner.xml contains 521 PER entities; 352 linked and 169 non-linked
# Document btv1b8610816f.tar.gz.tei_segmented_ner.xml contains 64 PER unique entities
# Document btv1b8610816f.tar.gz.tei_segmented_ner.xml contains 67 LOC entities; 46 linked and 21 non-linked
# Document btv1b8610816f.tar.gz.tei_segmented_ner.xml contains 10 LOC unique entities
# Document btv1b8610793w.tar.gz.tei_segmented_ner.xml contains 506 PER entities; 322 linked and 184 non-linked
# Document btv1b8610793w.tar.gz.tei_segmented_ner.xml contains 30 PER unique entities
# Document btv1b8610793w.tar.gz.tei_segmented_ner.xml contains 6 LOC entities; 4 linked and 2 non-linked
# Document btv1b8610793w.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k6364578h.tar.gz.tei_segmented_ner.xml contains 342 PER entities; 43 linked and 299 non-linked
# Document bpt6k6364578h.tar.gz.tei_segmented_ner.xml contains 21 PER unique entities
# Document bpt6k6364578h.tar.gz.tei_segmented_ner.xml contains 113 LOC entities; 101 linked and 12 non-linked
# Document bpt6k6364578h.tar.gz.tei_segmented_ner.xml contains 10 LOC unique entities
# Document bpt6k859380.tar.gz.tei_segmented_ner.xml contains 386 PER entities; 194 linked and 192 non-linked
# Document bpt6k859380.tar.gz.tei_segmented_ner.xml contains 47 PER unique entities
# Document bpt6k859380.tar.gz.tei_segmented_ner.xml contains 55 LOC entities; 48 linked and 7 non-linked
# ...
# Document bpt6k5744744m.tar.gz.tei_segmented_ner.xml contains 81 PER unique entities
# Document bpt6k5744744m.tar.gz.tei_segmented_ner.xml contains 22 LOC entities; 11 linked and 11 non-linked
# Document bpt6k5744744m.tar.gz.tei_segmented_ner.xml contains 11 LOC unique entities
# Document bpt6k10404954.tar.gz.tei_segmented_ner.xml contains 411 PER entities; 180 linked and 231 non-linked
# Document bpt6k10404954.tar.gz.tei_segmented_ner.xml contains 35 PER unique entities
# Document bpt6k10404954.tar.gz.tei_segmented_ner.xml contains 3 LOC entities; 0 linked and 3 non-linked
# Document bpt6k10404954.tar.gz.tei_segmented_ner.xml contains 0 LOC unique entities
# Error processing document 553: list index out of range
# Document bpt6k12802951.tar.gz.tei_segmented_ner.xml contains 348 PER entities; 243 linked and 105 non-linked
# Document bpt6k12802951.tar.gz.tei_segmented_ner.xml contains 48 PER unique entities
# Document bpt6k12802951.tar.gz.tei_segmented_ner.xml contains 53 LOC entities; 50 linked and 3 non-linked
# Document bpt6k12802951.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k1090060x.tar.gz.tei_segmented_ner.xml contains 521 PER entities; 207 linked and 314 non-linked
# Document bpt6k1090060x.tar.gz.tei_segmented_ner.xml contains 97 PER unique entities
# Document bpt6k1090060x.tar.gz.tei_segmented_ner.xml contains 40 LOC entities; 22 linked and 18 non-linked
# Document bpt6k1090060x.tar.gz.tei_segmented_ner.xml contains 14 LOC unique entities
# Document bpt6k5800744h.tar.gz.tei_segmented_ner.xml contains 1032 PER entities; 415 linked and 617 non-linked
# Document bpt6k5800744h.tar.gz.tei_segmented_ner.xml contains 104 PER unique entities
# Document bpt6k5800744h.tar.gz.tei_segmented_ner.xml contains 24 LOC entities; 15 linked and 9 non-linked
# Document bpt6k5800744h.tar.gz.tei_segmented_ner.xml contains 8 LOC unique entities
# Document bpt6k8569801.tar.gz.tei_segmented_ner.xml contains 92 PER entities; 38 linked and 54 non-linked
# Document bpt6k8569801.tar.gz.tei_segmented_ner.xml contains 20 PER unique entities
# Document bpt6k8569801.tar.gz.tei_segmented_ner.xml contains 7 LOC entities; 7 linked and 0 non-linked
# Document bpt6k8569801.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k1281031q.tar.gz.tei_segmented_ner.xml contains 625 PER entities; 501 linked and 124 non-linked
# Document bpt6k1281031q.tar.gz.tei_segmented_ner.xml contains 43 PER unique entities
# Document bpt6k1281031q.tar.gz.tei_segmented_ner.xml contains 8 LOC entities; 7 linked and 1 non-linked
# Document bpt6k1281031q.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k855192c.tar.gz.tei_segmented_ner.xml contains 184 PER entities; 98 linked and 86 non-linked
# Document bpt6k855192c.tar.gz.tei_segmented_ner.xml contains 32 PER unique entities
# Document bpt6k855192c.tar.gz.tei_segmented_ner.xml contains 11 LOC entities; 4 linked and 7 non-linked
# Document bpt6k855192c.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k1513909d.tar.gz.tei_segmented_ner.xml contains 309 PER entities; 140 linked and 169 non-linked
# Document bpt6k1513909d.tar.gz.tei_segmented_ner.xml contains 37 PER unique entities
# Document bpt6k1513909d.tar.gz.tei_segmented_ner.xml contains 97 LOC entities; 92 linked and 5 non-linked
# Document bpt6k1513909d.tar.gz.tei_segmented_ner.xml contains 9 LOC unique entities
# Document bpt6k63646887.tar.gz.tei_segmented_ner.xml contains 268 PER entities; 135 linked and 133 non-linked
# Document bpt6k63646887.tar.gz.tei_segmented_ner.xml contains 24 PER unique entities
# Document bpt6k63646887.tar.gz.tei_segmented_ner.xml contains 17 LOC entities; 12 linked and 5 non-linked
# Document bpt6k63646887.tar.gz.tei_segmented_ner.xml contains 10 LOC unique entities
# Document bpt6k65869952.tar.gz.tei_segmented_ner.xml contains 3802 PER entities; 2902 linked and 900 non-linked
# Document bpt6k65869952.tar.gz.tei_segmented_ner.xml contains 427 PER unique entities
# Document bpt6k65869952.tar.gz.tei_segmented_ner.xml contains 112 LOC entities; 87 linked and 25 non-linked
# Document bpt6k65869952.tar.gz.tei_segmented_ner.xml contains 35 LOC unique entities
# Document bpt6k10901764.tar.gz.tei_segmented_ner.xml contains 185 PER entities; 112 linked and 73 non-linked
# Document bpt6k10901764.tar.gz.tei_segmented_ner.xml contains 68 PER unique entities
# Document bpt6k10901764.tar.gz.tei_segmented_ner.xml contains 7 LOC entities; 4 linked and 3 non-linked
# Document bpt6k10901764.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k15106882.tar.gz.tei_segmented_ner.xml contains 307 PER entities; 150 linked and 157 non-linked
# Document bpt6k15106882.tar.gz.tei_segmented_ner.xml contains 36 PER unique entities
# Document bpt6k15106882.tar.gz.tei_segmented_ner.xml contains 10 LOC entities; 5 linked and 5 non-linked
# Document bpt6k15106882.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k1097890.tar.gz.tei_segmented_ner.xml contains 262 PER entities; 30 linked and 232 non-linked
# Document bpt6k1097890.tar.gz.tei_segmented_ner.xml contains 12 PER unique entities
# Document bpt6k1097890.tar.gz.tei_segmented_ner.xml contains 17 LOC entities; 10 linked and 7 non-linked
# Document bpt6k1097890.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document btv1b8626162d.tar.gz.tei_segmented_ner.xml contains 143 PER entities; 53 linked and 90 non-linked
# Document btv1b8626162d.tar.gz.tei_segmented_ner.xml contains 23 PER unique entities
# Document btv1b8626162d.tar.gz.tei_segmented_ner.xml contains 9 LOC entities; 8 linked and 1 non-linked
# Document btv1b8626162d.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k6269158p.tar.gz.tei_segmented_ner.xml contains 640 PER entities; 133 linked and 507 non-linked
# Document bpt6k6269158p.tar.gz.tei_segmented_ner.xml contains 50 PER unique entities
# Document bpt6k6269158p.tar.gz.tei_segmented_ner.xml contains 8 LOC entities; 3 linked and 5 non-linked
# Document bpt6k6269158p.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document btv1b86221039.tar.gz.tei_segmented_ner.xml contains 483 PER entities; 209 linked and 274 non-linked
# Document btv1b86221039.tar.gz.tei_segmented_ner.xml contains 32 PER unique entities
# Document btv1b86221039.tar.gz.tei_segmented_ner.xml contains 14 LOC entities; 13 linked and 1 non-linked
# Document btv1b86221039.tar.gz.tei_segmented_ner.xml contains 10 LOC unique entities
# Document bpt6k1280578j.tar.gz.tei_segmented_ner.xml contains 554 PER entities; 196 linked and 358 non-linked
# Document bpt6k1280578j.tar.gz.tei_segmented_ner.xml contains 58 PER unique entities
# Document bpt6k1280578j.tar.gz.tei_segmented_ner.xml contains 18 LOC entities; 10 linked and 8 non-linked
# Document bpt6k1280578j.tar.gz.tei_segmented_ner.xml contains 8 LOC unique entities
# Document btv1b8610783h.tar.gz.tei_segmented_ner.xml contains 696 PER entities; 526 linked and 170 non-linked
# Document btv1b8610783h.tar.gz.tei_segmented_ner.xml contains 65 PER unique entities
# Document btv1b8610783h.tar.gz.tei_segmented_ner.xml contains 18 LOC entities; 17 linked and 1 non-linked
# Document btv1b8610783h.tar.gz.tei_segmented_ner.xml contains 10 LOC unique entities
# Document bpt6k1280460h.tar.gz.tei_segmented_ner.xml contains 143 PER entities; 35 linked and 108 non-linked
# Document bpt6k1280460h.tar.gz.tei_segmented_ner.xml contains 17 PER unique entities
# Document bpt6k1280460h.tar.gz.tei_segmented_ner.xml contains 6 LOC entities; 6 linked and 0 non-linked
# Document bpt6k1280460h.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k5849655v.tar.gz.tei_segmented_ner.xml contains 149 PER entities; 52 linked and 97 non-linked
# Document bpt6k5849655v.tar.gz.tei_segmented_ner.xml contains 18 PER unique entities
# Document bpt6k5849655v.tar.gz.tei_segmented_ner.xml contains 24 LOC entities; 23 linked and 1 non-linked
# Document bpt6k5849655v.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k5752605t.tar.gz.tei_segmented_ner.xml contains 303 PER entities; 89 linked and 214 non-linked
# Document bpt6k5752605t.tar.gz.tei_segmented_ner.xml contains 45 PER unique entities
# Document bpt6k5752605t.tar.gz.tei_segmented_ner.xml contains 20 LOC entities; 15 linked and 5 non-linked
# Document bpt6k5752605t.tar.gz.tei_segmented_ner.xml contains 8 LOC unique entities
# Document bpt6k1097788.tar.gz.tei_segmented_ner.xml contains 247 PER entities; 131 linked and 116 non-linked
# Document bpt6k1097788.tar.gz.tei_segmented_ner.xml contains 41 PER unique entities
# Document bpt6k1097788.tar.gz.tei_segmented_ner.xml contains 27 LOC entities; 23 linked and 4 non-linked
# Document bpt6k1097788.tar.gz.tei_segmented_ner.xml contains 13 LOC unique entities
# Document bpt6k1513897n.tar.gz.tei_segmented_ner.xml contains 857 PER entities; 284 linked and 573 non-linked
# Document bpt6k1513897n.tar.gz.tei_segmented_ner.xml contains 87 PER unique entities
# Document bpt6k1513897n.tar.gz.tei_segmented_ner.xml contains 20 LOC entities; 13 linked and 7 non-linked
# Document bpt6k1513897n.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k1512308m.tar.gz.tei_segmented_ner.xml contains 125 PER entities; 81 linked and 44 non-linked
# Document bpt6k1512308m.tar.gz.tei_segmented_ner.xml contains 21 PER unique entities
# Document bpt6k1512308m.tar.gz.tei_segmented_ner.xml contains 2 LOC entities; 1 linked and 1 non-linked
# Document bpt6k1512308m.tar.gz.tei_segmented_ner.xml contains 1 LOC unique entities
# Document bpt6k1115609.tar.gz.tei_segmented_ner.xml contains 525 PER entities; 235 linked and 290 non-linked
# Document bpt6k1115609.tar.gz.tei_segmented_ner.xml contains 60 PER unique entities
# Document bpt6k1115609.tar.gz.tei_segmented_ner.xml contains 39 LOC entities; 23 linked and 16 non-linked
# Document bpt6k1115609.tar.gz.tei_segmented_ner.xml contains 13 LOC unique entities
# Document bpt6k5789985w.tar.gz.tei_segmented_ner.xml contains 367 PER entities; 230 linked and 137 non-linked
# Document bpt6k5789985w.tar.gz.tei_segmented_ner.xml contains 34 PER unique entities
# Document bpt6k5789985w.tar.gz.tei_segmented_ner.xml contains 62 LOC entities; 59 linked and 3 non-linked
# Document bpt6k5789985w.tar.gz.tei_segmented_ner.xml contains 13 LOC unique entities
# Document bpt6k8414817.tar.gz.tei_segmented_ner.xml contains 279 PER entities; 195 linked and 84 non-linked
# Document bpt6k8414817.tar.gz.tei_segmented_ner.xml contains 25 PER unique entities
# Document bpt6k8414817.tar.gz.tei_segmented_ner.xml contains 15 LOC entities; 13 linked and 2 non-linked
# Document bpt6k8414817.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k6283934q.tar.gz.tei_segmented_ner.xml contains 260 PER entities; 92 linked and 168 non-linked
# Document bpt6k6283934q.tar.gz.tei_segmented_ner.xml contains 59 PER unique entities
# Document bpt6k6283934q.tar.gz.tei_segmented_ner.xml contains 13 LOC entities; 9 linked and 4 non-linked
# Document bpt6k6283934q.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k1090053s.tar.gz.tei_segmented_ner.xml contains 313 PER entities; 74 linked and 239 non-linked
# Document bpt6k1090053s.tar.gz.tei_segmented_ner.xml contains 24 PER unique entities
# Document bpt6k1090053s.tar.gz.tei_segmented_ner.xml contains 5 LOC entities; 4 linked and 1 non-linked
# Document bpt6k1090053s.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k15100368.tar.gz.tei_segmented_ner.xml contains 1896 PER entities; 941 linked and 955 non-linked
# Document bpt6k15100368.tar.gz.tei_segmented_ner.xml contains 193 PER unique entities
# Document bpt6k15100368.tar.gz.tei_segmented_ner.xml contains 140 LOC entities; 100 linked and 40 non-linked
# Document bpt6k15100368.tar.gz.tei_segmented_ner.xml contains 25 LOC unique entities
# Document bpt6k5626158d.tar.gz.tei_segmented_ner.xml contains 645 PER entities; 287 linked and 358 non-linked
# Document bpt6k5626158d.tar.gz.tei_segmented_ner.xml contains 72 PER unique entities
# Document bpt6k5626158d.tar.gz.tei_segmented_ner.xml contains 52 LOC entities; 32 linked and 20 non-linked
# Document bpt6k5626158d.tar.gz.tei_segmented_ner.xml contains 23 LOC unique entities
# Document bpt6k852916s.tar.gz.tei_segmented_ner.xml contains 529 PER entities; 162 linked and 367 non-linked
# Document bpt6k852916s.tar.gz.tei_segmented_ner.xml contains 25 PER unique entities
# Document bpt6k852916s.tar.gz.tei_segmented_ner.xml contains 12 LOC entities; 7 linked and 5 non-linked
# Document bpt6k852916s.tar.gz.tei_segmented_ner.xml contains 5 LOC unique entities
# Document bpt6k12804148.tar.gz.tei_segmented_ner.xml contains 363 PER entities; 57 linked and 306 non-linked
# Document bpt6k12804148.tar.gz.tei_segmented_ner.xml contains 35 PER unique entities
# Document bpt6k12804148.tar.gz.tei_segmented_ner.xml contains 20 LOC entities; 18 linked and 2 non-linked
# Document bpt6k12804148.tar.gz.tei_segmented_ner.xml contains 7 LOC unique entities
# Document bpt6k10901037.tar.gz.tei_segmented_ner.xml contains 344 PER entities; 279 linked and 65 non-linked
# Document bpt6k10901037.tar.gz.tei_segmented_ner.xml contains 35 PER unique entities
# Document bpt6k10901037.tar.gz.tei_segmented_ner.xml contains 7 LOC entities; 7 linked and 0 non-linked
# Document bpt6k10901037.tar.gz.tei_segmented_ner.xml contains 3 LOC unique entities
# Document bpt6k10900954.tar.gz.tei_segmented_ner.xml contains 501 PER entities; 206 linked and 295 non-linked
# Document bpt6k10900954.tar.gz.tei_segmented_ner.xml contains 46 PER unique entities
# Document bpt6k10900954.tar.gz.tei_segmented_ner.xml contains 28 LOC entities; 23 linked and 5 non-linked
# Document bpt6k10900954.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k9905809.tar.gz.tei_segmented_ner.xml contains 1881 PER entities; 1174 linked and 707 non-linked
# Document bpt6k9905809.tar.gz.tei_segmented_ner.xml contains 163 PER unique entities
# Document bpt6k9905809.tar.gz.tei_segmented_ner.xml contains 152 LOC entities; 132 linked and 20 non-linked
# Document bpt6k9905809.tar.gz.tei_segmented_ner.xml contains 33 LOC unique entities
# Document bpt6k3118700.tar.gz.tei_segmented_ner.xml contains 162 PER entities; 103 linked and 59 non-linked
# Document bpt6k3118700.tar.gz.tei_segmented_ner.xml contains 36 PER unique entities
# Document bpt6k3118700.tar.gz.tei_segmented_ner.xml contains 19 LOC entities; 13 linked and 6 non-linked
# Document bpt6k3118700.tar.gz.tei_segmented_ner.xml contains 6 LOC unique entities
# Document bpt6k58122453.tar.gz.tei_segmented_ner.xml contains 529 PER entities; 123 linked and 406 non-linked
# Document bpt6k58122453.tar.gz.tei_segmented_ner.xml contains 49 PER unique entities
# Document bpt6k58122453.tar.gz.tei_segmented_ner.xml contains 32 LOC entities; 25 linked and 7 non-linked
# Document bpt6k58122453.tar.gz.tei_segmented_ner.xml contains 11 LOC unique entities
# Document bpt6k857217c.tar.gz.tei_segmented_ner.xml contains 192 PER entities; 94 linked and 98 non-linked
# Document bpt6k857217c.tar.gz.tei_segmented_ner.xml contains 21 PER unique entities
# Document bpt6k857217c.tar.gz.tei_segmented_ner.xml contains 5 LOC entities; 5 linked and 0 non-linked
# Document bpt6k857217c.tar.gz.tei_segmented_ner.xml contains 4 LOC unique entities
# Document bpt6k9807756q.tar.gz.tei_segmented_ner.xml contains 324 PER entities; 45 linked and 279 non-linked
# Document bpt6k9807756q.tar.gz.tei_segmented_ner.xml contains 27 PER unique entities
# Document bpt6k9807756q.tar.gz.tei_segmented_ner.xml contains 82 LOC entities; 72 linked and 10 non-linked
# Document bpt6k9807756q.tar.gz.tei_segmented_ner.xml contains 11 LOC unique entities
# Document bpt6k10901979.tar.gz.tei_segmented_ner.xml contains 464 PER entities; 138 linked and 326 non-linked
# Document bpt6k10901979.tar.gz.tei_segmented_ner.xml contains 40 PER unique entities
# Document bpt6k10901979.tar.gz.tei_segmented_ner.xml contains 36 LOC entities; 28 linked and 8 non-linked
# Document bpt6k10901979.tar.gz.tei_segmented_ner.xml contains 8 LOC unique entities

# %%
spacy_doc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 spacy_doc
#
# NameError: name 'spacy_doc' is not defined
