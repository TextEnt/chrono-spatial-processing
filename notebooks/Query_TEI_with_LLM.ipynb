# %% [markdown]
# # NER to LLM

# %%
import os
from lxml import etree
import pandas as pd
from openai import OpenAI
import requests
from ollama import chat
import json
import uuid
from tqdm import tqdm
from collections import Counter
from dotenv import load_dotenv

# %% [markdown]
# ## Extracting XML elements

# %%
# to install ollama python library before
# !OLLAMA_HOST=127.0.0.1:11435 ollama serve

# %%
def extract_elements(xml_file):
    namespaces = {'tei': 'http://www.tei-c.org/ns/1.0'}
    with open(xml_file, 'rb') as file:
        tree = etree.parse(file)
    
    elements = {
        'placeName': tree.xpath('/tei:TEI/tei:text/tei:body/tei:sp/tei:ab/tei:seg/tei:reg/tei:placeName', namespaces=namespaces),
        'persName': tree.xpath('/tei:TEI/tei:text/tei:body/tei:sp/tei:ab/tei:seg/tei:reg/tei:persName', namespaces=namespaces),
        'target': tree.xpath('//tei:ptr/@target', namespaces=namespaces),
        'author': tree.xpath('//tei:author/tei:persName/text()', namespaces=namespaces),
        'title': tree.xpath('//tei:title/text()', namespaces=namespaces),
        'pubPlace': tree.xpath('//tei:pubPlace/text()', namespaces=namespaces),
        'date': tree.xpath('//tei:TEI/tei:teiHeader/tei:fileDesc/tei:sourceDesc/tei:bibl/tei:date/@when', namespaces=namespaces)
    }
    
    return tree, elements

# %%
def process_xml_folder(folder_path):
    data_place = []
    data_pers = []
    
    for filename in tqdm(os.listdir(folder_path), desc="Processing XML files"):
        if filename.endswith(".xml"):
            file_path = os.path.join(folder_path, filename)
            tree, elements = extract_elements(file_path)
            
            placeNames = [el.text for el in elements['placeName']]
            persNames = [el.text for el in elements['persName']]
            target = elements['target'][0] if elements['target'] else None
            author = elements['author'][0] if elements['author'] else None
            title = elements['title'][0] if elements['title'] else None
            pubPlace = elements['pubPlace'][0] if elements['pubPlace'] else None
            date = elements['date'][0] if elements['date'] else None
            
            placeName_counts = Counter(placeNames)
            persName_counts = Counter(persNames)
            
            for placeName in set(placeNames):
                data_place.append({
                    'target': target,
                    'title': title,
                    'pubPlace': pubPlace,
                    'date': date,
                    'author': author,
                    'place': placeName,
                    'placeName_num': placeName_counts[placeName]
                })
                
            for persName in set(persNames):
                data_pers.append({
                    'target': target,
                    'title': title,
                    'pubPlace': pubPlace,
                    'date': date,
                    'author': author,
                    'person': persName,
                    'persName_num': persName_counts[persName]
                })
    
    return data_place, data_pers

# %%
def create_dataframes(data_place, data_pers):
    df_place = pd.DataFrame(data_place)
    df_pers = pd.DataFrame(data_pers)
    
    df_place = df_place.drop_duplicates().sort_values(by='placeName_num', ascending=False)
    df_pers = df_pers.drop_duplicates().sort_values(by='persName_num', ascending=False)
    
    return df_place, df_pers

# %%
folder_path = '/Users/nicola/Documents/Academia/Projects/TextEnt/Processing/NER'

data_place, data_pers = process_xml_folder(folder_path)
df_place, df_pers = create_dataframes(data_place, data_pers)
# Out:
# Processing XML files: 100%|██████████| 594/594 [00:02<00:00, 267.59it/s]

# %%
df_place["place"] = df_place["place"].str.lower()
df_place.head(10)
# Out:
#                                               target  \
# 805   http://catalogue.bnf.fr/ark:/12148/cb447294587
# 5273  http://catalogue.bnf.fr/ark:/12148/cb38652730w
# 2942  http://catalogue.bnf.fr/ark:/12148/cb35285434p
# 2798  http://catalogue.bnf.fr/ark:/12148/cb30881255g
# 3815  http://catalogue.bnf.fr/ark:/12148/cb44729688q
# 5252  http://catalogue.bnf.fr/ark:/12148/cb38652730w
# 876   http://catalogue.bnf.fr/ark:/12148/cb38650322p
# 4462  http://catalogue.bnf.fr/ark:/12148/cb303328602
# 3062  http://catalogue.bnf.fr/ark:/12148/cb352854320
# 4556  http://catalogue.bnf.fr/ark:/12148/cb38650916d
#
#                                                   title  pubPlace  date  \
# 805   Le Théâtre d'Alexandre Hardy, Parisien, tome q...  Grenoble  1626
# 5273                                        Athénaïs...  Grenoble  1700
# 2942  Le Dictateur romain : tragédie dédiée à Mgr le...  Grenoble  1647
# 2798                  Le dictateur romain , tragédie...  Grenoble  1646
# 3815                          Le Jeune Marius, tragédie  Grenoble  1669
# 5252                                        Athénaïs...  Grenoble  1700
# 876          Horace, tragédie par le Sieur Corneille...  Grenoble  1647
# 4462           Oeuvres poétiques du sieur Desmarets,...  Grenoble  1641
# 3062                          Europe : comédie héroïque  Grenoble  1645
# 4556  La Critique de l'Escole des femmes, comédie pa...  Grenoble  1663
#
#                                author     place  placeName_num
# 805                  Hardy, Alexandre    clitie            108
# 5273                  Pradon, Nicolas      rome             78
# 2942                 Mareschal, André      rome             77
# 2798                 Mareschal, André      rome             73
# 3815                    Boyer, Claude      rome             69
# 5252                  Pradon, Nicolas  carthage             67
# 876                 Corneille, Pierre      rome             67
# 4462  Desmarets de Saint-Sorlin, Jean    europe             67
# 3062  Desmarets de Saint-Sorlin, Jean    europe             64
# 4556                          Molière    uranie             63

# %%
df_pers["person"] = df_pers["person"].str.lower()
df_pers.head()
# Out:
#                                                target  \
# 13386  http://catalogue.bnf.fr/ark:/12148/cb309580795
# 35278  http://catalogue.bnf.fr/ark:/12148/cb33624900p
# 22159  http://catalogue.bnf.fr/ark:/12148/cb38650754d
# 52296  http://catalogue.bnf.fr/ark:/12148/cb309584558
# 4757   http://catalogue.bnf.fr/ark:/12148/cb38651168p
#
#                                                    title  pubPlace  date  \
# 13386                 Les oeuvres de Monsieur Molière...  Grenoble  1666
# 35278  Le Théâtre italien ou le recueil de toutes les...  Grenoble  1694
# 22159                 Les Oeuvres de Monsieur Molière...  Grenoble  1673
# 52296  Le bourgeois gentilhomme, comédie-balet faite ...  Grenoble  1673
# 4757   Le bourgeois gentilhomme. Comedie-ballet. Fait...  Grenoble  1671
#
#         author             person  persName_num
# 13386  Molière         mascarille           412
# 35278     None          colombine           398
# 22159  Molière         mascarille           396
# 52296  Molière  monsieur jourdain           323
# 4757   Molière                  m           323

# %% [markdown]
# ### Only top results

# %%
df_person_top_five = df_pers.groupby('target', group_keys=False).apply(lambda x: x.nlargest(5, 'persName_num'))
# Out:
# /var/folders/y2/1xj8qbr56dvf504d6g874cp00000gn/T/ipykernel_68773/3108880041.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_person_top_five = df_pers.groupby('target', group_keys=False).apply(lambda x: x.nlargest(5, 'persName_num'))

# %%
df_person_top_five.head(10)
# Out:
#                                                target  \
# 12961  http://catalogue.bnf.fr/ark:/12148/cb30000572m
# 12955  http://catalogue.bnf.fr/ark:/12148/cb30000572m
# 12980  http://catalogue.bnf.fr/ark:/12148/cb30000572m
# 12984  http://catalogue.bnf.fr/ark:/12148/cb30000572m
# 12978  http://catalogue.bnf.fr/ark:/12148/cb30000572m
# 56955  http://catalogue.bnf.fr/ark:/12148/cb30000577b
# 56975  http://catalogue.bnf.fr/ark:/12148/cb30000577b
# 56948  http://catalogue.bnf.fr/ark:/12148/cb30000577b
# 56986  http://catalogue.bnf.fr/ark:/12148/cb30000577b
# 56983  http://catalogue.bnf.fr/ark:/12148/cb30000577b
#
#                                         title  pubPlace  date  \
# 12961  Argélie, reyne de Thessalie . Tragédie  Grenoble  1674
# 12955  Argélie, reyne de Thessalie . Tragédie  Grenoble  1674
# 12980  Argélie, reyne de Thessalie . Tragédie  Grenoble  1674
# 12984  Argélie, reyne de Thessalie . Tragédie  Grenoble  1674
# 12978  Argélie, reyne de Thessalie . Tragédie  Grenoble  1674
# 56955     Coriolan , tragédie. Par M. Abeille  Grenoble  1676
# 56975     Coriolan , tragédie. Par M. Abeille  Grenoble  1676
# 56948     Coriolan , tragédie. Par M. Abeille  Grenoble  1676
# 56986     Coriolan , tragédie. Par M. Abeille  Grenoble  1676
# 56983     Coriolan , tragédie. Par M. Abeille  Grenoble  1676
#
#                  author    person  persName_num
# 12961  Abeille, Gaspard   argelie            46
# 12955  Abeille, Gaspard  timagène            35
# 12980  Abeille, Gaspard     arcas            16
# 12984  Abeille, Gaspard    phœnix            15
# 12978  Abeille, Gaspard     dione            13
# 56955  Abeille, Gaspard  virgilie            44
# 56975  Abeille, Gaspard  coriolan            32
# 56948  Abeille, Gaspard   camille            30
# 56986  Abeille, Gaspard    aufide            28
# 56983  Abeille, Gaspard     albin            23

# %%
df_place_top_two = df_place.groupby('target', group_keys=False).apply(lambda x: x.nlargest(2, 'placeName_num'))
# Out:
# /var/folders/y2/1xj8qbr56dvf504d6g874cp00000gn/T/ipykernel_68773/37667048.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_place_top_two = df_place.groupby('target', group_keys=False).apply(lambda x: x.nlargest(2, 'placeName_num'))

# %%
df_place_top_two['uuid'] = df_place_top_two['place'].apply(lambda x: str(uuid.uuid5(uuid.NAMESPACE_DNS, x)))

# %%
df_place_top_two.head(5)
# Out:
#                                               target  \
# 1164  http://catalogue.bnf.fr/ark:/12148/cb30000572m
# 1162  http://catalogue.bnf.fr/ark:/12148/cb30000572m
# 5039  http://catalogue.bnf.fr/ark:/12148/cb30000577b
# 5038  http://catalogue.bnf.fr/ark:/12148/cb30000577b
# 1656  http://catalogue.bnf.fr/ark:/12148/cb30040061d
#
#                                                   title  pubPlace  date  \
# 1164             Argélie, reyne de Thessalie . Tragédie  Grenoble  1674
# 1162             Argélie, reyne de Thessalie . Tragédie  Grenoble  1674
# 5039                Coriolan , tragédie. Par M. Abeille  Grenoble  1676
# 5038                Coriolan , tragédie. Par M. Abeille  Grenoble  1676
# 1656  Dipné, infante d'Irlande , tragédie, dédiée à ...  Grenoble  1668
#
#                  author   place  placeName_num  \
# 1164   Abeille, Gaspard  clytie             10
# 1162   Abeille, Gaspard  mycène              2
# 5039   Abeille, Gaspard    rome             59
# 5038   Abeille, Gaspard    lrin              2
# 1656  Aure, François d'  mogale              5
#
#                                       uuid
# 1164  97de832a-53f8-5e68-bff8-b6acd68630ff
# 1162  4496fd5d-0028-59f4-8e0e-91872008ae6a
# 5039  cbef6bfb-ce53-50a5-a154-fb3e13aa618e
# 5038  0efc0bf9-50b2-5d36-a979-d8d9c1173a55
# 1656  228538c2-3a68-5984-8bf2-3880e2f7747c

# %% [markdown]
# #### sample creation (testing purpose)

# %%
df_place_top_two_sample = df_place_top_two.head(50)

# %%
df_person_top_five_sample = df_person_top_five.head(50)

# %% [markdown]
# ### Sample: Combine Persons and Places together

# %%
columns_to_keep = ['target', 'title', 'pubPlace', 'date', 'author']

# %%
# using sample df here, to change
df_pers_place = pd.concat([df_person_top_five_sample, df_place_top_two_sample], ignore_index=True)

# %%
df_sample = df_pers_place[columns_to_keep + ['place', 'uuid', 'placeName_num', 'person', 'persName_num']]

# %% [markdown]
# ## Llama 3.2

# %% [markdown]
# ### Take place and persons, but no title of the play

# %%
# Function to query Ollama for each target
def get_timeframe_for_play(group):
    target = group['target'].iloc[0]  
    places = ", ".join(group['place'].dropna().astype(str).unique())  # concat unique places for the same target
    persons = ", ".join(group['person'].dropna().astype(str).unique())  # concat unique persons for the same target

    # prompt
    prompt = (
        f"I have a play with the id {target} happening in these places: {places}, "
        f"and with these characters: {persons}. Given this information, suggest me what could be the timeframe where the play takes place. "
        f"I do not need the precise and exact date, but the timespan, formatted in ISO, of the period where the play could have taken place. "
        f"If the information provided are not enough to determine a timeframe, give me your best guess. Respond only with valid JSON."
        f"Do not write an introduction or summary. For the JSON use the form:\n\n"
        f"{{\n  \"reason\": \"why has been chosen\",\n \"period\": \"period_identified\",\n  \"timeframe_start\": \"ISO value of the start\",\n  \"timeframe_end\": \"ISO value of the end\"\n}}\n\n"
        f"The values in the JSON \"timeframe_start\" and \"timeframe_end\" should always be a single valid ISO date in the form YYYY-MM-DD"

    )


    try:
        stream = chat(
            model='llama3.2',
            messages=[{'role': 'user', 'content': prompt}],
            stream=True,
        )

        response_data = ""
        for chunk in stream:
            if 'message' in chunk and 'content' in chunk['message']:
                response_data += chunk['message']['content']

        print(f"Full response for target {target}: {response_data}")

        response_json = json.loads(response_data.strip())

        return {
            "target": target,
            "reason": response_json.get("reason"),
            "period": response_json.get("period"),
            "time_llama_start": response_json.get("timeframe_start"),
            "time_llama_end": response_json.get("timeframe_end"),
        }

    except json.JSONDecodeError as e:
        print(f"JSON decode error for target {target}: {e}")
        print(f"Response data: {response_data}")
        return {
            "target": target,
            "reason": None,
            "period": None,
            "time_llama_start": None,
            "time_llama_end": None,
        }
    except Exception as e:
        print(f"Error for target {target}: {e}")
        return {
            "target": target,
            "reason": None,
            "period": None,
            "time_llama_start": None,
            "time_llama_end": None,
        }

# %%
results = []
for target, group in df_sample.groupby('target'):
    result = get_timeframe_for_play(group)
    if result:
        results.append(result)
# Out:
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30000572m: {
#   "reason": "Geographical locations and mythological characters suggest a Late Helladic period, which corresponds to the Mycenaean civilization.",
#   "period": "Late Helladic",
#   "timeframe_start": "1200-1150 BCE",
#   "timeframe_end": "1100-1050 BCE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30000577b: {
#   "reason": "Given that Coriolanus is a play by William Shakespeare, the timeframe can be associated with his life and works.",
#   "period": "Roman Republic",
#   "timeframe_start": "410-396 BCE",
#   "timeframe_end": "395 BCE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30040061d: {
#   "reason": "Geographic locations suggest a Mediterranean or Middle Eastern setting, which often corresponds to ancient periods.",
#   "period": "Ancient",
#   "timeframe_start": "750-0BCE",
#   "timeframe_end": "300-0BCE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30040062r: {
#   "reason": "Georges Bataille was a French literary figure associated with the 'Golgotha' play, but there's no direct connection to Gertrude Stein.",
#   "period": "20th century",
#   "timeframe_start": "1890-01-01",
#   "timeframe_end": "1933-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30041092x: {
#   "reason": "Character's age, cultural references, and geographical locations suggest a timeframe between the late 18th century to the mid-19th century.",
#   "period": "Modern",
#   "timeframe_start": "1789-01-01",
#   "timeframe_end": "1850-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb300410980: {
#   "reason": "Geographical location suggests ancient or classical setting",
#   "period": "Ancient Mediterranean",
#   "timeframe_start": "750-0000-00-00",
#   "timeframe_end": "500-0000-00-00"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb300550714: {
#   "reason": "Rome's involvement as Aquilie is unclear, but it was a Roman province from 264 BC to 1st century AD. Tarquin, the last king of Rome, reigned until 509 BC. The absence of more specific references to historical figures or events makes it difficult to pinpoint an exact timeframe.",
#   "period": "Ancient Rome",
#   "timeframe_start": "509-001D",
#   "timeframe_end": "264-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb300581040: {
#   "reason": "Geographic locations Rome, France suggest a timeframe before the Renaissance period, as this places are closely associated with the Baroque era.",
#  "period": "Baroque",
#  "timeframe_start": "1650-01-01",
#  "timeframe_end": "1750-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb300581118: {
#   "reason": "The play takes place in places that were part of ancient Greece, but with characters from French mythology.",
#   "period": "Ancient Greece",
#   "timeframe_start": "750-600 BCE",
#   "timeframe_end": "550-400 BCE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30071124b: {
#   "reason": "the play 'L'Arcadie' is a classic of French theatre, written by Jean Racine in 1670",
#   "period": "baroque period",
#   "timeframe_start": "1665-01-01",
#   "timeframe_end": "1680-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30077767q: {
#   "reason": "Roman Empire was a major power at that time, Greece was an ally, and Rome had a significant presence in Greece",
#   "period": "Ancient Greek period of Roman dominance",
#   "timeframe_start": "150-100 BCE",
#   "timeframe_end": "300 BCE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30078974s: {
#   "reason": "Id is from the BnF, which usually corresponds to French or European theatre.",
#   "period": "19th century",
#   "timeframe_start": "1800-01-01",
#   "timeframe_end": "1900-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30085086s: {
#   "reason": "Geographic location (France) might suggest a timeframe from the 17th to the 19th century, given the significance of Parnasse as an intellectual hub during that period.",
#   "period": "French Enlightenment and Romanticism",
#   "timeframe_start": "1780-01-01",
#   "timeframe_end": "1830-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30085107x: {
#   "reason": "Lack of specific information about the time period, but Perse is associated with ancient Greek mythology, which typically spans from around 2000 BCE to 500 CE.",
#   "period": "Ancient Greece",
#   "timeframe_start": "1501-01-01",
#   "timeframe_end": "500 CE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30121701g: {
#   "reason": "Geographic location Rome is most likely to refer to Ancient Rome or Renaissance Rome, not modern-day Rome.",
#   "period": "Ancient/Renaissance",
#   "timeframe_start": "1429-03-18",
#   "timeframe_end": "476-09-04"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb301217186: {
#   "reason": "Thrace's ancient history and Rande's modern-day location suggest a mix of historical and contemporary elements.",
#   "period": "Ancient",
#   "timeframe_start": "800-750 BCE",
#   "timeframe_end": "present day"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30122385g: {
#   "reason": "Geographical locations suggested a Mediterranean or ancient setting.",
#   "period": "Ancient",
#   "timeframe_start": "750-500 BCE",
#   "timeframe_end": "300 BCE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb301482732: {
#   "reason": "Geographical locations suggest Ancient Roman Empire era",
#   "period": "Ancient Roman Empire",
#   "timeframe_start": "146 BCE",
#   "timeframe_end": "476 CE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb301483097: {
#   "reason": "The timeframe is chosen because Rome was the capital city of the Roman Empire, which rose to power in the 1st century BC.",
#   "period": "Ancient Rome",
#   "timeframe_start": "509 BC",
#   "timeframe_end": "476 AD"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30152125p: {
#   "reason": "Geographical location and historical significance of Sicily, particularly during the Greek and Roman periods",
#   "period": "Ancient to Medieval",
#   "timeframe_start": "750-01-01",
#   "timeframe_end": "1000-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30152167m: {
#   "reason": "Given the locations Greece, Troy, and characters, it is likely that the play takes place during the Trojan War, which was fought between the city-states of Troy and Greece.",
#   "period": "Bronze Age",
#   "timeframe_start": "1200-1150 BCE",
#   "timeframe_end": "1150-1100 BCE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb301574549: {
#   "reason": "Geographical location: Limousin region, France, which was part of the medieval kingdom of Francia.",
#  "period": "Medieval period",
#   "timeframe_start": "1200-01-01",
#   "timeframe_end": "1500-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb301619297: {
#   "reason": "Proximity to historical events and cultural significance in France",
#   "period": "Middle Ages",
#   "timeframe_start": "1150-12-31",
#   "timeframe_end": "1250-01-01"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30167532g: {
#   "reason": "play's title 'Gabinie' and location 'Rome' suggests an Italian context, and given the id '30167532g' which is likely a library catalog record for an ancient text, it is reasonable to assume the play takes place in Ancient Rome.",
#   "period": "Ancient Roman period",
#   "timeframe_start": "146 BC",
#   "timeframe_end": "14 AD"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30167536v: {
#   "reason": "No direct connection to a specific timeframe can be made based on the provided information.",
#   "period": "Historical period",
#   "timeframe_start": "1800-01-01",
#   "timeframe_end": "1900-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30186247v: {
#   "reason": "Geographical location (Rome) is typically associated with Ancient Rome or Renaissance period",
#   "period": "Ancient/Renaissance period",
#   "timeframe_start": "49 BC-476 AD",
#   "timeframe_end": "1500 AD"
# }

# %%
results_df_ollama_no_title = pd.DataFrame(results)

# %%
results_df_ollama_no_title.head()
# Out:
#                                            target  \
# 0  http://catalogue.bnf.fr/ark:/12148/cb30000572m
# 1  http://catalogue.bnf.fr/ark:/12148/cb30000577b
# 2  http://catalogue.bnf.fr/ark:/12148/cb30040061d
# 3  http://catalogue.bnf.fr/ark:/12148/cb30040062r
# 4  http://catalogue.bnf.fr/ark:/12148/cb30041092x
#
#                                               reason          period  \
# 0  Geographical locations and mythological charac...   Late Helladic
# 1  Given that Coriolanus is a play by William Sha...  Roman Republic
# 2  Geographic locations suggest a Mediterranean o...         Ancient
# 3  Georges Bataille was a French literary figure ...    20th century
# 4  Character's age, cultural references, and geog...          Modern
#
#   time_llama_start time_llama_end
# 0    1200-1150 BCE  1100-1050 BCE
# 1      410-396 BCE        395 BCE
# 2         750-0BCE       300-0BCE
# 3       1890-01-01     1933-12-31
# 4       1789-01-01     1850-12-31

# %% [markdown]
# ### Take title, persons, places

# %%
# Function to query Ollama with title
def get_timeframe_for_play_title(group):
    target = group['target'].iloc[0]  
    title = ", ".join(group['title'].dropna().astype(str).unique())  # add title
    places = ", ".join(group['place'].dropna().astype(str).unique())  # concat unique places for the same target
    persons = ", ".join(group['person'].dropna().astype(str).unique())  # concat unique persons for the same target

    # prompt
    prompt = (
        f"I have a play titled {title} with the id {target} happening in these places: {places}, "
        f"and with these characters: {persons}. Given this information, suggest me what could be the timeframe where the play takes place. "
        f"I do not need the precise and exact date, but the timespan, formatted in ISO, of the period where the play could have taken place. "
        f"If the information provided are not enough to determine a timeframe, give me your best guess. Respond only with valid JSON. "
        f"Do not write an introduction or summary. For the JSON use the form:\n\n"
        f"{{\n  \"reason\": \"why has been chosen\",\n \"period\": \"period_identified\",\n  \"timeframe_start\": \"ISO value of the start\",\n  \"timeframe_end\": \"ISO value of the end\"\n}}\n\n"
        f"The values in the JSON \"timeframe_start\" and \"timeframe_end\" should always be a single valid ISO date in the form YYYY-MM-DD."
    )

    try:
        stream = chat(
            model='llama3.2',
            messages=[{'role': 'user', 'content': prompt}],
            stream=True,
        )

        # Collect the streamed response
        response_data = ""
        for chunk in stream:
            if 'message' in chunk and 'content' in chunk['message']:
                response_data += chunk['message']['content']

        # Debug assembled response
        print(f"Full response for target {target}: {response_data}")

        # Attempt to parse the assembled response as JSON
        response_json = json.loads(response_data.strip())

        # Extract the relevant fields
        return {
            "target": target,
            "title": title,
            "reason": response_json.get("reason"),
            "period": response_json.get("period"),
            "time_llama_start": response_json.get("timeframe_start"),
            "time_llama_end": response_json.get("timeframe_end"),
        }

    except json.JSONDecodeError as e:
        print(f"JSON decode error for target {target}: {e}")
        print(f"Response data: {response_data}")
        return {
            "target": target,
            "title": title,
            "reason": None,
            "period": None,
            "time_llama_start": None,
            "time_llama_end": None,
        }
    except Exception as e:
        print(f"Error for target {target}: {e}")
        return {
            "target": target,
            "title": title,
            "reason": None,
            "period": None,
            "time_llama_start": None,
            "time_llama_end": None,
        }

# %%
results = []
for target, group in df_sample.groupby('target'):
    result = get_timeframe_for_play_title(group)
    if result:
        results.append(result)
# Out:
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30000572m: {"reason": "Mythological periods where Clytie was associated with Myc\u00e9ne", "period": "Mycenaean period", "timeframe_start": "1200-1150 BC", "timeframe_end": "1100-1050 BC"}
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30000577b: {
#   "reason": "Given that Coriolan is attributed to M. Abeille, a French writer, and the play takes place in Rome, Lutèce (Lrin), it is likely that the timeframe is from the late Middle Ages or Early Modern Period, when the city of Paris was also known as Lutèce.",
#   "period": "Late Middle Ages/Early Modern Period",
#   "timeframe_start": "1450-01-01",
#   "timeframe_end": "1550-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30040061d: {
#   "reason": "Irlande was part of the feudal kingdom of Morgawr (Mogale) during the 5th to 12th centuries, and it shares cultural similarities with 11th-century Normandy",
#   "period": "Middle Ages",
#   "timeframe_start": "870-1000",
#   "timeframe_end": "1200"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30040062r: {
#   "reason": "Geographic locations and historical figures suggest an 18th-century French setting.",
#   "period": "Rococo period",
#   "timeframe_start": "1750-01-01",
#   "timeframe_end": "1780-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30041092x: {
#   "reason": "Geographical locations and title suggest Baroque period",
#   "period": "Baroque",
#   "timeframe_start": "1650-01-01",
#   "timeframe_end": "1700-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb300410980: {
#   "reason": "Location at Madonte and presence of Temple de Diane suggest an earlier period, given its association with Diana (goddess) and possibly pre-Christian era",
#   "period": "Antiquity",
#   "timeframe_start": "500 BCE",
#   "timeframe_end": "500 CE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb300550714: {"reason": "Brutus was assassinated on March 15, 44 BCE", "period": "Late Roman Republic", "timeframe_start": "49-43 BCE", "timeframe_end": "44-40 BCE"}
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb300581040: {
#   "reason": "Geographical information suggests late Renaissance or early Baroque period, given the presence of Rome and France",
#   "period": "Renaissance to Baroque transition",
#   "timeframe_start": "1590-01-01",
#   "timeframe_end": "1650-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb300581118: {
#   "reason": "Geographic locations suggest an ancient or medieval setting, with Gange and Trone possibly being references to ancient city names.",
#   "period": "Ancient Greece or Rome",
#   "timeframe_start": "750-500 BCE",
#   "timeframe_end": "500 CE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30071124b: {
#   "reason": "Given that the play is based on an invention by 'De l'invention du sieur de Basire' which is attributed to Jean-Honoré Fragonard, and considering the themes of Arcadia and pastoral scenes, I have chosen a timeframe for La Princesse ou L'heureuse bergère.",
#   "period": "18th century French literature",
#   "timeframe_start": "1750-01-01",
#   "timeframe_end": "1799-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30077767q: {
#   "reason": "Geographical locations (Greece and Rome) are associated with ancient civilizations, while 'Hypsicratee' seems to be inspired by Greek history.",
#   "period": "Ancient Era",
#   "timeframe_start": "432 BCE",
#   "timeframe_end": "338 BCE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30078974s: {
#   "reason": "The timeframe is chosen based on the historical period when Monomotapa was an independent chiefdom, which was during the 16th to 19th centuries.",
#   "period": "colonial era",
#   "timeframe_start": "1850-01-01",
#   "timeframe_end": "1900-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30085086s: {
#   "reason": "Given that Sa Majesté is referring to King Louis XIV, who was the ruler of France during this time period, and the play took place at his chateau de Saint-Germain-en-Laye, we can narrow down the timeframe.",
#   "period": "17th century",
#   "timeframe_start": "1625-12-01",
#   "timeframe_end": "1715-11-30"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30085107x: {
#   "reason": "the play is a tragi-comedie, which suggests it could have taken place during the 17th or 18th century",
#   "period": "Baroque period",
#   "timeframe_start": "1660-01-01",
#   "timeframe_end": "1750-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30121701g: {"reason": "Rome was a major city from 8th century BC to 4th century AD, Telme is likely a misspelling of \"Theleme\", a mythical island from ancient Greek literature, and the Countess de Pembroc does not have clear historical references", "period": "Ancient Greece or Roman era", "timeframe_start": "1500-01-01", "timeframe_end": "500-12-31"}
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb301217186: {
#   "reason": "Geographic location and historical context suggest a timeframe between the 16th and 17th centuries, as Thracia was part of the Ottoman Empire during this period.",
#   "period": "Ottoman era",
#   "timeframe_start": "1550-01-01",
#   "timeframe_end": "1650-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30122385g: {
#   "reason": "Geographic locations suggest Ancient Greece or Roman Empire, while Play is attributed to Jean Boissin de Gallardon, a French writer from the 17th century.",
#   "period": "Ancient Greece and Medieval Europe",
#   "timeframe_start": "500-1500",
#   "timeframe_end": "1700"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb301482732: {
#   "reason": "Historical records indicate Germanicus' military campaigns took place between 15 BC and 19 AD, with his death occurring around 19 AD.",
#   "period": "Late Republic to Early Empire period",
#   "timeframe_start": "15-01-01",
#   "timeframe_end": "19-03-27"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb301483097: {
#   "reason": "Geographical locations and character are not sufficient to determine an exact timeframe, but Rome's historical presence in these places and Phaéton being a mythological figure from ancient Greek literature suggest a Hellenistic period timeline.",
#   "period": "Hellenistic period",
#   "timeframe_start": "300 BCE-100 BCE",
#   "timeframe_end": "100 BCE-50 BCE"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30152125p: {
#   "reason": "Given that the play is a tragi-comédie, it could take place during the Renaissance or Baroque period when such genre was popular.",
#   "period": "Renaissance and Baroque",
#   "timeframe_start": "1580-01-01",
#   "timeframe_end": "1750-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30152167m: {
#   "reason": "Given that the play is based on Homer's Odyssey, and considering the locations Greece, Troy, and the mythical island of Circe, it is likely that the play takes place during the Trojan War.",
#   "period": "Late Bronze Age",
#   "timeframe_start": "1200-1180",
#   "timeframe_end": "1150-1130"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb301574549: {
#   "reason": "Molière's death is documented as July 17th, 1673, but there is no direct link to this date with the given id or locations.",
#   "period": "17th century",
#   "timeframe_start": "1650-01-01",
#   "timeframe_end": "1680-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb301619297: {
#   "reason": "Geographical references to Rochelle and Tours in France, which experienced significant political unrest during the French Revolution",
#   "period": "French Revolution",
#   "timeframe_start": "1789-11-04",
#   "timeframe_end": "1794-03-24"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30167532g: {
#   "reason": "The play is titled Gabinie, tragedie chretienne and refers to a specific work by an unknown author, which likely dates back to the Christian era",
#   "period": "Christian era",
#   "timeframe_start": "500-01-01",
#   "timeframe_end": "1500-12-31"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30167536v: {
#   "reason": "Given the locations (Madagascar, Ariège) and the character types (Le grondeur, comédie), it is likely that the play takes place in France during its colonial period.",
#   "period": "French colonial period",
#   "timeframe_start": "1872-08-01",
#   "timeframe_end": "1960-11-30"
# }
# Full response for target http://catalogue.bnf.fr/ark:/12148/cb30186247v: {
#   "reason": "Based on historical context and the Roman setting",
#   "period": "Late Antiquity",
#   "timeframe_start": "270-280",
#   "timeframe_end": "290"
# }

# %%
results_df_with_title_llama = pd.DataFrame(results)

# %%
results_df_with_title_llama.head()
# Out:
#                                            target  \
# 0  http://catalogue.bnf.fr/ark:/12148/cb30000572m
# 1  http://catalogue.bnf.fr/ark:/12148/cb30000577b
# 2  http://catalogue.bnf.fr/ark:/12148/cb30040061d
# 3  http://catalogue.bnf.fr/ark:/12148/cb30040062r
# 4  http://catalogue.bnf.fr/ark:/12148/cb30041092x
#
#                                                title  \
# 0             Argélie, reyne de Thessalie . Tragédie
# 1                Coriolan , tragédie. Par M. Abeille
# 2  Dipné, infante d'Irlande , tragédie, dédiée à ...
# 3  Geneviève, ou L'innocence reconnue , tragédie,...
# 4  La Dorinde du Sr Auvray . Tragi-comédie. Dédié...
#
#                                               reason  \
# 0  Mythological periods where Clytie was associat...
# 1  Given that Coriolan is attributed to M. Abeill...
# 2  Irlande was part of the feudal kingdom of Morg...
# 3  Geographic locations and historical figures su...
# 4  Geographical locations and title suggest Baroq...
#
#                                  period time_llama_start time_llama_end
# 0                      Mycenaean period     1200-1150 BC   1100-1050 BC
# 1  Late Middle Ages/Early Modern Period       1450-01-01     1550-12-31
# 2                           Middle Ages         870-1000           1200
# 3                         Rococo period       1750-01-01     1780-12-31
# 4                               Baroque       1650-01-01     1700-12-31

# %%
#results_df_with_title_llama.to_csv('/Users/nicola/Downloads/results_with_llama.csv', index=False)

# %% [markdown]
# ## Open AI API

# %% [markdown]
# ### Take title, persons, places

# %%
load_dotenv()
# Out:
# True

# %%
def get_timeframe_for_play(group):
    # add API key
    api_key = os.getenv("OPENAI_API_KEY")
    client = OpenAI(api_key=api_key)
    
    target = group['target'].iloc[0]
    title = ", ".join(group['title'].dropna().astype(str).unique())
    places = ", ".join(group['place'].dropna().astype(str).unique()) # concat unique places for the same target
    persons = ", ".join(group['person'].dropna().astype(str).unique()) # concat unique persons for the same target
    
    prompt = (
        f"I have a play titled {title} with the id {target} happening in these places: {places}, "
        f"and with these characters: {persons}. Given this information, suggest me what could be the timeframe where the play takes place. "
        f"I do not need the precise and exact date, but the timespan, formatted in ISO, of the period where the play could have taken place. "
        f"If the information provided are not enough to determine a timeframe, give me your best guess. Respond only with valid JSON. "
        f"Do not write an introduction or summary. For the JSON use the form:\n\n"
        f"{{\n  \"reason\": \"why has been chosen\",\n \"period\": \"period_identified\",\n  \"timeframe_start\": \"ISO value of the start\",\n  \"timeframe_end\": \"ISO value of the end\"\n}}\n\n"
        f"The values in the JSON \"timeframe_start\" and \"timeframe_end\" should always be a single valid ISO date in the form YYYY-MM-DD."
    )
    
    try:
        completion = client.chat.completions.create(
            model="gpt-4",  # model name, using just gpt-4 here
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": prompt}
            ]
        )
        
        response_data = completion.choices[0].message.content.strip()
        response_data = response_data.strip("```").strip("json").strip()
        print(f"Full response for target {target}: {response_data}")
        response_json = json.loads(response_data)
        
        return {
            "target": target,
            "title": title,
            "reason": response_json.get("reason"),
            "period": response_json.get("period"),
            "time_openai_start": response_json.get("timeframe_start"),
            "time_openai_end": response_json.get("timeframe_end"),
        }
        
    except json.JSONDecodeError as e:
        print(f"JSON decode error for target {target}: {e}")
        print(f"Response data: {response_data}")
        return {
            "target": target,
            "title": title,
            "reason": None,
            "period": None,
            "time_openai_start": None,
            "time_openai_end": None,
        }
    except Exception as e:
        print(f"Error for target {target}: {e}")
        return {
            "target": target,
            "title": title,
            "reason": None,
            "period": None,
            "time_openai_start": None,
            "time_openai_end": None,
        }

# %%
results = []
for target, group in df_sample.groupby('target'):
    result = get_timeframe_for_play(group)
    if result:
        results.append(result)

# %%
results_df_openai = pd.DataFrame(results)

# %%
results_df_openai.head()
# Out:
#                                            target  \
# 0  http://catalogue.bnf.fr/ark:/12148/cb30000572m
# 1  http://catalogue.bnf.fr/ark:/12148/cb30000577b
# 2  http://catalogue.bnf.fr/ark:/12148/cb30040061d
# 3  http://catalogue.bnf.fr/ark:/12148/cb30040062r
# 4  http://catalogue.bnf.fr/ark:/12148/cb30041092x
#
#                                                title  \
# 0             Argélie, reyne de Thessalie . Tragédie
# 1                Coriolan , tragédie. Par M. Abeille
# 2  Dipné, infante d'Irlande , tragédie, dédiée à ...
# 3  Geneviève, ou L'innocence reconnue , tragédie,...
# 4  La Dorinde du Sr Auvray . Tragi-comédie. Dédié...
#
#                                               reason            period  \
# 0  The play is based on Greek mythology and Mycen...        Bronze Age
# 1  The play Coriolan is a tragedy written by M. A...    Roman Republic
# 2  The play Dipné, infante d'Irlande is likely se...       Middle Ages
# 3  Based on the information provided, the exact t...  The 17th century
# 4  As there's no specific date related to the pla...      17th century
#
#   time_openai_start time_openai_end
# 0        1600-01-01      1100-12-31
# 1        -509-01-01       -27-01-01
# 2         500-01-01      1500-12-31
# 3        1600-01-01      1699-12-31
# 4        1600-01-01      1699-12-31
