# %% [markdown]
# Entity linkers to test:
# - spacy entity fishing
# - relik
# - mGENRE

# %% [markdown]
# ## Test spaCy
#
# Just some simple tests using spacy, with a large model for French, and entity linking with the `entity-fishing` server.

# %%
# imports
import spacy

# %%
nlp_model_fr = spacy.load("fr_core_news_lg")

# %%
nlp_model_fr.remove_pipe('ner')
# Out:
# ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x11ff64ac0>)

# %%
nlp_model_fr.add_pipe(
    "entityfishing", config={
        "api_ef_base": "http://nerd.huma-num.fr/nerd/service"
    }
)

# %%
# TODO:
# load the text from docs dataframe
# load the entity mentions from the corresponding dataframe
# this way we can compare the number of entities extracted by spacy
# versus those that we extract
text_fr = "À NIONSIEUR AIXTTUSIC LIEUTENANT DE LA Compagnie de Chevaux-Légers, de Monseigneur le Cardiar, Duc de RICHELIEU, et son Lieutenant. aussi au Gouvernement du Pont de l'Arche ONSIEUR, Ce n'est ni vôtre grande reprit putation, ni l'estime particulière que le premier de tous les hommes fait de votre grande Vertu, qui m'obligé à vous dédier ce petit Ouvrage, que tous mes Amis me demandent. C'est ma pure inclination, qui m'y porte, et la passion extrême que ie conserve inviolablement, et sans discontinuation aucune à votre service, depuis quatorze ans entiers, que j'ai l'honneur d'être connu de Vous, et l'avantage de vous bien connaître. À qui, Seigneur vous prie, pourrais-je plus justement présenter mon PYRANDRE, qu'à Celui qui le fait reviure aujourd'huypar ses actions, et qui pour parler plus proprement, cache en quelque façon le sens moral de la Fable que j'invente? l'espère, MONSIEUR, qu'elle sera encore mieux un jour expliquée en votre Personne, et que votre mérite vous éleuerd si haut, que vous ne changerez pas volontiers votre condition à celle des Princes d'Alba nit. ArAuis jonis miendre davantage, voi pouvés, comme eux, fournir présentement de matière aux plus beaux Romans, et plus a vantageusement en ce point, que nous serons bien assurés qu'ils partiront d'une source pure, et qu'ils auront un fondement vérila, blé. Vous n'avez jamais rien entrepris, qui ne vous ait heureusement reüssy; Vous n'avez jamais fait aucun combat, où vous n'ayez eu tout l'avantage. Quelque modestie naturelle qui vous porte à cacher vos actions, votre gloire est si manifeste, que personne ne l'ignore plus; Et qui ne sait point aujourd'hui que vous êtes le seul Auteur de la délivrance de Rheuré, ne connaît pas le nom de Celui qui en cette occasion, comme en beaucoup d'autres, s'est servi de votre courage, et de votre adresse. Il n'appartient qu'à peine, MONSIEUR, de faire de justes élections, sans toucher à ses autres qualités, que je ne regarde qu'avec respect, et que sans sais mieux admirer que décrire. Il ne faut pas que je vous cèle, que me sentant obligé par ses bien-faits particuliers, et par ceux dont il a comblé toute la France, à lui donner désormais toutes mes pensées, j'ai presque été sur le point d'emprunter l'éclat de son Nom, pour mettre ce petit livre en lumière. Mais parce qu'il n'y a aucune proportion entre sa condition, et les galanteries que ie traitte, j'eusse véritablement eu honte de mandier sa faveur et sa protection pour des Princes fabuleux, cependant qu'il en protesge de véritables, et que sérieusement toute l'Europe implore son assistance. À ce défaut donc belle m'adresse à Vous, qui avez, cet honneur entre beaucoup d'autres, de porter la qualité de son Lieutenant; et et Les bien que l'on sache
#  ArAuis,
#  jonis miendre,
#  voi pouvés,
#  Romans,
#  vérila,
#  Vous n'avez jamais,
#  Et qui ne sait point,
#  Auteur de la délivrance,
#  Rheuré,
#  Celui,
#  MONSIEUR,
#  la France,
#  Nom,
#  Princes,
#  l'Europe,
#  Lieutenant;,
#  Les bien que l'on sache,
#  Éminence,
#  Créatures,
#  MONSIEUR,
#  Votre très-humble,
#  ARGUMENT Es guerres de Thrace,
#  Pyrandre,
#  Armée,
#  Estat,
#  Enfin le Roi,
#  Princesse Lisimène,
#  Albanie,
#  Princesse Orante,
#  États,
#  Prince Pyroxène,
#  Ambassade,
#  Roi d'Albanie,
#  Pyrandre,
#  Princesse,
#  Roi,
#  Prince,
#  Ambassade,
#  Ennemis,
#  Croie,
#  Albanie,
#  Roi,
# ...

# %%
extracted_places = [e for e in doc_fr.ents if e.label_ == "LOC"]

# %%
len(extracted_places)
# Out:
# 28

# %%
for ent in extracted_places:
        print((ent.text, ent.label_, ent._.kb_qid, ent._.url_wikidata, ent._.nerd_score))
# Out:
# ('Romans', 'LOC', 'Q1747689', 'https://www.wikidata.org/wiki/Q1747689', 0.4596)
# ('la France', 'LOC', 'Q527431', 'https://www.wikidata.org/wiki/Q527431', 0.148)
# ('Princes', 'LOC', 'Q7244433', 'https://www.wikidata.org/wiki/Q7244433', 0.3402)
# ("l'Europe", 'LOC', None, None, None)
# ('Estat', 'LOC', None, None, None)
# ('Albanie', 'LOC', 'Q222', 'https://www.wikidata.org/wiki/Q222', 0.3167)
# ('Princesse Orante', 'LOC', None, None, None)
# ('États', 'LOC', 'Q16147749', 'https://www.wikidata.org/wiki/Q16147749', 0.4484)
# ('Ambassade', 'LOC', None, None, None)
# ("Roi d'Albanie", 'LOC', None, None, None)
# ('Ambassade', 'LOC', None, None, None)
# ('Croie', 'LOC', None, None, None)
# ('Albanie', 'LOC', 'Q222', 'https://www.wikidata.org/wiki/Q222', 0.3167)
# ('Cour', 'LOC', 'Q16089913', 'https://www.wikidata.org/wiki/Q16089913', 0.3402)
# ('Orante', 'LOC', None, None, None)
# ('Pyrandre', 'LOC', None, None, None)
# ('Orante', 'LOC', None, None, None)
# ...

# %%
for ent in doc_fr.ents:
        print((ent.text, ent.label_, ent._.kb_qid, ent._.url_wikidata, ent._.nerd_score))
# Out:
# ('NIONSIEUR', 'ORG', None, None, None)
# ('AIXTTUSIC LIEUTENANT DE LA Compagnie de Chevaux-Légers', 'MISC', None, None, None)
# ('Monseigneur le Cardiar', 'PER', None, None, None)
# ('Duc de RICHELIEU', 'PER', 'Q2663290', 'https://www.wikidata.org/wiki/Q2663290', 0.1321)
# ('Lieutenant', 'PER', 'Q186024', 'https://www.wikidata.org/wiki/Q186024', 0.4112)
# ("Gouvernement du Pont de l'Arche ONSIEUR", 'MISC', None, None, None)
# ("Ce n'est ni vôtre grande", 'MISC', None, None, None)
# ('Vertu', 'PER', 'Q1130409', 'https://www.wikidata.org/wiki/Q1130409', 0.4594)
# ('Ouvrage', 'MISC', None, None, None)
# ("Vous, et l'avantage de vous bien", 'MISC', None, None, None)
# ('Seigneur vous prie', 'MISC', None, None, None)
# ('PYRANDRE', 'ORG', None, None, None)
# ('la Fable', 'MISC', None, None, None)
# ('MONSIEUR', 'ORG', 'Q1092777', 'https://www.wikidata.org/wiki/Q1092777', 0.1555)
# ("Princes d'Alba nit", 'PER', None, None, None)
# ('ArAuis', 'PER', None, None, None)
# ...

# %%
for n_sent, sentence in enumerate(doc_fr.sents):
    for token in sentence:
        print(n_sent, token.text, token.ent_type_)
# Out:
# 0 À
# 0 NIONSIEUR ORG
# 0 AIXTTUSIC MISC
# 0 LIEUTENANT MISC
# 0 DE MISC
# 0 LA MISC
# 0 Compagnie MISC
# 0 de MISC
# 0 Chevaux MISC
# 0 - MISC
# 0 Légers MISC
# 0 ,
# 0 de
# 0 Monseigneur PER
# 0 le PER
# 0 Cardiar PER
# 0 ,
# 0 Duc PER
# 0 de PER
# 0 RICHELIEU PER
# 0 ,
# 0 et
# 0 son
# 0 Lieutenant PER
# 0 .
# 1 aussi
# 1 au
# 1 Gouvernement MISC
# 1 du MISC
# 1 Pont MISC
# 1 de MISC
# 1 l' MISC
# 1 Arche MISC
# 1 ONSIEUR MISC
# 1 ,
# 1 Ce MISC
# 1 n' MISC
# 1 est MISC
# 1 ni MISC
# 1 vôtre MISC
# 1 grande MISC
# 1 reprit
# 1 putation
# 1 ,
# 1 ni
# 1 l'
# 1 estime
# 1 particulière
# 1 que
# 1 le
# 1 premier
# 1 de
# 1 tous
# 1 les
# 1 hommes
# 1 fait
# 1 de
# 1 votre
# 1 grande
# 1 Vertu PER
# 1 ,
# 1 qui
# 1 m'
# 1 obligé
# 1 à
# 1 vous
# 1 dédier
# 1 ce
# 1 petit
# 1 Ouvrage MISC
# 1 ,
# 1 que
# 1 tous
# 1 mes
# 1 Amis
# 1 me
# 1 demandent
# 1 .
# 2 C'
# 2 est
# 2 ma
# 2 pure
# 2 inclination
# 2 ,
# 2 qui
# 2 m'
# 2 y
# 2 porte
# 2 ,
# 2 et
# 2 la
# 2 passion
# 2 extrême
# ...

# %% [markdown]
# ## Test `tei2spacy` pipeline (wip)
#
# If we want to replace spacy entity mentions with our own ones, we need to intervene in the spacy docs, and inject our mentions.
# This is doable but requires a mapping between each token in the spacy document and TEI tags in the input TEI file. This way, we can know whether a given token is part of a `placeName` or `persName` tag and label it accordingly. At that point we can call the entity fishing service on our custom mentions.

# %%
import random
import sys
from pathlib import Path
sys.path.append("../")
import spacy
from spacy.tokens import DocBin
from lib.utils import tei2spacy, nlp_model_fr, sample_files, print_corpus_summary
from typing import List

# %%
SPACY_CORPUS_SERIALIZED_PATH = "./data/corpus.spacy"

if Path(SPACY_CORPUS_SERIALIZED_PATH).exists():
    spacy_corpus = DocBin(store_user_data=True).from_disk(SPACY_CORPUS_SERIALIZED_PATH)
    print(f"Loaded serialize spacy corpus from {SPACY_CORPUS_SERIALIZED_PATH}")
else:
    spacy_corpus = DocBin(store_user_data=True)
# Out:
# Loaded serialize spacy corpus from ./data/corpus.spacy

# %%
print_corpus_summary(spacy_corpus, nlp_model_fr)
# Out:
# Number of documents in the corpus: 7
# Number of entities in the corpus: 1653
# Number of tokens in the corpus: 92125

# %%
sample_size = 5
corpus_basedir = Path("../TheatreLFSV2-downloaded/")
sampled_files = sample_files(Path(corpus_basedir / 'NER'), sample_size)

# %%
len(sampled_files)
# Out:
# 5

# %%
# %%time
entity_projection = False
docs = []
for n, f in enumerate(sampled_files):
    docs.append(tei2spacy(f, entity_projection))
# Out:
# Processing file: ../TheatreLFSV2-downloaded/NER/bpt6k15133011.tar.gz.tei_segmented_ner.xml
# ...
# shrink whitespace: 100%|██████████| 72243/72243 [00:04<00:00, 14752.33it/s]
# There are 4530 tokens in document bpt6k15133011.tar.gz.tei_segmented_ner.xml
# Skipping entity projection
# Processing file: ../TheatreLFSV2-downloaded/NER/bpt6k5789987q.tar.gz.tei_segmented_ner.xml
# ...
# shrink whitespace: 100%|██████████| 268171/268171 [00:21<00:00, 12396.25it/s]
# There are 19004 tokens in document bpt6k5789987q.tar.gz.tei_segmented_ner.xml
# Skipping entity projection
# Processing file: ../TheatreLFSV2-downloaded/NER/bpt6k10900546.tar.gz.tei_segmented_ner.xml
# ...
# shrink whitespace: 100%|██████████| 274226/274226 [00:20<00:00, 13178.42it/s]
# There are 19013 tokens in document bpt6k10900546.tar.gz.tei_segmented_ner.xml
# Skipping entity projection
# Processing file: ../TheatreLFSV2-downloaded/NER/bpt6k54487748.tar.gz.tei_segmented_ner.xml
# ...

# %%
# %%time
entity_projection = True
docs = []
for n, f in enumerate(sampled_files):
    docs.append(tei2spacy(f, entity_projection))
# Out:
# Processing file: ../TheatreLFSV2-downloaded/NER/bpt6k15133011.tar.gz.tei_segmented_ner.xml
# ...
# shrink whitespace: 100%|██████████| 72243/72243 [00:04<00:00, 14528.28it/s]
# There are 4530 tokens in document bpt6k15133011.tar.gz.tei_segmented_ner.xml
# Projecting NER labels from TEI onto SpaCy tokens: 100%|██████████| 4530/4530 [01:18<00:00, 58.03it/s]
# Found 83 entities in document bpt6k15133011.tar.gz.tei_segmented_ner.xml
# ##############################################
# Processing file: ../TheatreLFSV2-downloaded/NER/bpt6k5789987q.tar.gz.tei_segmented_ner.xml
# ...
# shrink whitespace: 100%|██████████| 268171/268171 [00:21<00:00, 12753.45it/s]
# There are 19004 tokens in document bpt6k5789987q.tar.gz.tei_segmented_ner.xml
# Projecting NER labels from TEI onto SpaCy tokens: 100%|██████████| 19004/19004 [49:36<00:00,  6.39it/s]
# Found 375 entities in document bpt6k5789987q.tar.gz.tei_segmented_ner.xml
# ##############################################
# ...

# %%
for doc in docs:
    spacy_corpus.add(doc)
    
corpus_summary(spacy_corpus, nlp_model_fr)
# Out:
# Number of documents in the corpus: 7
# Number of entities in the corpus: 1653
# Number of tokens in the corpus: 92125

# %%
spacy_corpus.to_disk("./data/corpus.spacy")

# %% [markdown]
# ### Parallelize

# %%
from dask.distributed import Client
import dask.bag as db

# %%
dask_client = Client()
# Out:
# /opt/miniconda3/envs/relik/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 54968 instead
#   warnings.warn(

# %%
dask_client
# Out:
# <Client: 'tcp://127.0.0.1:54969' processes=3 threads=6, memory=16.00 GiB>

# %%
entity_projection = True
sample_size = 5
corpus_basedir = Path("../TheatreLFSV2-downloaded/")
sampled_files = sample_files(Path(corpus_basedir / 'NER'), sample_size)

# %%
docs = db.from_sequence(sampled_files).map(tei2spacy, entity_projection).compute()
# Out:
# Processing file: ../TheatreLFSV2-downloaded/NER/bpt6k5458862p.tar.gz.tei_segmented_ner.xml
# Processing file: ../TheatreLFSV2-downloaded/NER/bpt6k1526239b.tar.gz.tei_segmented_ner.xml
# Processing file: ../TheatreLFSV2-downloaded/NER/bpt6k852851z.tar.gz.tei_segmented_ner.xml
# Processing file: ../TheatreLFSV2-downloaded/NER/bpt6k6112868p.tar.gz.tei_segmented_ner.xmlProcessing file: ../TheatreLFSV2-downloaded/NER/bpt6k1280410m.tar.gz.tei_segmented_ner.xml
# ...
#  53%|█████▎    | 153/288 [00:01<00:01, 117.46it/s]0:02, 4491.52it/s]
#
# ...
# create view: 100%|██████████| 26733/26733 [00:11<00:00, 2391.78it/s]39it/s]
#
# ...
# shrink whitespace: 100%|██████████| 42614/42614 [00:02<00:00, 14481.02it/s]
#
# ...
# 100%|██████████| 992/992 [00:03<00:00, 256.41it/s]][A
#
# ...
# insert tag text:   2%|▏         | 5107/220816 [00:00<00:12, 17640.47it/s]
# There are 2513 tokens in document bpt6k1526239b.tar.gz.tei_segmented_ner.xml
# insert tag text:   4%|▍         | 15261/379430 [00:00<00:19, 18325.90it/s]
# ...

# %%
for doc in docs:
    spacy_corpus.add(doc)
    
corpus_summary(spacy_corpus, nlp_model_fr)
# Out:
# Number of documents in the corpus: 12
# Number of entities in the corpus: 3204
# Number of tokens in the corpus: 184314

# %%
spacy_corpus.to_disk("./data/corpus.spacy")

# %% [markdown]
# ## Entity fishing with spaCy

# %%
nlp_model_fr.add_pipe(
    "entityfishing", config={
        "api_ef_base": "http://nerd.huma-num.fr/nerd/service"
    }
)

# %%
entity_fishing_pipe = nlp_model_fr.get_pipe("entityfishing")

# %%
spacy_doc = entity_fishing_pipe(spacy_doc)

# %%
import pandas as pd

# %%
entities_df = pd.DataFrame(
    [
        {
            'mention': ent.text,
            'ner_label': ent.label_,
            'qid': ent._.kb_qid,
            'url_wikidata': ent._.url_wikidata,
            'nerd_score': ent._.nerd_score
        }
        for ent in spacy_doc.ents
    ]
)

# %%
entities_df.sample(10)
# Out:
#       mention ner_label       qid                            url_wikidata  \
# 249    Oedipe       PER  Q3107460  https://www.wikidata.org/wiki/Q3107460
# 216    EPHITE       PER      None                                    None
# 244    EPHITE       PER      None                                    None
# 235     CREON       PER   Q732066   https://www.wikidata.org/wiki/Q732066
# 191     CREON       PER   Q732066   https://www.wikidata.org/wiki/Q732066
# 162     CREON       PER   Q732066   https://www.wikidata.org/wiki/Q732066
# 55     Thebes       LOC     Q5760     https://www.wikidata.org/wiki/Q5760
# 196     CREON       PER   Q732066   https://www.wikidata.org/wiki/Q732066
# 89   Seigneur       PER  Q3455090  https://www.wikidata.org/wiki/Q3455090
# 52   Polinice       PER   Q334817   https://www.wikidata.org/wiki/Q334817
#
#      nerd_score
# 249      0.4326
# 216         NaN
# 244         NaN
# 235      0.4609
# 191      0.4609
# 162      0.4609
# 55       0.8757
# ...

# %%
entities_df[entities_df['ner_label'] == 'LOC'].qid.value_counts()
# Out:
# qid
# Q5760       11
# Q41          6
# Q473295      1
# Q142         1
# Q762262      1
# Q1405281     1
# Q3470764     1
# Q90          1
# Name: count, dtype: int64

# %%
entities_df[entities_df['ner_label'] == 'PER'].qid.value_counts()
# Out:
# qid
# Q732066       73
# Q2023534      17
# Q65072220     15
# Q241077       10
# Q3455090       7
# Q3107460       4
# Q414           4
# Q753902        4
# Q107175006     3
# Q334817        3
# Q25269         2
# Q2366336       2
# Q388115        2
# Q410169        2
# Q650176        2
# Q2892027       1
# Q3083831       1
# Q174389        1
# Q848599        1
# Q28865         1
# Q663           1
# Q16985831      1
# Q456           1
# Q7542          1
# Q1357640       1
# Q776250        1
# Q657710        1
# Q107359663     1
# Q193529        1
# Q5756086       1
# Q693933        1
# Q3144070       1
# Q288307        1
# Q246154        1
# Q3576516       1
# Q3150          1
# Q1654435       1
# Q42289         1
# Q405292        1
# Q551735        1
# Name: count, dtype: int64

# %%
for ent in spacy_doc.ents:
        print((ent.text, ent.label_, ent._.kb_qid, ent._.url_wikidata, ent._.nerd_score))
# Out:
# ('ANTHOINE', 'PER', 'Q3083831', 'https://www.wikidata.org/wiki/Q3083831', 0.1887)
# ('SOMAVILLE', 'PER', None, None, None)
# ('France', 'LOC', 'Q142', 'https://www.wikidata.org/wiki/Q142', 0.4631)
# ('Césars', 'PER', 'Q174389', 'https://www.wikidata.org/wiki/Q174389', 0.4588)
# ('Alexandres', 'PER', None, None, None)
# ('Bris', 'PER', 'Q848599', 'https://www.wikidata.org/wiki/Q848599', 0.5968)
# ('Allemagne', 'LOC', 'Q473295', 'https://www.wikidata.org/wiki/Q473295', 0.3807)
# ('ROTROU', 'PER', 'Q2892027', 'https://www.wikidata.org/wiki/Q2892027', 0.2006)
# ('POLTACE', 'PER', None, None, None)
# ('ADRASTE', 'PER', 'Q107175006', 'https://www.wikidata.org/wiki/Q107175006', 0.1469)
# ('CREON', 'PER', 'Q732066', 'https://www.wikidata.org/wiki/Q732066', 0.4609)
# ('Polynice', 'PER', 'Q2023534', 'https://www.wikidata.org/wiki/Q2023534', 0.418)
# ('Polynice', 'PER', 'Q2023534', 'https://www.wikidata.org/wiki/Q2023534', 0.418)
# ...

# %%
# !head -n 200 {tei_files_paths[-1]}
# Out:
# 8358.41s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# <?xml version='1.0' encoding='UTF-8'?>
# <TEI xmlns="http://www.tei-c.org/ns/1.0">
#   <teiHeader>
#     <fileDesc>
#       <titleStmt>
#         <title>Antigone , tragédie de Mr. de Rotrou</title>
#         <author>Rotrou, Jean de</author>
#         <respStmt>
#           <resp>Acquisition &amp; transformation by</resp>
#           <persName>
#             <forename>Thibault</forename>
#             <surname>Clérice</surname>
#             <idno type="orcid">0000-0003-1852-9204</idno>
#           </persName>
#           <persName>
#             <forename>Simon</forename>
#             <surname>Gabay</surname>
#             <idno type="orcid">0000-0001-9094-4475</idno>
#           </persName>
#         </respStmt>
#       </titleStmt>
#       <extent>
#         <measure unit="images" n=""/>
#       </extent>
#       <publicationStmt>
#         <publisher>COLaF</publisher>
# ...
